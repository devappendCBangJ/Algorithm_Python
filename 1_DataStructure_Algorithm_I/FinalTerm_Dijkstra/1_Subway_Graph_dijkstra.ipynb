# %%
import pandas as pd
import numpy as np

df_sb_list = pd.read_csv('C:\\Users\\Hi\\Desktop\\자료구조\\지하철역.csv')

# %% [markdown]
# # 1. 데이터 전처리

# %% [markdown]
# ## 1) 기본

# %%
df_sb_list
# Out:
#       1호선        2호선  3호선    4호선   5호선
# 0     소요산         시청   대화     진접    방화
# 1     동두천      을지로입구   주엽     오남   개화산
# 2      보산      을지로3가  정발산  별내별가람  김포공항
# 3   동두천중앙      을지로4가   마두    당고개    송정
# 4      지행  동대문역사문화공원   백석     상계    마곡
# ..    ...        ...  ...    ...   ...
# 90     아산        NaN  NaN    NaN   NaN
# 91     배방        NaN  NaN    NaN   NaN
# 92   온양온천        NaN  NaN    NaN   NaN
# 93     신창        NaN  NaN    NaN   NaN
# 94    서동탄        NaN  NaN    NaN   NaN
#
# [95 rows x 5 columns]

# %%
sb_list = df_sb_list.to_numpy()
sb_list
# Out:
# array([['소요산', '시청', '대화', '진접', '방화'],
#        ['동두천', '을지로입구', '주엽', '오남', '개화산'],
#        ['보산', '을지로3가', '정발산', '별내별가람', '김포공항'],
#        ['동두천중앙', '을지로4가', '마두', '당고개', '송정'],
#        ['지행', '동대문역사문화공원', '백석', '상계', '마곡'],
#        ['덕정', '신당', '대곡', '노원', '발산'],
#        ['덕계', '상왕십리', '화정', '창동', '우장산'],
#        ['양주', '왕십리', '원당', '쌍문', '화곡'],
#        ['녹양', '한양대', '삼송', '수유', '까치산'],
#        ['가능', '뚝섬', '지축', '미아', '신정'],
#        ['의정부', '성수', '구파발', '미아삼거리', '목동'],
#        ['회룡', '건대입구', '연신내', '길음', '오목교'],
#        ['망월사', '구의', '붕광', '성신여대입구', '양평'],
#        ['도봉산', '강변', '녹번', '한성대입구', '영등포구청'],
#        ['방학', '잠실나루', '홍제', '혜화', '영등포시장'],
#        ['창동', '신천', '무악재', '동대문', '신길'],
#        ['녹천', '종합운동장', '독립문', '동대문역사문화공원', '여의도'],
#        ['월계', '삼성', '경북궁', '충무로', '여의나루'],
#        ['성북', '선릉', '안국', '명동', '마포'],
#        ['신이문', '역삼', '종로3가', '회현', '공덕'],
#        ['외대앞', '강남', '을지로3가', '서울역', '애오개'],
#        ['회기', '교대', '충무로', '숙대입구', '충정로'],
#        ['청량리', '서초', '동대입구', '삼각지', '서대문'],
#        ['제기동', '방배', '약수', '신용산', '광화문'],
#        ['신설동', '사당', '금호', '이촌', '종로3가'],
#        ['동묘앞', '낙성대', '옥수', '동작', '을지로4가'],
#        ['동대문', '서울대입구', '압구정', '이수', '동대문역사문화공원'],
#        ['종로5가', '봉천', '신사', '사당', '청구'],
#        ['종로3가', '신림', '잠원', '남태령', '신금호'],
#        ['종각', '신대방', '고속터미널', '선바위', '행당'],
#        ['시청', '구로디지털단지', '교대', '경마공원', '왕십리'],
#        ['서울역', '대림', '남부터미널', '대공원', '마장'],
#        ['남영', '신도림', '양재', '과천', '답십리'],
#        ['용산', '문래', '매봉', '정부과천청사', '장한평'],
#        ['노량진', '영등포구청', '도곡', '인덕원', '군자'],
#        ['대방', '당산', '대치', '평촌', '아차산'],
#        ['신길', '합정', '학여울', '범계', '광나루'],
#        ['영등포', '홍대입구', '대청', '금정', '천호'],
#        ['신도림', '신촌', '일원', '산본', '강동'],
#        ['구로', '이대', '수서', '수리산', '길동'],
#        ['구일', '아현', '가락시장', '대야미반월', '굽은다리'],
#        ['개봉', '충정로', '경찰병원', '상록수', '명일'],
#        ['오류동', '시청', '오금', '한대앞', '고덕'],
#        ['온수', nan, nan, '중앙', '상일동'],
#        ['역곡', nan, nan, '고잔', '둔촌동'],
#        ['소사', nan, nan, '공단', '올림픽공원'],
#        ['부천', nan, nan, '안산', '방이'],
#        ['중동', nan, nan, '신길온천', '오금'],
#        ['송내', nan, nan, '정왕', '개롱'],
#        ['부개', nan, nan, '오이도', '거여'],
#        ['부평', nan, nan, nan, '마천'],
#        ['백운', nan, nan, nan, nan],
#        ['동암', nan, nan, nan, nan],
#        ['간석', nan, nan, nan, nan],
#        ['주안', nan, nan, nan, nan],
#        ['도화', nan, nan, nan, nan],
#        ['제물포', nan, nan, nan, nan],
#        ['도원', nan, nan, nan, nan],
#        ['동인천', nan, nan, nan, nan],
#        ['인천', nan, nan, nan, nan],
#        ['광명', nan, nan, nan, nan],
#        ['가산디지털단지', nan, nan, nan, nan],
#        ['독산', nan, nan, nan, nan],
#        ['금천구청', nan, nan, nan, nan],
#        ['석수', nan, nan, nan, nan],
#        ['관악', nan, nan, nan, nan],
#        ['안양', nan, nan, nan, nan],
#        ['명학', nan, nan, nan, nan],
#        ['금정', nan, nan, nan, nan],
#        ['군포', nan, nan, nan, nan],
#        ['당정', nan, nan, nan, nan],
#        ['의왕', nan, nan, nan, nan],
#        ['성균관대', nan, nan, nan, nan],
#        ['화서', nan, nan, nan, nan],
#        ['수원', nan, nan, nan, nan],
#        ['세류', nan, nan, nan, nan],
#        ['병점', nan, nan, nan, nan],
#        ['세마', nan, nan, nan, nan],
#        ['오산대', nan, nan, nan, nan],
#        ['진위', nan, nan, nan, nan],
#        ['송탄', nan, nan, nan, nan],
#        ['서정리', nan, nan, nan, nan],
#        ['지제', nan, nan, nan, nan],
#        ['평택', nan, nan, nan, nan],
#        ['성환', nan, nan, nan, nan],
#        ['직산', nan, nan, nan, nan],
#        ['두정', nan, nan, nan, nan],
#        ['천안', nan, nan, nan, nan],
#        ['봉명', nan, nan, nan, nan],
#        ['쌍용', nan, nan, nan, nan],
#        ['아산', nan, nan, nan, nan],
#        ['배방', nan, nan, nan, nan],
#        ['온양온천', nan, nan, nan, nan],
#        ['신창', nan, nan, nan, nan],
#        ['서동탄', nan, nan, nan, nan]], dtype=object)

# %%
# 데이터 개수 확인
len(sb_list)
# Out:
# 95

# %%
# 환승역 확인
for k in range(0, 5):
    for u in range(k+1, 5):
        for i in range(len(sb_list)):
            for j in range(len(sb_list)):
                if sb_list[i][k] == sb_list[j][u]:
                    print("ㅡㅡㅡ환승역 :", sb_list[i][k], "ㅡㅡㅡ")
                    print(k+1, "호선 <->", u+1, "호선" )
                    print("행1, 행2, 호선1, 호선2 :", i+1, j+1, k+1, u+1)
# Out:
# ㅡㅡㅡ환승역 : 시청 ㅡㅡㅡ
# 1 호선 <-> 2 호선
# 행1, 행2, 호선1, 호선2 : 31 1 1 2
# ㅡㅡㅡ환승역 : 시청 ㅡㅡㅡ
# 1 호선 <-> 2 호선
# 행1, 행2, 호선1, 호선2 : 31 43 1 2
# ㅡㅡㅡ환승역 : 신도림 ㅡㅡㅡ
# 1 호선 <-> 2 호선
# 행1, 행2, 호선1, 호선2 : 39 33 1 2
# ㅡㅡㅡ환승역 : 종로3가 ㅡㅡㅡ
# 1 호선 <-> 3 호선
# 행1, 행2, 호선1, 호선2 : 29 20 1 3
# ㅡㅡㅡ환승역 : 창동 ㅡㅡㅡ
# 1 호선 <-> 4 호선
# 행1, 행2, 호선1, 호선2 : 16 7 1 4
# ㅡㅡㅡ환승역 : 동대문 ㅡㅡㅡ
# 1 호선 <-> 4 호선
# 행1, 행2, 호선1, 호선2 : 27 16 1 4
# ㅡㅡㅡ환승역 : 서울역 ㅡㅡㅡ
# 1 호선 <-> 4 호선
# 행1, 행2, 호선1, 호선2 : 32 21 1 4
# ㅡㅡㅡ환승역 : 금정 ㅡㅡㅡ
# 1 호선 <-> 4 호선
# 행1, 행2, 호선1, 호선2 : 69 38 1 4
# ㅡㅡㅡ환승역 : 종로3가 ㅡㅡㅡ
# 1 호선 <-> 5 호선
# 행1, 행2, 호선1, 호선2 : 29 25 1 5
# ㅡㅡㅡ환승역 : 신길 ㅡㅡㅡ
# 1 호선 <-> 5 호선
# 행1, 행2, 호선1, 호선2 : 37 16 1 5
# ㅡㅡㅡ환승역 : 을지로3가 ㅡㅡㅡ
# 2 호선 <-> 3 호선
# 행1, 행2, 호선1, 호선2 : 3 21 2 3
# ㅡㅡㅡ환승역 : 교대 ㅡㅡㅡ
# 2 호선 <-> 3 호선
# 행1, 행2, 호선1, 호선2 : 22 31 2 3
# ㅡㅡㅡ환승역 : 동대문역사문화공원 ㅡㅡㅡ
# 2 호선 <-> 4 호선
# 행1, 행2, 호선1, 호선2 : 5 17 2 4
# ㅡㅡㅡ환승역 : 사당 ㅡㅡㅡ
# 2 호선 <-> 4 호선
# 행1, 행2, 호선1, 호선2 : 25 28 2 4
# ㅡㅡㅡ환승역 : 을지로4가 ㅡㅡㅡ
# 2 호선 <-> 5 호선
# 행1, 행2, 호선1, 호선2 : 4 26 2 5
# ㅡㅡㅡ환승역 : 동대문역사문화공원 ㅡㅡㅡ
# 2 호선 <-> 5 호선
# 행1, 행2, 호선1, 호선2 : 5 27 2 5
# ㅡㅡㅡ환승역 : 왕십리 ㅡㅡㅡ
# 2 호선 <-> 5 호선
# 행1, 행2, 호선1, 호선2 : 8 31 2 5
# ㅡㅡㅡ환승역 : 영등포구청 ㅡㅡㅡ
# 2 호선 <-> 5 호선
# 행1, 행2, 호선1, 호선2 : 35 14 2 5
# ㅡㅡㅡ환승역 : 충정로 ㅡㅡㅡ
# 2 호선 <-> 5 호선
# 행1, 행2, 호선1, 호선2 : 42 22 2 5
# ㅡㅡㅡ환승역 : 충무로 ㅡㅡㅡ
# 3 호선 <-> 4 호선
# 행1, 행2, 호선1, 호선2 : 22 18 3 4
# ㅡㅡㅡ환승역 : 종로3가 ㅡㅡㅡ
# 3 호선 <-> 5 호선
# 행1, 행2, 호선1, 호선2 : 20 25 3 5
# ㅡㅡㅡ환승역 : 오금 ㅡㅡㅡ
# 3 호선 <-> 5 호선
# 행1, 행2, 호선1, 호선2 : 43 48 3 5
# ㅡㅡㅡ환승역 : 동대문역사문화공원 ㅡㅡㅡ
# 4 호선 <-> 5 호선
# 행1, 행2, 호선1, 호선2 : 17 27 4 5

# %%
# 1호선 확인
for i in range(len(sb_list)):
    print(sb_list[i][0])
# Out:
# 소요산
# 동두천
# 보산
# 동두천중앙
# 지행
# 덕정
# 덕계
# 양주
# 녹양
# 가능
# 의정부
# 회룡
# 망월사
# 도봉산
# 방학
# 창동
# 녹천
# 월계
# 성북
# 신이문
# 외대앞
# 회기
# 청량리
# 제기동
# 신설동
# 동묘앞
# 동대문
# 종로5가
# 종로3가
# 종각
# 시청
# 서울역
# 남영
# 용산
# 노량진
# 대방
# 신길
# 영등포
# 신도림
# 구로
# 구일
# 개봉
# 오류동
# 온수
# 역곡
# 소사
# 부천
# 중동
# 송내
# 부개
# 부평
# 백운
# 동암
# 간석
# 주안
# 도화
# 제물포
# 도원
# 동인천
# 인천
# 광명
# 가산디지털단지
# 독산
# 금천구청
# 석수
# 관악
# 안양
# 명학
# 금정
# 군포
# 당정
# 의왕
# 성균관대
# 화서
# 수원
# 세류
# 병점
# 세마
# 오산대
# 진위
# 송탄
# 서정리
# 지제
# 평택
# 성환
# 직산
# 두정
# 천안
# 봉명
# 쌍용
# 아산
# 배방
# 온양온천
# 신창
# 서동탄

# %% [markdown]
# ## 테스트

# %%
pd.isna(sb_list[1][1])
# Out:
# False

# %%
sb_list[1][1]
# Out:
# '을지로입구'

# %%
graph = {"0":{"00":2}}

# %%
graph
# Out:
# {'0': {'00': 2}}

# %%
graph.get("0")
# Out:
# {'00': 2}

# %%
graph["1"] = {"11":2, "12":2, "13":2}

# %%
graph
# Out:
# {'0': {'00': 2}, '1': {'11': 2, '12': 2, '13': 2}}

# %%
graph.keys()
# Out:
# dict_keys(['0', '1'])

# %%
graph.values()
# Out:
# dict_values([{'00': 2}, {'11': 2, '12': 2, '13': 2}])

# %%
for i in graph.keys():
    print(i)
for i in graph.values():
    print(i)
# Out:
# 0
# 1
# {'00': 2}
# {'11': 2, '12': 2, '13': 2}

# %%
len(graph["0"])
# Out:
# 1

# %%
[i for i in graph["0"].values()]
# Out:
# [2]

# %%
keys = [i for i in graph["1"].keys()]
print(keys)
values = [i for i in graph["1"].values()]
print(values)
dic = {}
for i in range(len(keys)):
    dic[keys[i]] = values[i]
dic['14'] = 2
graph["2"] = dic
# Out:
# ['11', '12', '13']
# [2, 2, 2]

# %%
graph
# Out:
# {'0': {'00': 2},
#  '1': {'11': 2, '12': 2, '13': 2},
#  '2': {'11': 2, '12': 2, '13': 2, '14': 2}}

# %% [markdown]
# ## 2) 단방향 Graph 전처리

# %%
graph = {}

# print(graph) # 확인용 코드

for i in range(5):
    # print(i) # 확인용 코드
    for j in range(len(sb_list)):
        # print(j) # 확인용 코드
        if(j < len(sb_list)-1 and not pd.isna(sb_list[j+1][i]) and not pd.isna(sb_list[j][i])):
            if sb_list[j][i] in graph:
                # print(sb_list[j][i]) # 확인용 코드
                keys = [k for k in graph[sb_list[j][i]].keys()]
                # print(key) # 확인용 코드
                values = [v for v in graph[sb_list[j][i]].values()]
                # print(values) # 확인용 코드
                dic = {}
                for d in range(len(keys)):
                    dic[keys[d]] = values[d]
                dic[sb_list[j+1][i]] = 2
                graph[sb_list[j][i]] = dic
                # graph[sb_list[j][i]] = {graph.get(sb_list[j][i]), sb_list[j+1][i]:2}
# %%
# 그래프 : 본인 노드 이름 : {연결된 노드 이름 : 연결된 노드까지의 거리}
# distances : 시작 노드에서 특정 노드까지 거리 저장 dic
# start : 시작 노드
# heap : 다음 특정 노드 저장
# distance : 특정 노드까지 최소 거리
# current distance : 특정 노드까지 거리
# current destination : 특정 노드 노드명

import heapq  # 우선순위 큐 구현을 위함

def dijkstra(graph, start):
    # 초기값
    distances = {node: float('inf') for node in graph} # [시작 노드에서 특정 노드까지 거리] : 무한대
    distances[start] = 0 # [시작 노드에서 시작 노드까지 거리] : 0
    # print(distances) # 확인용 코드
    queue = [] # [정보 저장 heap] 생성
    heapq.heappush(queue, [distances[start], start])  # [[시작 노드에서 시작 노드까지 거리], [시작 노드명]]를 [정보 저장 heap]에 저장
    # print(distances[start], start) # 확인용 코드

    # graph 생성
    while queue:  # heap에서 노드가 빌 때까지 반복
        current_distance, current_destination = heapq.heappop(queue) # [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] 빼기
        # print(current_distance, current_destination)
        if distances[current_destination] < current_distance: # 가장 작은 [시작 노드에서 특정 노드까지 거리]가 [기존 시작 노드에서 특정 노드까지 거리]보다 크면 건너띔
            print(distances[current_destination], current_distance) # 확인용 코드
            continue

        for new_destination, new_distance in graph[current_destination].items(): # [특정 노드]에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]] 전부 돌기
            distance = current_distance + new_distance # [시작 노드에서 다음 특정 노드까지의 새로운 거리] = [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] + 특정 노드명에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]
            if distance < distances[new_destination]: # [시작 노드에서 다음 특정 노드까지 거리] > [시작 노드에서 다음 특정 노드까지의 새로운 거리]라면
                # 거리 최신화
                distances[new_destination] = distance # [시작 노드에서 다음 특정 노드까지 거리] 최신화
                heapq.heappush(queue, [distance, new_destination]) # [[시작 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]을 [정보 저장 heap]에 저장

    return distances

print(dijkstra(graph, '소요산'))
# Out:
# {'소요산': 0, '동두천': 2, '보산': 4, '동두천중앙': 6, '지행': 8, '덕정': 10, '덕계': 12, '양주': 14, '녹양': 16, '가능': 18, '의정부': 20, '회룡': 22, '망월사': 24, '도봉산': 26, '방학': 28, '창동': 30, '녹천': 32, '월계': 34, '성북': 36, '신이문': 38, '외대앞': 40, '회기': 42, '청량리': 44, '제기동': 46, '신설동': 48, '동묘앞': 50, '동대문': 48, '종로5가': 50, '종로3가': 52, '종각': 54, '시청': 56, '서울역': 58, '남영': 60, '용산': 62, '노량진': 64, '대방': 66, '신길': 68, '영등포': 70, '신도림': 72, '구로': 74, '구일': 76, '개봉': 78, '오류동': 80, '온수': 82, '역곡': 84, '소사': 86, '부천': 88, '중동': 90, '송내': 92, '부개': 94, '부평': 96, '백운': 98, '동암': 100, '간석': 102, '주안': 104, '도화': 106, '제물포': 108, '도원': 110, '동인천': 112, '인천': 114, '광명': 116, '가산디지털단지': 118, '독산': 120, '금천구청': 122, '석수': 124, '관악': 126, '안양': 128, '명학': 130, '금정': 92, '군포': 94, '당정': 96, '의왕': 98, '성균관대': 100, '화서': 102, '수원': 104, '세류': 106, '병점': 108, '세마': 110, '오산대': 112, '진위': 114, '송탄': 116, '서정리': 118, '지제': 120, '평택': 122, '성환': 124, '직산': 126, '두정': 128, '천안': 130, '봉명': 132, '쌍용': 134, '아산': 136, '배방': 138, '온양온천': 140, '신창': 142, '서동탄': 144, '을지로입구': 58, '을지로3가': 54, '을지로4가': 54, '동대문역사문화공원': 50, '신당': 52, '상왕십리': 54, '왕십리': 56, '한양대': 58, '뚝섬': 60, '성수': 62, '건대입구': 64, '구의': 66, '강변': 68, '잠실나루': 70, '신천': 72, '종합운동장': 74, '삼성': 76, '선릉': 78, '역삼': 80, '강남': 82, '교대': 70, '서초': 72, '방배': 74, '사당': 72, '낙성대': 74, '서울대입구': 76, '봉천': 78, '신림': 80, '신대방': 82, '구로디지털단지': 84, '대림': 86, '문래': 74, '영등포구청': 76, '당산': 78, '합정': 80, '홍대입구': 82, '신촌': 84, '이대': 86, '아현': 88, '충정로': 80, nan: inf, '대화': inf, '주엽': inf, '정발산': inf, '마두': inf, '백석': inf, '대곡': inf, '화정': inf, '원당': inf, '삼송': inf, '지축': inf, '구파발': inf, '연신내': inf, '붕광': inf, '녹번': inf, '홍제': inf, '무악재': inf, '독립문': inf, '경북궁': inf, '안국': inf, '충무로': 52, '동대입구': 54, '약수': 56, '금호': 58, '옥수': 60, '압구정': 62, '신사': 64, '잠원': 66, '고속터미널': 68, '남부터미널': 72, '양재': 74, '매봉': 76, '도곡': 78, '대치': 80, '학여울': 82, '대청': 84, '일원': 86, '수서': 88, '가락시장': 90, '경찰병원': 92, '오금': 90, '진접': inf, '오남': inf, '별내별가람': inf, '당고개': inf, '상계': inf, '노원': inf, '쌍문': 32, '수유': 34, '미아': 36, '미아삼거리': 38, '길음': 40, '성신여대입구': 42, '한성대입구': 44, '혜화': 46, '명동': 54, '회현': 56, '숙대입구': 60, '삼각지': 62, '신용산': 64, '이촌': 66, '동작': 68, '이수': 70, '남태령': 74, '선바위': 76, '경마공원': 78, '대공원': 80, '과천': 82, '정부과천청사': 84, '인덕원': 86, '평촌': 88, '범계': 90, '산본': 94, '수리산': 96, '대야미반월': 98, '상록수': 100, '한대앞': 102, '중앙': 104, '고잔': 106, '공단': 108, '안산': 110, '신길온천': 112, '정왕': 114, '오이도': 116, '방화': inf, '개화산': inf, '김포공항': inf, '송정': inf, '마곡': inf, '발산': inf, '우장산': inf, '화곡': inf, '까치산': inf, '신정': inf, '목동': inf, '오목교': inf, '양평': inf, '영등포시장': 78, '여의도': 70, '여의나루': 72, '마포': 74, '공덕': 76, '애오개': 78, '서대문': 82, '광화문': 84, '청구': 52, '신금호': 54, '행당': 56, '마장': 58, '답십리': 60, '장한평': 62, '군자': 64, '아차산': 66, '광나루': 68, '천호': 70, '강동': 72, '길동': 74, '굽은다리': 76, '명일': 78, '고덕': 80, '상일동': 82, '둔촌동': 84, '올림픽공원': 86, '방이': 88, '개롱': 92, '거여': 94, '마천': 96}

# %% [markdown]
# ## 3) 양방향 Graph 전처리(nan 존재o+호선 구별x + 중복 호선 환승 고려x)

# %%
graph = {}

# print(graph) # 확인용 코드

# 모든 역에 대해서 전처리
for i in range(5):
    # print(i) # 확인용 코드
    for j in range(len(sb_list)):
        # print(j) # 확인용 코드
        
        # graph 생성 - graph 마지막 원소 전이고, 비어있지 않은 역인 경우
        if(j < len(sb_list)-1 and not pd.isna(sb_list[j+1][i]) and not pd.isna(sb_list[j][i])):
            # graph에 해당 역 존재 : 해당 역의 key, value 빼서 다시 전처리 + 다음 역 추가시킨 graph 생성
            if sb_list[j][i] in graph:
                # print(sb_list[j][i]) # 확인용 코드
                keys = [k for k in graph[sb_list[j][i]].keys()]
                # print(key) # 확인용 코드
                values = [v for v in graph[sb_list[j][i]].values()]
                # print(values) # 확인용 코드
                dic = {}
                for d in range(len(keys)):
                    dic[keys[d]] = values[d]
                dic[sb_list[j+1][i]] = 2
                graph[sb_list[j][i]] = dic
                # graph[sb_list[j][i]] = {graph.get(sb_list[j][i]), sb_list[j+1][i]:2}
                
            # graph에 해당 역 존재하지 않음 : 다음 역 추가시킨 graph 생성
            else:
                graph[sb_list[j][i]] = {sb_list[j+1][i]:2}
        # graph 생성 - graph 마지막 원소이거나, 비어있는 역인 경우
        else:
            # graph에 해당 역 존재 : 건너뛰기
            if sb_list[j][i] in graph:
                pass
            # graph에 해당 역 존재하지 않음 : 빈 원소로 두기
            else:
                graph[sb_list[j][i]] = {}

        # graph 생성 - graph 첫 번째 원소 이후이고, 비어있지 않은 역인 경우
        if(0 < j and not pd.isna(sb_list[j-1][i]) and not pd.isna(sb_list[j][i])):
            # graph에 해당 역 존재 : 해당 역의 key, value 빼서 다시 전처리 + 다음 역 추가시킨 graph 생성
            if sb_list[j][i] in graph:
                # print(sb_list[j][i]) # 확인용 코드
                keys = [k for k in graph[sb_list[j][i]].keys()]
                # print(key) # 확인용 코드
                values = [v for v in graph[sb_list[j][i]].values()]
                # print(values) # 확인용 코드
                dic = {}
                for d in range(len(keys)):
                    dic[keys[d]] = values[d]
                dic[sb_list[j-1][i]] = 2
                graph[sb_list[j][i]] = dic
                # graph[sb_list[j][i]] = {graph.get(sb_list[j][i]), sb_list[j+1][i]:2}
                '''if(sb_list[j][i] == '시청'): # 확인용 코드
                    print(keys)
                    print(graph[sb_list[j][i]])'''
            # graph에 해당 역 존재하지 않음 : 다음 역 추가시킨 graph 생성
            else:
                graph[sb_list[j][i]] = {sb_list[j-1][i]:2}
        # graph 생성 - graph 첫번째 원소이거나, 비어있는 역인 경우 : 불가능한 경우
        else:
            pass
        
print(graph)
# Out:
# {'소요산': {'동두천': 2}, '동두천': {'보산': 2, '소요산': 2}, '보산': {'동두천중앙': 2, '동두천': 2}, '동두천중앙': {'지행': 2, '보산': 2}, '지행': {'덕정': 2, '동두천중앙': 2}, '덕정': {'덕계': 2, '지행': 2}, '덕계': {'양주': 2, '덕정': 2}, '양주': {'녹양': 2, '덕계': 2}, '녹양': {'가능': 2, '양주': 2}, '가능': {'의정부': 2, '녹양': 2}, '의정부': {'회룡': 2, '가능': 2}, '회룡': {'망월사': 2, '의정부': 2}, '망월사': {'도봉산': 2, '회룡': 2}, '도봉산': {'방학': 2, '망월사': 2}, '방학': {'창동': 2, '도봉산': 2}, '창동': {'녹천': 2, '방학': 2, '쌍문': 2, '노원': 2}, '녹천': {'월계': 2, '창동': 2}, '월계': {'성북': 2, '녹천': 2}, '성북': {'신이문': 2, '월계': 2}, '신이문': {'외대앞': 2, '성북': 2}, '외대앞': {'회기': 2, '신이문': 2}, '회기': {'청량리': 2, '외대앞': 2}, '청량리': {'제기동': 2, '회기': 2}, '제기동': {'신설동': 2, '청량리': 2}, '신설동': {'동묘앞': 2, '제기동': 2}, '동묘앞': {'동대문': 2, '신설동': 2}, '동대문': {'종로5가': 2, '동묘앞': 2, '동대문역사문화공원': 2, '혜화': 2}, '종로5가': {'종로3가': 2, '동대문': 2}, '종로3가': {'종각': 2, '종로5가': 2, '을지로3가': 2, '안국': 2, '을지로4가': 2, '광화문': 2}, '종각': {'시청': 2, '종로3가': 2}, '시청': {'서울역': 2, '종각': 2, '을지로입구': 2, '충정로': 2}, '서울역': {'남영': 2, '시청': 2, '숙대입구': 2, '회현': 2}, '남영': {'용산': 2, '서울역': 2}, '용산': {'노량진': 2, '남영': 2}, '노량진': {'대방': 2, '용산': 2}, '대방': {'신길': 2, '노량진': 2}, '신길': {'영등포': 2, '대방': 2, '여의도': 2, '영등포시장': 2}, '영등포': {'신도림': 2, '신길': 2}, '신도림': {'구로': 2,
섬': {'성수': 2, '한양대': 2}, '성수': {'건대입구': 2, '뚝섬': 2}, '건대입구': {'구의': 2, '성수': 2}, '구의': {'강변': 2, '건대입구': 2}, '강변': {'잠실나루': 2, '구의': 2}, '잠실나루': {'신천': 2, '강변': 2}, '신천': {'종합운동장': 2, '잠실나루': 2}, '종합운동장': {'삼성': 2, '신천': 2}, '삼성': {'선릉': 2, '종합운동장': 2}, '선릉': {'역삼': 2, '삼성': 2}, '역삼': {'강남': 2, '선릉': 2}, '강남': {'교대': 2, '역삼': 2}, '교대': {'서초': 2, '강남': 2, '남부터미널': 2, '고속터미널': 2}, '서초': {'방배': 2, '교대': 2}, '방배': {'사당': 2, '서초': 2}, '사당': {'낙성대': 2, '방배': 2, '남태령': 2, '이수': 2}, '낙성대': {'서울대입구': 2, '사당': 2}, '서울대입구': {'봉천': 2, '낙성대': 2}, '봉천': {'신림': 2, '서울대입구': 2}, '신림': {'신대방': 2, '봉천': 2}, '신대방': {'구로디지털단지': 2, '신림': 2}, '구로디지털단지': {'대림': 2, '신대방': 2}, '대림': {'신도림': 2, '구로디지털단지': 2}, '문래': {'영등포구청': 2, '신도림': 2}, '영등포구청': {'당산': 2, '문래': 2, '영등포시장': 2, '양평': 2}, '당산': {'합정': 2, '영등포구청': 2}, '합정': {'홍대입구': 2, '당산': 2}, '홍대입구': {'신촌': 2, '합정': 2}, '신촌': {'이대': 2, '홍대입구': 2}, '이대': {'아현':  ...

# %% [markdown]
# ## 3) 양방향 Graph 거리 계산(nan 존재o+호선 구별x + 중복 호선 환승 고려x)

# %%
# 그래프 : 본인 노드 이름 : {연결된 노드 이름 : 연결된 노드까지의 거리}
# distances : 시작 노드에서 특정 노드까지 거리 저장 dic
# start : 시작 노드
# heap : 다음 특정 노드 저장
# distance : 특정 노드까지 최소 거리
# current distance : 특정 노드까지 거리
# current destination : 특정 노드 노드명

import heapq  # 우선순위 큐 구현을 위함

def dijkstra(graph, start):
    # 거리 초기 설정
    distances = {node: float('inf') for node in graph} # [시작 노드에서 특정 노드까지 거리] : 무한대
    distances[start] = 0 # [시작 노드에서 시작 노드까지 거리] : 0
    # print(distances) # 확인용 코드
    queue = [] # [정보 저장 heap] 생성
    heapq.heappush(queue, [distances[start], start])  # [[시작 노드에서 시작 노드까지 거리], [시작 노드명]]를 [정보 저장 heap]에 저장
    # print(distances[start], start) # 확인용 코드

    # graph 생성
    while queue:  # heap에서 노드가 빌 때까지 반복
        current_distance, current_destination = heapq.heappop(queue) # [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] 빼기
        # print(current_distance, current_destination)
        if distances[current_destination] < current_distance: # [정보 저장 heap]에서 가장 작은 [시작 노드에서 특정 노드까지 거리] > [기존 시작 노드에서 특정 노드까지 거리]이면 건너띔
            print(distances[current_destination], current_distance) # 확인용 코드
            continue

        for new_destination, new_distance in graph[current_destination].items(): # [특정 노드]에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]] 전부 돌기
            distance = current_distance + new_distance # [시작 노드에서 다음 특정 노드까지의 새로운 거리] = [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] + 특정 노드명에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]
            if distance < distances[new_destination]: # [시작 노드에서 다음 특정 노드까지 거리] > [시작 노드에서 다음 특정 노드까지의 새로운 거리]라면
                # 거리 최신화
                distances[new_destination] = distance # [시작 노드에서 다음 특정 노드까지 거리] 최신화
                heapq.heappush(queue, [distance, new_destination]) # [[시작 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]을 [정보 저장 heap]에 저장

    return distances

print(dijkstra(graph, '시청'))
# Out:
# {'소요산': 56, '동두천': 54, '보산': 52, '동두천중앙': 50, '지행': 48, '덕정': 46, '덕계': 44, '양주': 42, '녹양': 40, '가능': 38, '의정부': 36, '회룡': 34, '망월사': 32, '도봉산': 30, '방학': 28, '창동': 26, '녹천': 28, '월계': 26, '성북': 24, '신이문': 22, '외대앞': 20, '회기': 18, '청량리': 16, '제기동': 14, '신설동': 12, '동묘앞': 10, '동대문': 8, '종로5가': 6, '종로3가': 4, '종각': 2, '시청': 0, '서울역': 2, '남영': 4, '용산': 6, '노량진': 8, '대방': 10, '신길': 12, '영등포': 14, '신도림': 16, '구로': 18, '구일': 20, '개봉': 22, '오류동': 24, '온수': 26, '역곡': 28, '소사': 30, '부천': 32, '중동': 34, '송내':
# %% [markdown]
# ## 4) 양방향 Graph 전처리(nan 존재x+호선 구별x + 중복 호선 환승 고려x)

# %%
graph = {}

# print(graph) # 확인용 코드

# 모든 역에 대해서 전처리
for i in range(5):
    # print(i) # 확인용 코드
    for j in range(len(sb_list)):
        # print(j) # 확인용 코드
        
        # graph 생성 - graph 마지막 원소 전이고, 비어있지 않은 역인 경우
        if(j < len(sb_list)-1 and not pd.isna(sb_list[j+1][i]) and not pd.isna(sb_list[j][i])):
            # graph에 해당 역 존재 : 해당 역의 key, value 빼서 다시 전처리 + 다음 역 추가시킨 graph 생성
            if sb_list[j][i] in graph:
                # print(sb_list[j][i]) # 확인용 코드
                keys = [k for k in graph[sb_list[j][i]].keys()]
                # print(key) # 확인용 코드
                values = [v for v in graph[sb_list[j][i]].values()]
                # print(values) # 확인용 코드
                dic = {}
                for d in range(len(keys)):
                    dic[keys[d]] = values[d]
                dic[sb_list[j+1][i]] = 2
                graph[sb_list[j][i]] = dic
                # graph[sb_list[j][i]] = {graph.get(sb_list[j][i]), sb_list[j+1][i]:2}
                
            # graph에 해당 역 존재하지 않음 : 다음 역 추가시킨 graph 생성
            else:
                graph[sb_list[j][i]] = {sb_list[j+1][i]:2}
        # graph 생성 - 비어있는 역인 경우 : 건너뛰기
        elif(pd.isna(sb_list[j][i]) == True):
            pass
        # graph 생성 - 비어있는 역 아닌 경우
        else:
            # graph에 해당 역 존재 : 건너뛰기
            if sb_list[j][i] in graph:
                pass
            # graph에 해당 역 존재하지 않음 : 빈 원소로 두기
            else:
                graph[sb_list[j][i]] = {}
                print(sb_list[j][i]) # 확인용 코드

        # graph 생성 - graph 첫 번째 원소 이후이고, 비어있지 않은 역인 경우
        if(0 < j and not pd.isna(sb_list[j-1][i]) and not pd.isna(sb_list[j][i])):
            # graph에 해당 역 존재 : 해당 역의 key, value 빼서 다시 전처리 + 다음 역 추가시킨 graph 생성
            if sb_list[j][i] in graph:
                # print(sb_list[j][i]) # 확인용 코드
                keys = [k for k in graph[sb_list[j][i]].keys()]
                # print(key) # 확인용 코드
                values = [v for v in graph[sb_list[j][i]].values()]
                # print(values) # 확인용 코드
                dic = {}
                for d in range(len(keys)):
                    dic[keys[d]] = values[d]
                dic[sb_list[j-1][i]] = 2
                graph[sb_list[j][i]] = dic
                # graph[sb_list[j][i]] = {graph.get(sb_list[j][i]), sb_list[j+1][i]:2}
                '''if(sb_list[j][i] == '시청'): # 확인용 코드
                    print(keys)
                    print(graph[sb_list[j][i]])'''
            # graph에 해당 역 존재하지 않음 : 다음 역 추가시킨 graph 생성
            else:
                graph[sb_list[j][i]] = {sb_list[j-1][i]:2}
        # graph 생성 - graph 첫번째 원소이거나, 비어있는 역인 경우 : 불가능한 경우
        else:
            pass
        
print(graph)
# Out:
# 서동탄
# 오금
# 오이도
# 마천
# {'소요산': {'동두천': 2}, '동두천': {'보산': 2, '소요산': 2}, '보산': {'동두천중앙': 2, '동두천': 2}, '동두천중앙': {'지행': 2, '보산': 2}, '지행': {'덕정': 2, '동두천중앙': 2}, '덕정': {'덕계': 2, '지행': 2}, '덕계': {'양주': 2, '덕정': 2}, '양주': {'녹양': 2, '덕계': 2}, '녹양': {'가능': 2, '양주': 2}, '가능': {'의정부': 2, '녹양': 2}, '의정부': {'회룡': 2, '가능': 2}, '회룡': {'망월사': 2, '의정부': 2}, '망월사': {'도봉산': 2, '회룡': 2}, '도봉산': {'방학': 2


# %%
# 그래프 : 본인 노드 이름 : {연결된 노드 이름 : 연결된 노드까지의 거리}
# distances : 시작 노드에서 특정 노드까지 거리 저장 dic
# start : 시작 노드
# heap : 다음 특정 노드 저장
# distance : 특정 노드까지 최소 거리
# current distance : 특정 노드까지 거리
# current destination : 특정 노드 노드명

import heapq  # 우선순위 큐 구현을 위함

def dijkstra(graph, start):
    # 거리 초기 설정
    distances = {node: float('inf') for node in graph} # [시작 노드에서 특정 노드까지 거리] : 무한대
    distances[start] = 0 # [시작 노드에서 시작 노드까지 거리] : 0
    # print(distances) # 확인용 코드
    queue = [] # [정보 저장 heap] 생성
    heapq.heappush(queue, [distances[start], start])  # [[시작 노드에서 시작 노드까지 거리], [시작 노드명]]를 [정보 저장 heap]에 저장
    # print(distances[start], start) # 확인용 코드

    # graph 생성
    while queue:  # heap에서 노드가 빌 때까지 반복
        current_distance, current_destination = heapq.heappop(queue) # [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] 빼기
        # print(current_distance, current_destination)
        if distances[current_destination] < current_distance: # [정보 저장 heap]에서 가장 작은 [시작 노드에서 특정 노드까지 거리] > [기존 시작 노드에서 특정 노드까지 거리]이면 건너띔
            print(distances[current_destination], current_distance) # 확인용 코드
            continue

        for new_destination, new_distance in graph[current_destination].items(): # [특정 노드]에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]] 전부 돌기
            distance = current_distance + new_distance # [시작 노드에서 다음 특정 노드까지의 새로운 거리] = [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] + 특정 노드명에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]
            if distance < distances[new_destination]: # [시작 노드에서 다음 특정 노드까지 거리] > [시작 노드에서 다음 특정 노드까지의 새로운 거리]라면
                # 거리 최신화
                distances[new_destination] = distance # [시작 노드에서 다음 특정 노드까지 거리] 최신화
                heapq.heappush(queue, [distance, new_destination]) # [[시작 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]을 [정보 저장 heap]에 저장

    return distances

print(dijkstra(graph, '시청'))
# Out:
# {'소요산': 56, '동두천': 54, '보산': 52, '동두천중앙': 50, '지행': 48, '덕정': 46, '덕계': 44, '양주': 42, '녹양': 40, '가능': 38, '의정부': 36, '회룡': 34, '망월사': 32, '도봉산': 30, '방학': 28, '창동': 26, '녹천': 28, '월계': 26, '성북': 24, '신이문': 22, '외대앞': 20, '회기': 18, '청량리': 16, '제기동': 14, '신설동': 12, '동묘앞': 10, '동대문': 8, '종로5가': 6, '종로3가': 4, '종각': 2, '시청': 0, '서울역': 2, '남영': 4, '용산': 6, '노량진': 8, '대방': 10, '신길': 12, '영등포': 14, '신도림': 16, '구로': 18, '구일': 20, '개봉': 22, '오류동': 24, '온수': 26, '역곡': 28, '소사': 30, '부천': 32, '중동': 34, '송내': 36, '부개': 38, '부평': 40, '백운': 42, '동암': 44, '간석': 46, '주안': 48, '도화': 50, '제물포': 52, '도원': 54, '동인천': 56, '인천': 54, '광명': 52, '가산디지털단지': 50, '독산': 48, '금천구청': 46, '석수': 44, '관악': 42, '안양': 40, '명학': 38, '금정': 36, '군포': 38, '당정': 40, '의왕': 42, '성균관대': 44, '화서': 46, '수원': 48, '세류': 50, '병점': 52, '세마': 54, '오산대': 56, '진위': 58, '송탄': 60, '서정리': 62, '지제': 64, '평택': 66, '성환': 68, '직산': 70, '두정': 72, '천안': 74, '봉명': 76, '쌍용': 78, '아산': 80, '배방': 82, '온양온천': 84, '신창': 86, '서동탄': 88, '을지로입구': 2, '을지로3가': 4, '을지로4가': 6, '동대문역사문화공원': 8, '신당': 10, '상왕십리': 12, '왕십리': 14, '한양대': 16, '뚝섬': 18, '성수': 20, '건대입구': 22, '구의': 24, '강변': 26, '잠실나루': 28, '신천': 30, '종합운동장': 32, '삼성': 30, '선릉': 28, '역삼': 26, '강남': 24, '교대': 22, '서초': 20, '방배': 18, '사당': 16, '낙성대': 18, '서울대입구': 20, '봉천': 22, '신림': 24, '신대방': 22, '구로디지털단지': 20, '대림': 18, '문래': 18, '영등포구청': 16, '당산': 14, '합정': 12, '홍대입구': 10, '신촌': 8, '이대': 6, '아현': 4, '충정로': 2, '대화': 42, '주엽': 40, '정발산': 38, '마두': 36, '백석': 34, '대곡': 32, '화정': 30, '원당': 28, '삼송': 26, '지축': 24, '구파발': 22, '연신내': 20, '붕광': 18, '녹번': 16, '홍제': 14, '무악재': 12, '독립문': 10, '경북궁': 8, '안국': 6, '충무로': 6, '동대입구': 8, '약수': 10, '금호': 12, '옥수': 14, '압구정': 16, '신사': 18, '잠원': 20, '고속터미널': 22, '남부터미널': 24, '양재': 26, '매봉': 28, '도곡': 30, '대치': 32, '학여울': 34, '대청': 36, '일원': 38, '수서': 40, '가락시장': 42, '경찰병원': 44, '오금': 46, '진접': 38, '오남': 36, '별내별가람': 34, '당고개': 32, '상계': 30, '노원': 28, '쌍문': 24, '수유': 22, '미아': 20, '미아삼거리': 18, '길음': 16, '성신여대입구': 14, '한성대입구': 12, '혜화': 10, '명동': 6, '회현': 4, '숙대입구': 4, '삼각지': 6, '신용산': 8, '이촌': 10, '동작': 12, '이수': 14, '남태령': 18, '선바위': 20, '경마공원': 22, '대공원': 24, '과천': 26, '정부과천청사': 28, '인덕원': 30, '평촌': 32, '범계': 34, '산본': 38, '수리산': 40, '대야미반월': 42, '상록수': 44, '한대앞': 46, '중앙': 48, '고잔': 50, '공단': 52, '안산': 54, '신길온천': 56, '정왕': 58, '오이도': 60, '방화': 42, '개화산': 40, '김포공항': 38, '송정': 36, '마곡': 34, '발산': 32, '우장산': 30, '화곡': 28, '까치산': 26, '신정': 24, '목동': 22, '오목교': 20, '양평': 18, '영등포시장': 14, '여의도': 12, '여의나루': 10, '마포': 8, '공덕': 6, '애오개': 4, '서대문': 4, '광화문': 6, '청구': 10, '신금호': 12, '행당': 14, '마장': 16, '답십리': 18, '장한평': 20, '군자': 22, '아차산': 24, '광나루': 26, '천호': 28, '강동': 30, '길동': 32, '굽은다리': 34, '명일': 36, '고덕': 38, '상일동': 40, '둔촌동': 42, '올림픽공원': 44, '방이': 46, '개롱': 48, '거여': 50, '마천': 52}

# %% [markdown]
# ## 테스트

# %%
print("sb_list[1][1] : ", sb_list[1][1])
print("sb_list[1][1] : ", sb_list[1][1] + str(0))
# Out:
# sb_list[1][1] :  을지로입구
# sb_list[1][1] :  을지로입구0

# %%
print(len(graph))
for i in graph:
    print(i)
    print(i[0:len(i)-1])
# Out:
# 261
# 소요산
# 소요
# 동두천
# 동두
# 보산
# 보
# 동두천중앙
# 동두천중
# 지행
# 지
# 덕정
# 덕
# 덕계
# 덕
# 양주
# 양
# 녹양
# 녹
# 가능
# 가
# 의정부
# 의정
# 회룡
# 회
# 망월사
# 망월
# 도봉산
# 도봉
# 방학
# 방
# 창동
# 창
# 녹천
# 녹
# 월계
# 월
# 성북
# 성
# 신이문
# 신이
# 외대앞
# 외대
# 회기
# 회
# 청량리
# 청량
# 제기동
# 제기
# 신설동
# 신설
# 동묘앞
# 동묘
# 동대문
# 동대
# 종로5가
# 종로5
# 종로3가
# 종로3
# 종각
# 종
# 시청
# 시
# 서울역
# 서울
# 남영
# 남
# 용산
# 용
# 노량진
# 노량
# 대방
# 대
# 신길
# 신
# 영등포
# 영등
# 신도림
# 신도
# 구로
# 구
# 구일
# 구
# 개봉
# 개
# 오류동
# 오류
# 온수
# 온
# 역곡
# 역
# 소사
# 소
# 부천
# 부
# 중동
# 중
# 송내
# 송
# 부개
# 부
# 부평
# 부
# 백운
# 백
# 동암
# 동
# 간석
# 간
# 주안
# 주
# 도화
# 도
# 제물포
# 제물
# 도원
# 도
# 동인천
# 동인
# 인천
# 인
# 광명
# 광
# 가산디지털단지
# 가산디지털단
# 독산
# 독
# 금천구청
# 금천구
# 석수
# 석
# 관악
# 관
# 안양
# 안
# 명학
# 명
# 금정
# 금
# 군포
# 군
# 당정
# 당
# 의왕
# 의
# 성균관대
# 성균관
# 화서
# 화
# 수원
# 수
# 세류
# 세
# 병점
# 병
# 세마
# 세
# 오산대
# 오산
# 진위
# 진
# 송탄
# 송
# 서정리
# 서정
# 지제
# 지
# 평택
# 평
# 성환
# 성
# 직산
# 직
# 두정
# 두
# 천안
# 천
# 봉명
# 봉
# 쌍용
# 쌍
# 아산
# 아
# 배방
# 배
# 온양온천
# 온양온
# 신창
# 신
# 서동탄
# 서동
# 을지로입구
# 을지로입
# 을지로3가
# 을지로3
# 을지로4가
# 을지로4
# 동대문역사문화공원
# 동대문역사문화공
# 신당
# 신
# 상왕십리
# 상왕십
# 왕십리
# 왕십
# 한양대
# 한양
# 뚝섬
# 뚝
# 성수
# 성
# 건대입구
# 건대입
# 구의
# 구
# 강변
# 강
# 잠실나루
# 잠실나
# 신천
# 신
# 종합운동장
# 종합운동
# 삼성
# 삼
# 선릉
# 선
# 역삼
# 역
# 강남
# 강
# 교대
# 교
# 서초
# 서
# 방배
# 방
# 사당
# 사
# 낙성대
# 낙성
# 서울대입구
# 서울대입
# 봉천
# 봉
# 신림
# 신
# 신대방
# 신대
# 구로디지털단지
# 구로디지털단
# 대림
# 대
# 문래
# 문
# 영등포구청
# 영등포구
# 당산
# 당
# 합정
# 합
# 홍대입구
# 홍대입
# 신촌
# 신
# 이대
# 이
# 아현
# 아
# 충정로
# 충정
# 대화
# 대
# 주엽
# 주
# 정발산
# 정발
# 마두
# 마
# 백석
# 백
# 대곡
# 대
# 화정
# 화
# 원당
# 원
# 삼송
# 삼
# 지축
# 지
# 구파발
# 구파
# 연신내
# 연신
# 붕광
# 붕
# 녹번
# 녹
# 홍제
# 홍
# 무악재
# 무악
# 독립문
# 독립
# 경북궁
# 경북
# 안국
# 안
# 충무로
# 충무
# 동대입구
# 동대입
# 약수
# 약
# 금호
# 금
# 옥수
# 옥
# 압구정
# 압구
# 신사
# 신
# 잠원
# 잠
# 고속터미널
# 고속터미
# 남부터미널
# 남부터미
# 양재
# 양
# 매봉
# 매
# 도곡
# 도
# 대치
# 대
# 학여울
# 학여
# 대청
# 대
# 일원
# 일
# 수서
# 수
# 가락시장
# 가락시
# 경찰병원
# 경찰병
# 오금
# 오
# 진접
# 진
# 오남
# 오
# 별내별가람
# 별내별가
# 당고개
# 당고
# 상계
# 상
# 노원
# 노
# 쌍문
# 쌍
# 수유
# 수
# 미아
# 미
# 미아삼거리
# 미아삼거
# 길음
# 길
# 성신여대입구
# 성신여대입
# 한성대입구
# 한성대입
# 혜화
# 혜
# 명동
# 명
# 회현
# 회
# 숙대입구
# 숙대입
# 삼각지
# 삼각
# 신용산
# 신용
# 이촌
# 이
# 동작
# 동
# 이수
# 이
# 남태령
# 남태
# 선바위
# 선바
# 경마공원
# 경마공
# 대공원
# 대공
# 과천
# 과
# 정부과천청사
# 정부과천청
# 인덕원
# 인덕
# 평촌
# 평
# 범계
# 범
# 산본
# 산
# 수리산
# 수리
# 대야미반월
# 대야미반
# 상록수
# 상록
# 한대앞
# 한대
# 중앙
# 중
# 고잔
# 고
# 공단
# 공
# 안산
# 안
# 신길온천
# 신길온
# 정왕
# 정
# 오이도
# 오이
# 방화
# 방
# 개화산
# 개화
# 김포공항
# 김포공
# 송정
# 송
# 마곡
# 마
# 발산
# 발
# 우장산
# 우장
# 화곡
# 화
# 까치산
# 까치
# 신정
# 신
# 목동
# 목
# 오목교
# 오목
# 양평
# 양
# 영등포시장
# 영등포시
# 여의도
# 여의
# 여의나루
# 여의나
# 마포
# 마
# 공덕
# 공
# 애오개
# 애오
# 서대문
# 서대
# 광화문
# 광화
# 청구
# 청
# 신금호
# 신금
# 행당
# 행
# 마장
# 마
# 답십리
# 답십
# 장한평
# 장한
# 군자
# 군
# 아차산
# 아차
# 광나루
# 광나
# 천호
# 천
# 강동
# 강
# 길동
# 길
# 굽은다리
# 굽은다
# 명일
# 명
# 고덕
# 고
# 상일동
# 상일
# 둔촌동
# 둔촌
# 올림픽공원
# 올림픽공
# 방이
# 방
# 개롱
# 개
# 거여
# 거
# 마천
# 마

# %% [markdown]
# ## 5) 양방향 Graph 전처리(nan 존재x + 호선 구별o + 중복 호선 환승 고려x)

# %%
graph = {}

# print(graph) # 확인용 코드

# 모든 역에 대해서 전처리
for i in range(5):
    # print(i) # 확인용 코드
    for j in range(len(sb_list)):
        # print(j) # 확인용 코드
        
        # graph 생성 - graph 마지막 원소 전이고, 비어있지 않은 역인 경우
        if(j < len(sb_list)-1 and not pd.isna(sb_list[j+1][i]) and not pd.isna(sb_list[j][i])):
            # graph에 해당 역 존재 : 해당 역의 key, value 빼서 다시 전처리 + 다음 역 추가시킨 graph 생성
            if (sb_list[j][i] + str(i+1)) in graph:
                # print(sb_list[j][i]) # 확인용 코드
                keys = [k for k in graph[sb_list[j][i] + str(i+1)].keys()]
                # print(key) # 확인용 코드
                values = [v for v in graph[sb_list[j][i] + str(i+1)].values()]
                # print(values) # 확인용 코드
                dic = {}
                for d in range(len(keys)):
                    dic[keys[d]] = values[d]
                dic[sb_list[j+1][i] + str(i+1)] = 2
                graph[sb_list[j][i] + str(i+1)] = dic
                # graph[sb_list[j][i]] = {graph.get(sb_list[j][i]), sb_list[j+1][i]:2}
                
            # graph에 해당 역 존재하지 않음 : 다음 역 추가시킨 graph 생성
            else:
                graph[sb_list[j][i] + str(i+1)] = {(sb_list[j+1][i] + str(i+1)):2}       
        # graph 생성 - 비어있는 역인 경우 : 건너뛰기
        elif(pd.isna(sb_list[j][i]) == True):
            pass
        # graph 생성 - 비어있는 역 아닌 경우
        else:
            # graph에 해당 역 존재 : 건너뛰기
            if (str(sb_list[j][i]) + str(i+1)) in graph:
                pass
            # graph에 해당 역 존재하지 않음 : 빈 원소로 두기
            else:
                graph[sb_list[j][i] + str(i+1)] = {}
                print(sb_list[j][i] + str(i+1)) # 확인용 코드
                
        # graph 생성 - graph 첫 번째 원소 이후이고, 비어있지 않은 역인 경우
        if(0 < j and not pd.isna(sb_list[j-1][i]) and not pd.isna(sb_list[j][i])):
            # graph에 해당 역 존재 : 해당 역의 key, value 빼서 다시 전처리 + 다음 역 추가시킨 graph 생성
            if (sb_list[j][i] + str(i+1)) in graph:
                # print(sb_list[j][i]) # 확인용 코드
                keys = [k for k in graph[sb_list[j][i] + str(i+1)].keys()]
                # print(key) # 확인용 코드
                values = [v for v in graph[sb_list[j][i] + str(i+1)].values()]
                # print(values) # 확인용 코드
                dic = {}
                for d in range(len(keys)):
                    dic[keys[d]] = values[d]
                dic[sb_list[j-1][i] + str(i+1)] = 2
                graph[sb_list[j][i] + str(i+1)] = dic
                # graph[sb_list[j][i]] = {graph.get(sb_list[j][i]), sb_list[j+1][i]:2}
                '''if(sb_list[j][i] == '시청'): # 확인용 코드
                    print(keys)
                    print(graph[sb_list[j][i]])'''
            # graph에 해당 역 존재하지 않음 : 다음 역 추가시킨 graph 생성
            else:
                graph[sb_list[j][i] + str(i+1)] = {sb_list[j-1][i] + str(i+1):2}
        # graph 생성 - graph 첫번째 원소이거나, 비어있는 역인 경우 : 불가능한 경우
        else:
            pass
        
print(graph)
# Out:
# 서동탄1
# 오금3
# 오이도4
# 마천5
# {'소요산1': {'동두천1': 2}, '동두천1': {'보산1': 2, '소요산1': 2}, '보산1': {'동두천중앙1': 2, '동두천1': 2}, '동두천중앙1': {'지행1': 2, '보산1': 2}, '지행1': {'덕정1': 2, '동두천중앙1': 2}, '덕정1': {'덕계1': 2, '지행1': 2}, '덕계1': {'양주1': 2, '덕정1': 2}, '양주1': {'녹양1': 2, '덕계1': 2}, '녹양1': {'가능1': 2, '양주1': 2}, '가능1': {'의정부1': 2, '녹양1': 2}, '의정부1': {'회룡1': 2, '가능1': 2}, '회룡1': {'망월사1': 2, '의정부1': 2}, '망월사1': {'도봉산1': 2, '회룡1': 2}, '도봉산1': {'방학1': 2, '망월사1': 2}, '방학1': {'창동1': 2, '도봉산1': 2}, '창동1': {'녹천1': 2, '방학1': 2}, '녹천1': {'월계1': 2, '창동1': 2}, '월계1': {'성북1': 2, '녹천1': 2}, '성북1': {'신이문1': 2, '월계1': 2}, '신이문1': {'외대앞1': 2, '성북1': 2}, '외대앞1': {'회기1': 2, '신이문1': 2}, '회기1': {'청량리1': 2, '외대앞1': 2}, '청량리1': {'제기동1': 2, '회기1': 2}, '제기동1': {'신설동1': 2, '청량리1': 2}, '신설동1': {'동묘앞1': 2, '제기동1': 2}, '동묘앞1': {'동대문1': 2, '신설동1': 2}, '동대문1': {'종로5가1': 2, '동묘앞1': 2}, '종로5가1': {'종로3가1': 2, '동대문1': 2}, '종로3가1': {'종각1': 2, '종로5가1': 2}, '종각1': {'시청1': 2, '종로3가1': 2}, '시청1': {'서울역1': 2, '종각1': 2}, '서울역1': {'남영1': 2, '시청1': 2}, '남영1': {'용산1': 2, '서울역1': 2}, '용산1': {'노량진1': 2, '남영1': 2}, '노량진1': {'대방1': 2, '용산1': 2}, '대
지로4가2': 2, '을지로입구2': 2}, '을지로4가2': {'동대문역사문화공원2': 2, '을지로3가2': 2}, '동대문역사문화공원2': {'신당2': 2, '을지로4가2': 2}, '신당2': {'상왕십리2': 2, '동대문역사문화공원2': 2}, '상왕십리2': {'왕십리2': 2, '신당2': 2}, '왕십리2': {'한양대2': 2, '상왕십리2': 2}, '한양대2': {'뚝섬2': 2, '왕십리2': 2}, '뚝섬2': {'성수2': 2, '한양대2': 2}, '성수2': {'건대입구2': 2, '뚝섬2': 2}, '건대입구2': {'구의2': 2, '성수2': 2}, '구의2': {'강변2': 2, '건대입구2': 2}, '강변2': {'잠실나루2': 2, '구의2': 2}, '잠실나루2': {'신천2': 2, '강변2': 2}, '신천2': {'종합운동장2': 2, '잠실나루2': 2}, '종합운동장2': {'삼성2': 2, '신천2': 2}, '삼성2': {'선릉2': 2, '종합운동장2': 2}, '선릉2': {'역삼2': 2, '삼성2': 2}, '역삼2': {'강남2': 2, '선릉2': 2}, '강남2': {'교대2': 2, '역삼2': 2}, '교대2': {'서초2': 2, '강남2': 2}, '서초2': {'방배2': 2, '교대2': 2}, '방배2': {'사당2': 2, '서초2': 2}, '사당2': {'낙성대2': 2, '방배2': 2}, '낙성대2': {'서울대입구2': 2, '사당2': 2}, '서울대입구2': {'봉천2': 2, '낙성대2': 2}, '봉천2': {'신림2': 2, '서울대입구2': 2}, '신림2': {'신대방2': 2, '봉천2': 2}, '신대방2': {'구로디지털단지2': 2, '신림2': 2}, '구로디지털단지2': {'대림2': 2, '신대방2': 2}, '대림2': {'신도림2': 2, '구로디지털단지2': 2}, '신도림2': {'문래2': 2, '대림2': 2}, '문래2': {'영등포구청2': 2, '신도림2': 2}, '영등포구청2': {'당산2': 2, '문래2': 2}, '당산2': {'합 ...

# %% [markdown]
# ## 5) 양방향 Graph 전처리 추가(중복 호선 환승 고려o)

# %%
graph_key = list(graph.keys())
# print(graph_key) # 확인용 코드
print("ㅡㅡㅡㅡㅡ중첩 데이터 출력ㅡㅡㅡㅡㅡ")

for i in range(len(graph_key)):
    for j in range(i+1, len(graph_key)):
        # print(graph_key[0]) # 확인용 코드
        # print(graph_key[0][0:len(graph_key[0])-1]) # 확인용 코드
        if(graph_key[i][0:len(graph_key[i])-1] == graph_key[j][0:len(graph_key[j])-1]):
            print(graph_key[i], graph_key[j]) # 확인용 코드

            keys = [k for k in graph[graph_key[i]]]
            # print(key) # 확인용 코드
            values = [v for v in graph[graph_key[i]].values()]
            # print(values) # 확인용 코드
            dic = {}
            for d in range(len(keys)):
                dic[keys[d]] = values[d]
            dic[graph_key[j]] = 2
            graph[graph_key[i]] = dic

            keys = [k for k in graph[graph_key[j]]]
            # print(key) # 확인용 코드
            values = [v for v in graph[graph_key[j]].values()]
            # print(values) # 확인용 코드
            dic = {}
            for d in range(len(keys)):
                dic[keys[d]] = values[d]
            dic[graph_key[i]] = 2
            graph[graph_key[j]] = dic
# Out:
# ㅡㅡㅡㅡㅡ중첩 데이터 출력ㅡㅡㅡㅡㅡ
 2, '신당2': 2}, '왕십리2': {'한양대2': 2, '상왕십리2': 2, '왕십리5': 2}, '한양대2': {'뚝섬2': 2, '왕십리2': 2}, '뚝섬2': {'성수2': 2, '한양대2': 2}, '성수2': {'건대입구2': 2, '뚝섬2': 2}, '건대입구2': {'구의2': 2, '성수2': 2}, '구의2': {'강변2': 2, '건대입구2': 2}, '강변2': {'잠실나루2': 2, '구의2': 2}, '잠실나루2': {'신천2': 2, '강변2': 2}, '신천2': {'종합운동장2': 2, '잠실나루2': 2}, '종합운동장2': {'삼성2': 2, '신천2': 2}, '삼성2': {'선릉2': 2, '종합운동장2': 2}, '선릉2': {'역삼2': 2, '삼성2': 2}, '역삼2': {'강남2': 2, '선릉2': 2}, '강남2': {'교대2': 2, '역삼2': 2}, '교대2': {'서초2': 2, '강남2': 2, '교대3': 2}, '서초2': {'방배2': 2, '교대2': 2}, '방배2': {'사당2': 2, '서초2': 2}, '사당2': {'낙성대2': 2, '방배2': 2, '사당4': 2}, '낙성대2': {'서울대입구2': 2, '사당2': 2}, '서울대입구2': {'봉천2': 2, '낙성대2': 2}, '봉천2': {'신림2': 2, '서울대입구2': 2}, '신림2': {'신대방2': 2, '봉천2': 2}, '신대방2': {'구로 ...

# %% [markdown]
# ## 5-1) 양방향 Graph 거리 계산(nan 존재x + 호선 구별o + 중복 호선 환승 고려o)

# %%
# 그래프 : 본인 노드 이름 : {연결된 노드 이름 : 연결된 노드까지의 거리}
# distances : 시작 노드에서 특정 노드까지 거리 저장 dic
# start : 시작 노드
# heap : 다음 특정 노드 저장
# distance : 특정 노드까지 최소 거리
# current distance : 특정 노드까지 거리
# current destination : 특정 노드 노드명

import heapq  # 우선순위 큐 구현을 위함

def dijkstra(graph, start):
    # 거리 초기 설정
    distances = {node: float('inf') for node in graph} # [시작 노드에서 특정 노드까지 거리] : 무한대
    distances[start] = 0 # [시작 노드에서 시작 노드까지 거리] : 0
    # print(distances) # 확인용 코드
    queue = [] # [정보 저장 heap] 생성
    heapq.heappush(queue, [distances[start], start])  # [[시작 노드에서 시작 노드까지 거리], [시작 노드명]]를 [정보 저장 heap]에 저장
    # print(distances[start], start) # 확인용 코드

    # graph 생성
    while queue:  # heap에서 노드가 빌 때까지 반복
        current_distance, current_destination = heapq.heappop(queue) # [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] 빼기
        # print(current_distance, current_destination)
        if distances[current_destination] < current_distance: # [정보 저장 heap]에서 가장 작은 [시작 노드에서 특정 노드까지 거리] > [기존 시작 노드에서 특정 노드까지 거리]이면 건너띔
            print(distances[current_destination], current_distance) # 확인용 코드
            continue

        for new_destination, new_distance in graph[current_destination].items(): # [특정 노드]에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]] 전부 돌기
            distance = current_distance + new_distance # [시작 노드에서 다음 특정 노드까지의 새로운 거리] = [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] + 특정 노드명에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]
            if distance < distances[new_destination]: # [시작 노드에서 다음 특정 노드까지 거리] > [시작 노드에서 다음 특정 노드까지의 새로운 거리]라면
                # 거리 최신화
                distances[new_destination] = distance # [시작 노드에서 다음 특정 노드까지 거리] 최신화
                heapq.heappush(queue, [distance, new_destination]) # [[시작 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]을 [정보 저장 heap]에 저장

    return distances

print(dijkstra(graph, '시청1'))
# Out:
# {'소요산1': 60, '동두천1': 58, '보산1': 56, '동두천중앙1': 54, '지행1': 52, '덕정1': 50, '덕계1': 48, '양주1': 46, '녹양1': 44, '가능1': 42, '의정부1': 40, '회룡1': 38, '망월사1': 36, '도봉산1': 34, '방학1': 32, '창동1': 30, '녹천1': 28, '월계1': 26, '성북1': 24, '신이문1': 22, '외대앞1': 20, '회기1': 18, '청량리1': 16, '제기동1': 14, '신설동1': 12, '동묘앞1': 10, '동대문1': 8, '종로5가1': 6, '종로3가1': 4, '종각1': 2, '시청1': 0, '서울역1': 2, '남영1': 4, '용산1': 6, '노량진1': 8, '대방1': 10, '신길1': 12, '영등포1': 14, '신도림1': 16, '구로1': 18, '구일1': 20, '개봉1': 22, '오류동1': 24, '온수1': 26, '역곡1': 28, '소사1': 30, '부천1': 32, '중동1': 34, '송내1': 36, '부개1': 38, '부평1': 40, '백운1': 42, '동암1': 44, '간석1': 46, '주안1': 48, '도화1': 
50, '고잔4': 52, '공단4': 54, '안산4': 56, '신길온천4': 58, '정왕4': 60, '오이도4': 62, '방화5': 44, '개화산5': 42, '김포공항5': 40, '송정5': 38, '마곡5': 36, '발산5': 34, '우장산5': 32, '화곡5': 30, '까치산5': 28, '신정5': 26, '목동5': 24, '오목교5': 22, '양평5': 20, '영등포구청5': 18, '영등포시장5': 16, '신길5': 14, '여의도5': 16, '여의나루5': 14, '마포5': 12, '공덕5': 10, '애오개5': 8, '충정로5': 6, '서대문5': 8, '광화문5': 8, '종로3가5': 6, '을지로4가5': 8, '동대문역사문화공원5': 10, '청구5': 12, '신금호5': 14, '행당5': 16, '왕십리5': 18, '마장5': 20, '답십리5': 22, '장한평5': 24, '군자5': 26, '아차산5': 28, '광나루5': 30, '천호5': 32, '강동5': 34, '길동5': 36, '굽은다리5': 38, '명일5': 40, '고덕5': 42, '상일동5': 44, '둔촌동5': 46, '올림픽공원5': 48, '방이5': 50, '오금5': 52, '개롱5': 54, '거여5': 56, '마천5': 58}

# %% [markdown]
# ## 5-2) 양방향 Graph 거리 계산(nan 존재x + 호선 구별o + 중복 호선 환승 고려o + 가독성 향상)

# %%
# 그래프 : 본인 노드 이름 : {연결된 노드 이름 : 연결된 노드까지의 거리}
# dist : 시작 노드에서 특정 노드까지 거리 저장 dic
# st : 시작 노드
# heap : 다음 특정 노드 저장
# plus dist : 특정 노드까지 최소 거리
# cur dist : 특정 노드까지 거리
# cur dest : 특정 노드 노드명

import heapq  # 우선순위 큐 구현을 위함

def dijkstra(graph, st):
    # 거리 초기 설정
    dist = {node: float('inf') for node in graph} # [시작 노드에서 특정 노드까지 거리] : 무한대
    dist[st] = 0 # [시작 노드에서 시작 노드까지 거리] : 0
    # print(dist) # 확인용 코드
    
    # heap 초기 설정
    queue = [] # [정보 저장 heap] 생성
    heapq.heappush(queue, [dist[st], st])  # [[시작 노드에서 시작 노드까지 거리], [시작 노드명]]를 [정보 저장 heap]에 저장
    # print(dist[st], st) # 확인용 코드

    # graph 생성
    while queue:  # heap에서 노드가 빌 때까지 반복
        cur_dist, cur_dest = heapq.heappop(queue) # [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] 빼기
        # print(cur_dist, cur_dest)
        if dist[cur_dest] < cur_dist: # [정보 저장 heap]에서 가장 작은 [시작 노드에서 특정 노드까지 거리] > [기존 시작 노드에서 특정 노드까지 거리]이면 건너띔
            print(dist[cur_dest], cur_dist) # 확인용 코드
            continue

        for new_dest, new_dist in graph[cur_dest].items(): # [특정 노드]에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]] 전부 돌기
            plus_dist = cur_dist + new_dist # [시작 노드에서 다음 특정 노드까지의 새로운 거리] = [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] + 특정 노드명에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]
            if plus_dist < dist[new_dest]: # [시작 노드에서 다음 특정 노드까지 거리] > [시작 노드에서 다음 특정 노드까지의 새로운 거리]라면
                # 거리 최신화
                dist[new_dest] = plus_dist # [시작 노드에서 다음 특정 노드까지 거리] 최신화
                heapq.heappush(queue, [plus_dist, new_dest]) # [[시작 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]을 [정보 저장 heap]에 저장

    return dist

print(dijkstra(graph, '시청1'))
# Out:
# {'소요산1': 60, '동두천1': 58, '보산1': 56, '동두천중앙1': 54, '지행1': 52, '덕정1': 50, '덕계1': 48, '양주1': 46, '녹양1': 44, '가능1': 42, '의정부1': 40, '회룡1': 38, '망월사1': 36, '도봉산1': 34, '방학1': 32, '창동1': 30, '녹천1': 28, '월계1': 26, '성북1': 24, '신이문1': 22, '외대앞1': 20, '회기1': 18, '청량리1': 16, '제기동1': 14, '신설동1': 12, '동묘앞1': 10, '동대문1': 8, '종로5가1': 6, '종로3가1': 4, '종각1': 2, '시청1': 0, '서울역1': 2, '남영1': 4, '용산1': 6, '노량진1': 8, '대방1': 10, '신길1': 12, '영등포1': 14, '신도림1': 16, '구로1': 18, '구일1': 20, '개봉1': 22, '오류동1': 24, '온수1': 26, '역곡1': 28, '소사1': 30, '부천1': 32, '중동1': 34, '송내1': 36, '부개1': 38, '부평1': 40, '백운1': 42, '동암1': 44, '간석1': 46, '주안1': 48, '도화1': 50, '제물포1': 52, '도원1': 54, '동인천1': 56, '인천1': 58, '광명1': 56, '가산디지털단지1': 54, '독산1': 52,
화산5': 42, '김포공항5': 40, '송정5': 38, '마곡5': 36, '발산5': 34, '우장산5': 32, '화곡5': 30, '까치산5': 28, '신정5': 26, '목동5': 24, '오목교5': 22, '양평5': 20, '영등포구청5': 18, '영등포시장5': 16, '신길5': 14, '여의도5': 16, '여의나루5': 14, '마포5': 12, '공덕5': 10, '애오개5': 8, '충정로5': 6, '서대문5': 8, '광화문5': 8, '종로3가5': 6, '을지로4가5': 8, '동대문역사문화공원5': 10, '청구5': 12, '신금호5': 14, '행당5': 16, '왕십리5': 18, '마장5': 20, '답십리5': 22, '장한평5': 24, '군자5': 26, '아차산5': 28, '광나루5': 30, '천호5': 32, '강동5': 34, '길동5': 36, '굽은다리5': 38, '명일5': 40, '고덕5': 42, '상일동5': 44, '둔촌동5': 46, '올림픽공원5': 48, '방이5': 50, '오금5': 52, '개롱5': 54, '거여5': 56, '마천5': 58}

# %% [markdown]
# ## 5-3) 양방향 Graph 거리 계산(nan 존재x + 호선 구별o + 중복 호선 환승 고려o + 가독성 향상 + 경로 출력)

# %%
# 그래프 : 본인 노드 이름 : {연결된 노드 이름 : 연결된 노드까지의 거리}
# dist : 시작 노드에서 특정 노드까지 거리 저장 dic
# st : 시작 노드
# heap : 다음 특정 노드 저장
# plus dist : 특정 노드까지 최소 거리
# cur dist : 특정 노드까지 거리
# cur dest : 특정 노드 노드명

# track : 시작 노드에서 특정 노드까지 경로 저장 dic

import heapq  # 우선순위 큐 구현을 위함

def dijkstra(graph, st):
    # 거리 + track 초기 설정
    dist = {node: float('inf') for node in graph} # [시작 노드에서 특정 노드까지 거리] : 무한대
    global track
    track = {node: [] for node in graph} # [시작 노드에서 특정 노드까지 경로] : 비어있음
    track[st] = [st] # [시작 노드에서 시작 노드까지 경로] : 시작 노드
    dist[st] = 0 # [시작 노드에서 시작 노드까지 거리] : 0
    # print(dist) # 확인용 코드
    
    # heap 초기 설정
    queue = [] # [정보 저장 heap] 생성
    heapq.heappush(queue, [dist[st], st])  # [[시작 노드에서 시작 노드까지 거리], [시작 노드명]]를 [정보 저장 heap]에 저장
    # print(dist[st], st) # 확인용 코드

    # graph 생성
    while queue:  # heap에서 노드가 빌 때까지 반복
        cur_dist, cur_dest = heapq.heappop(queue) # [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] 빼기
        # print(cur_dist, cur_dest)
        if dist[cur_dest] < cur_dist: # [정보 저장 heap]에서 가장 작은 [시작 노드에서 특정 노드까지 거리] > [기존 시작 노드에서 특정 노드까지 거리]이면 건너띔
            print(dist[cur_dest], cur_dist) # 확인용 코드
            continue

        for new_dest, new_dist in graph[cur_dest].items(): # [특정 노드]에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]] 전부 돌기
            plus_dist = cur_dist + new_dist # [시작 노드에서 다음 특정 노드까지의 새로운 거리] = [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] + 특정 노드명에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]
            if plus_dist < dist[new_dest]: # [시작 노드에서 다음 특정 노드까지 거리] > [시작 노드에서 다음 특정 노드까지의 새로운 거리]라면
                # 거리 최신화
                dist[new_dest] = plus_dist # [시작 노드에서 다음 특정 노드까지 거리] 최신화
                # print(type(track[cur_dest])) # 확인용 코드
                # print(track[new_dest]) # 확인용 코드
                # print(track[cur_dest]) # 확인용 코드
                
                # 경로 최신화
                track[new_dest] = track[cur_dest][:] # [시작 노드에서 특정 노드까지 경로] 최신화
                # track[cur_dest] = [] # 확인용 코드
                track[new_dest].append(new_dest)
                # print(cur_dest, new_dest) # 확인용 코드
                # print(track[new_dest]) # 확인용 코드
                # print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ") # 확인용 코드
                # if(new_dest == '시청1'):
                    # print(track[new_dest]) # 확인용 코드
                heapq.heappush(queue, [plus_dist, new_dest]) # [[시작 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]을 [정보 저장 heap]에 저장

        # print("ㅡㅡfor문 돌아ㅡㅡ") # 확인용 코드
    return dist

print(dijkstra(graph, '시청1'))
# Out:
# {'소요산1': 60, '동두천1': 58, '보산1': 56, '동두천중앙1': 54, '지행1': 52, '덕정1': 50, '덕계1': 48, '양주1': 46, '녹양1': 44, '가능1': 42, '의정부1': 40, '회룡1': 38, '망월사1': 36, '도봉산1': 34, '방학1': 32, '창동1': 30, '녹천1': 28, '월계1': 26, '성북1': 24, '신이문1': 22, '외대앞1': 20, '회기1': 18, '청량리1': 16, '제기동1': 14, '신설동1': 12, '동묘앞1': 10, '동대문1': 8, '종로
 10, '명동4': 8, '회현4': 6, '서울역4': 4, '숙대입구4': 6, '삼각지4': 8, '신용산4': 10, '이촌4': 12, '동작4': 14, '이수4': 16, '사당4': 18, '남태령4': 20, '선바위4': 22, '경마공원4': 24, '대공원4': 26, '과천4': 28, '정부과천청사4': 30, '인덕원4': 32, '평촌4': 34, '범계4': 36, '금정4': 38, '산본4': 40, '수리산4': 42, '대야미반월4': 44, '상록수4': 46, '한대앞4': 48, '중앙4': 50, '고잔4': 52, '공단4': 54, '안산4': 56, '신길온천4': 58, '정왕4': 60, '오이도4': 62, '방화5': 44, '개화산5': 42, '김포공항5': 40, '송정5': 38, '마곡5': 36, '발산5': 34, '우장산5': 32, '화곡5': 30, '까치산5': 28, '신정5': 26, '목동5': 24, '오목교5': 22, '양평5': 20, '영등포구청5': 18, '영등포시장5': 16, '신길5': 14, '여의도5': 16, '여의나루5': 14, '마포5': 12, '공덕5': 10, '애오개5': 8, '충정로5': 6, '서대문5': 8, '광화문5': 8, '종로3가5': 6, '을지로4가5': 8, '동대문역사문화공원5': 10, '청구5': 12, '신금호5': 14, '행당5': 16, '왕십리5': 18, '마장5': 20, '답십리5': 22, '장한평5': 24, '군자5': 26, '아차산5': 28, '광나루5': 30, '천호5': 32, '강동5': 34, '길동5': 36, '굽은다리5': 38, '명일5': 40, '고덕5': 42, '상일동5': 44, '둔촌동5': 46, '올림픽공원5': 48, '방이5': 50, '오금5': 52, '개롱5': 54, '거여5': 56, '마천5': 58}

# %%
# 경로 출력
print(track)
# Out:
# {'소요산1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1', '보산1', '동두천1', '소요산1'], '동두천1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1', '보산1', '동두천1'], '보산1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1', '보산1'], '동두천중앙1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1'], '지행1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1'], '덕정1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1'], '덕계1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1'], '양주1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1'], '녹양1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1'], '가능1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1'], '의정부1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1'], '회룡1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1'], '망월사1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1'], '도봉산1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1'], '방학1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1'], '창동1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1'], '녹천1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1'], '월계1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1'], '성북1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1'], '신이문1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1'], '외대앞1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1'], '회기1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1'], '청량리1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1'], '제기동1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1'], '신설동1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1'], '동묘앞1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1'], '동대문1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1'], '종로5가1': ['시 ...

# %%
print(track['시청1'])
print(track['명동4'])
print(track['상일동5'])
print(track['을지로3가3'])
print(track['금호3'])
# Out:
# ['시청1']
# ['시청1', '서울역1', '서울역4', '회현4', '명동4']
# ['시청1', '시청2', '을지로입구2', '을지로3가2', '을지로4가2', '동대문역사문화공원2', '신당2', '상왕십리2', '왕십리2', '왕십리5', '마장5', '답십리5', '장한평5', '군자5', '아차산5', '광나루5', '천호5', '강동5', '길동5', '굽은다리5', '명일5', '고덕5', '상일동5']
# ['시청1', '시청2', '을지로입구2', '을지로3가2', '을지로3가3']
# ['시청1', '시청2', '을지로입구2', '을지로3가2', '을지로3가3', '충무로3', '동대입구3', '약수3', '금호3']

# %% [markdown]
# ## 5-4) 양방향 Graph 거리 계산(nan 존재x + 호선 구별o + 중복 호선 환승 고려o + 가독성 향상 + 경로 출력 + 환승 횟수 출력)

# %%
# 그래프 : 본인 노드 이름 : {연결된 노드 이름 : 연결된 노드까지의 거리}
# dist : 시작 노드에서 특정 노드까지 거리 저장 dic
# st : 시작 노드
# heap : 다음 특정 노드 저장
# plus dist : 특정 노드까지 최소 거리
# cur dist : 특정 노드까지 거리
# cur dest : 특정 노드 노드명

# track : 시작 노드에서 특정 노드까지 경로 저장 dic
# count : 시작 노드에서 특정 노드까지 환승 횟수 저장 dic

import heapq  # 우선순위 큐 구현을 위함

def dijkstra(graph, st):
    # 거리 + track + 환승횟수 초기 설정
    dist = {node: float('inf') for node in graph} # [시작 노드에서 특정 노드까지 거리] : 무한대
    global track, count
    track = {node: [] for node in graph} # [시작 노드에서 특정 노드까지 경로] : 비어있음
    track[st] = [st] # [시작 노드에서 시작 노드까지 경로] : 시작 노드
    count = {node: 0 for node in graph} # [시작 노드에서 특정 노드까지 환승 횟수] : 0
    dist[st] = 0 # [시작 노드에서 시작 노드까지 거리] : 0
    # print(dist) # 확인용 코드
    
    # heap 초기 설정
    queue = [] # [정보 저장 heap] 생성
    heapq.heappush(queue, [dist[st], st])  # [[시작 노드에서 시작 노드까지 거리], [시작 노드명]]를 [정보 저장 heap]에 저장
    # print(dist[st], st) # 확인용 코드

    # graph 생성
    while queue:  # heap에서 노드가 빌 때까지 반복
        cur_dist, cur_dest = heapq.heappop(queue) # [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] 빼기
        # print(cur_dist, cur_dest)
        if dist[cur_dest] < cur_dist: # [정보 저장 heap]에서 가장 작은 [시작 노드에서 특정 노드까지 거리] > [기존 시작 노드에서 특정 노드까지 거리]이면 건너띔
            print(dist[cur_dest], cur_dist) # 확인용 코드
            continue

        for new_dest, new_dist in graph[cur_dest].items(): # [특정 노드]에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]] 전부 돌기
            plus_dist = cur_dist + new_dist # [시작 노드에서 다음 특정 노드까지의 새로운 거리] = [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] + 특정 노드명에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]
            if plus_dist < dist[new_dest]: # [시작 노드에서 다음 특정 노드까지 거리] > [시작 노드에서 다음 특정 노드까지의 새로운 거리]라면
                # 거리 최신화
                dist[new_dest] = plus_dist # [시작 노드에서 다음 특정 노드까지 거리] 최신화
                # print(type(track[cur_dest])) # 확인용 코드
                # print(track[new_dest]) # 확인용 코드
                # print(track[cur_dest]) # 확인용 코드
                
                # 경로 최신화
                track[new_dest] = track[cur_dest][:] # [시작 노드에서 특정 노드까지 경로] 최신화 (특정 노드 이전까지 경로 얕은 복사 + 특정 노드도 경로에 추가)
                # track[cur_dest] = [] # 확인용 코드
                track[new_dest].append(new_dest)
                if(new_dest == '충무로4'): # 확인용 코드
                    print(track[new_dest])
                    
                # 환승 횟수 최신화
                if(new_dest[0:len(new_dest)-1] == cur_dest[0:len(cur_dest)-1]): # [시작 노드에서 특정 노드까지 환승 횟수] 최신화 (특정 노드 이전까지 환승 횟수 + 특정 노드도 확인 후 추가)
                    count[new_dest] = count[cur_dest] + 1
                    print(new_dest, cur_dest) # 확인용 코드
                else:
                    count[new_dest] = count[cur_dest]
                # print(cur_dest, new_dest) # 확인용 코드
                # print(track[new_dest]) # 확인용 코드
                # print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ") # 확인용 코드
                # if(new_dest == '시청1'):
                    # print(track[new_dest]) # 확인용 코드
                heapq.heappush(queue, [plus_dist, new_dest]) # [[시작 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]을 [정보 저장 heap]에 저장

        # print("ㅡㅡfor문 돌아ㅡㅡ") # 확인용 코드
    return dist

print(dijkstra(graph, '시청1'))
# Out:
# 시청2 시청1
# 서울역4 서울역1
# 종로3가3 종로3가1
# 종로3가5 종로3가1
# 충정로5 충정로2
# 을지로3가3 을지로3가2
# 동대문4 동대문1
# ['시청1', '서울역1', '서울역4', '회현4', '명동4', '충무로4']
# 신길5 신길1
# 신도림2 신도림1
# 왕십리5 왕십리2
# 사당2 사당4
# 금정1 금정4
# {'소요산1': 60, '동두천1': 58, '보산1': 56, '동두천중앙1': 54, '지행1': 52, '덕정1': 50, '덕계1': 48, '양주1': 46, '녹양1': 44, '가능1': 42, '의정부1': 40, '회룡1': 38, '망월사1': 36, '도봉산1': 34, '방학1': 32, '창동1': 30, '녹천1': 28, '월계1': 26, '성북1': 24, '신이문1': 22, '외대앞1': 20, '회기1': 18, '청량리1': 16, '제기동1': 14, '신설동1': 12, '동묘앞1': 10, '동대문1': 8, '종로5가1': 6, '종로3가1': 4, '종각1': 2, '시청1': 0, '서울역1': 2, '남영1': 4, '용산1': 6, '노량진1': 8, '대방1': 10, '신길1': 12
, '사당4': 18, '남태령4': 20, '선바위4': 22, '경마공원4': 24, '대공원4': 26, '과천4': 28, '정부과천청사4': 30, '인덕원4': 32, '평촌4': 34, '범계4': 36, '금정4': 38, '산본4': 40, '수리산4': 42, '대야미반월4': 44, '상록수4': 46, '한대앞4': 48, '중앙4': 50, '고잔4': 52, '공단4': 54, '안산4': 56, '신길온천4': 58, '정왕4': 60, '오이도4': 62, '방화5': 44, '개화산5': 42, '김포공항5': 40, '송정5': 38, '마곡5': 36, '발산5': 34, '우장산5': 32, '화곡5': 30, '까치산5': 28, '신정5': 26, '목동5': 24, '오목교5': 22, '양평5': 20, '영등포구청5': 18, '영등포시장5': 16, '신길5': 14, '여의도5': 16, '여의나루5': 14, '마포5': 12, '공덕5': 10, '애오개5': 8, '충정로5': 6, '서대문5': 8, '광화문5': 8, '종로3가5': 6, '을지로4가5': 8, '동대문역사문화공원5': 10, '청구5': 12, '신금호5': 14, '행당5': 16, '왕십리5': 18, '마장5': 20, '답십리5': 22, '장한평5': 24, '군자5': 26, '아차산5': 28, '광나루5': 30, '천호5': 32, '강동5': 34, '길동5': 36, '굽은다리5': 38, '명일5': 40, '고덕5': 42, '상일동5': 44, '둔촌동5': 46, '올림픽공원5': 48, '방이5': 50, '오금5': 52, '개롱5': 54, '거여5': 56, '마천5': 58}

# %%
# 경로 출력
print(track)
# Out:
# {'소요산1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1', '보산1', '동두천1', '소요산1'], '동두천1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1', '보산1', '동두천1'], '보산1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1', '보산1'], '동두천중앙1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1'], '지행1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1'], '덕정1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1'], '덕계1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1'], '양주1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1'], '녹양1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1'], '가능1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1'], '의정부1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1'], '회룡1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1'], '망월사1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1'], '도봉산1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1'], '방학1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1'], '창동1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1'], '녹천1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1'], '월계1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1'], '성북1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1'], '신이문1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1'], '외대앞1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1'], '회기1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1'], '청량리1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1'], '제기동1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1'], '신설동1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1'], '동묘앞1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1'], '동대문1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1'], '종로5가1': ['시 ...

# %%
print(track['시청1'])
print(track['명동4'])
print(track['상일동5'])
print(track['시청2'])
print(track['을지로3가3'])
print(track['금호3'])
# Out:
# ['시청1']
# ['시청1', '서울역1', '서울역4', '회현4', '명동4']
# ['시청1', '시청2', '을지로입구2', '을지로3가2', '을지로4가2', '동대문역사문화공원2', '신당2', '상왕십리2', '왕십리2', '왕십리5', '마장5', '답십리5', '장한평5', '군자5', '아차산5', '광나루5', '천호5', '강동5', '길동5', '굽은다리5', '명일5', '고덕5', '상일동5']
# ['시청1', '시청2']
# ['시청1', '시청2', '을지로입구2', '을지로3가2', '을지로3가3']
# ['시청1', '시청2', '을지로입구2', '을지로3가2', '을지로3가3', '충무로3', '동대입구3', '약수3', '금호3']

# %%
# 환승 횟수 출력
print(count)
# Out:
# {'소요산1': 0, '동두천1': 0, '보산1': 0, '동두천중앙1': 0, '지행1': 0, '덕정1': 0, '덕계1': 0, '양주1': 0, '녹양1': 0, '가능1': 0, '의정부1': 0, '회룡1': 0, '망월사1': 0, '도봉산1': 0, '방학1': 0, '창동1': 0, '녹천1': 0, '월계1': 0, '성북1': 0, '신이문1': 0, '외대앞1': 0, '회기1': 0, '청량리1': 0, '제기동1': 0, '신설동1': 0, '동묘앞1': 0, '동대문1': 0, '종로5가1
, '명동4': 1, '회현4': 1, '서울역4': 1, '숙대입구4': 1, '삼각지4': 1, '신용산4': 1, '이촌4': 1, '동작4': 1, '이수4': 1, '사당4': 1, '남태령4': 1, '선바위4': 1, '경마공원4': 1, '대공원4': 1, '과천4': 1, '정부과천청사4': 1, '인덕원4': 1, '평촌4': 1, '범계4': 1, '금정4': 1, '산본4': 1, '수리산4': 1, '대야미반월4': 1, '상록수4': 1, '한대앞4': 1, '중앙4': 1, '고잔4': 1, '공단4': 1, '안산4': 1, '신길온천4': 1, '정왕4': 1, '오이도4': 1, '방화5': 1, '개화산5': 1, '김포공항5': 1, '송정5': 1, '마곡5': 1, '발산5': 1, '우장산5': 1, '화곡5': 1, '까치산5': 1, '신정5': 1, '목동5': 1, '오목교5': 1, '양평5': 1, '영등포구청5': 1, '영등포시장5': 1, '신길5': 1, '여의도5': 1, '여의나루5': 2, '마포5': 2, '공덕5': 2, '애오개5': 2, '충정로5': 2, '서대문5': 2, '광화문5': 1, '종로3가5': 1, '을지로4가5': 1, '동대문역사문화공원5': 1, '청구5': 1, '신금호5': 1, '행당5': 1, '왕십리5': 2, '마장5': 2, '답십리5': 2, '장한평5': 2, '군자5': 2, '아차산5': 2, '광나루5': 2, '천호5': 2, '강동5': 2, '길동5': 2, '굽은다리5': 2, '명일5': 2, '고덕5': 2, '상일동5': 2, '둔촌동5': 2, '올림픽공원5': 2, '방이5': 2, '오금5': 2, '개롱5': 2, '거여5': 2, '마천5': 2}

# %%
print(count['시청1'])
print(count['명동4'])
print(count['상일동5'])
print(count['시청2'])
print(count['을지로3가3'])
print(count['금호3']) # 이건 환승 2번함
# Out:
# 0
# 1
# 2
# 1
# 2
# 2

# %% [markdown]
# ## 5-5) 양방향 Graph 거리 계산(nan 존재x + 호선 구별o + 중복 호선 환승 고려o + 가독성 향상 + 경로 출력 + 환승 횟수 출력 + 하나의 dic으로 통일화)

# %%
# 그래프 : 본인 노드 이름 : {연결된 노드 이름 : 연결된 노드까지의 거리}
# dist : 시작 노드에서 특정 노드까지 거리 + 경로 + 환승 횟수 저장 dic
# st : 시작 노드
# heap : 다음 특정 노드 저장
# plus dist : 특정 노드까지 최소 거리
# cur dist : 특정 노드까지 거리
# cur dest : 특정 노드 노드명

import heapq  # 우선순위 큐 구현을 위함

def dijkstra(graph, st):
    # 거리 + track + 환승횟수 초기 설정
    global dist
    dist = {node: [float('inf')] for node in graph} # [시작 노드에서 특정 노드까지 거리] : 무한대
    # print(dist) # 확인용 코드
    for node in graph:
        dist[node].append([]) # [시작 노드에서 특정 노드까지 경로] : 비어있음
        dist[node].append(0) # [시작 노드에서 특정 노드까지 환승 횟수] : 0
    # print(dist) # 확인용 코드
    dist[st][1] = [st]
    dist[st][0] = 0
    # print(dist) # 확인용 코드
    # print(dist['충무로4'][1]) # 확인용 코드
    
    # heap 초기 설정
    queue = [] # [정보 저장 heap] 생성
    heapq.heappush(queue, [dist[st][0], st])  # [[시작 노드에서 시작 노드까지 거리], [시작 노드명]]를 [정보 저장 heap]에 저장
    # print(dist[st], st) # 확인용 코드

    # graph 생성
    while queue:  # heap에서 노드가 빌 때까지 반복
        cur_dist, cur_dest = heapq.heappop(queue) # [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] 빼기
        # print(cur_dist, cur_dest)
        if dist[cur_dest][0] < cur_dist: # [정보 저장 heap]에서 가장 작은 [시작 노드에서 특정 노드까지 거리] > [기존 시작 노드에서 특정 노드까지 거리]이면 건너띔
            print(dist[cur_dest][0], cur_dist) # 확인용 코드
            continue

        for new_dest, new_dist in graph[cur_dest].items(): # [특정 노드]에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]] 전부 돌기
            plus_dist = cur_dist + new_dist # [시작 노드에서 다음 특정 노드까지의 새로운 거리] = [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] + 특정 노드명에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]
            if plus_dist < dist[new_dest][0]: # [시작 노드에서 다음 특정 노드까지 거리] > [시작 노드에서 다음 특정 노드까지의 새로운 거리]라면
                # 거리 최신화
                dist[new_dest][0] = plus_dist # [시작 노드에서 다음 특정 노드까지 거리] 최신화
                # print(type(track[cur_dest])) # 확인용 코드
                # print(track[new_dest]) # 확인용 코드
                # print(track[cur_dest]) # 확인용 코드
                
                # 경로 최신화
                dist[new_dest][1] = dist[cur_dest][1][:] # [시작 노드에서 특정 노드까지 경로] 최신화 (특정 노드 이전까지 경로 얕은 복사 + 특정 노드도 경로에 추가)
                # track[cur_dest] = [] # 확인용 코드
                # print(dist[new_dest][1]) # 확인용 코드
                dist[new_dest][1].append(new_dest)
                # if(new_dest == '충무로4'): # 확인용 코드
                    # print(dist[new_dest][1])
                    
                # 환승 횟수 최신화
                if(new_dest[0:len(new_dest)-1] == cur_dest[0:len(cur_dest)-1]): # [시작 노드에서 특정 노드까지 환승 횟수] 최신화 (특정 노드 이전까지 환승 횟수 + 특정 노드도 확인 후 추가)
                    dist[new_dest][2] = dist[cur_dest][2] + 1
                    # print(new_dest, cur_dest) # 확인용 코드
                else:
                    dist[new_dest][2] = dist[cur_dest][2]
                # print(cur_dest, new_dest) # 확인용 코드
                # print(track[new_dest]) # 확인용 코드
                # print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ") # 확인용 코드
                # if(new_dest == '시청1'):
                    # print(track[new_dest]) # 확인용 코드
                heapq.heappush(queue, [plus_dist, new_dest]) # [[시작 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]을 [정보 저장 heap]에 저장

        # print("ㅡㅡfor문 돌아ㅡㅡ") # 확인용 코드
    return dist

print(dijkstra(graph, '시청1'))
# Out:
# {'소요산1': [60, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1', '보산1', '동두천1', '소요산1'], 0], '동두천1': [58, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1', '보산1', '동두천1'], 0], '보산1': [56, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1', '보산1'], 0], '동두천중앙1': [54, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1'], 0], '지행1': [52, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1'], 0], '덕정1': [50, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1'], 0], '덕계1': [48, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1'], 0], '양주1': [46, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1'], 0], '녹양1': [44, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1'], 0], '가능1': [42, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1'], 0], '의정부1': [40, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1'], 0], '회룡1': [38, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1'], 0], '망월사1': [36, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1'], 0], '도봉산1': [34, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1'], 0], '방학1': [32, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1'], 0], '창동1': [30, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1'], 0], '녹천1': [28, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1'], 0], '월계1': [26, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1'], 0], '성북1': [24, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1'], 0], '신이문1': [22, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1'], 0], '외대앞1': [20, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1'], 0], '회기1': [18, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1'], 0], '청량리1': [16, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1'], 0], '제기동1': [14, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', ...

# %%
# 확인용 코드
print(dist['시청1'][0])
print(dist['시청1'][1])
print(dist['시청1'][2])
print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
print(dist['명동4'][0])
print(dist['명동4'][1])
print(dist['명동4'][2])
print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
print(dist['상일동5'][0])
print(dist['상일동5'][1])
print(dist['상일동5'][2])
print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
print(dist['시청2'][0])
print(dist['시청2'][1])
print(dist['시청2'][2])
print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
print(dist['을지로3가3'][0])
print(dist['을지로3가3'][1])
print(dist['을지로3가3'][2])
print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
print(dist['금호3'][0])
print(dist['금호3'][1])
print(dist['금호3'][2])
# Out:
# 0
# ['시청1']
# 0
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# 8
# ['시청1', '서울역1', '서울역4', '회현4', '명동4']
# 1
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# 44
# ['시청1', '시청2', '을지로입구2', '을지로3가2', '을지로4가2', '동대문역사문화공원2', '신당2', '상왕십리2', '왕십리2', '왕십리5', '마장5', '답십리5', '장한평5', '군자5', '아차산5', '광나루5', '천호5', '강동5', '길동5', '굽은다리5', '명일5', '고덕5', '상일동5']
# 2
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# 2
# ['시청1', '시청2']
# 1
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# 8
# ['시청1', '시청2', '을지로입구2', '을지로3가2', '을지로3가3']
# 2
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# 16
# ['시청1', '시청2', '을지로입구2', '을지로3가2', '을지로3가3', '충무로3', '동대입구3', '약수3', '금호3']
# 2

# %% [markdown]
# ## 5-6) 양방향 Graph 거리 계산(nan 존재x + 호선 구별o + 중복 호선 환승 고려o + 가독성 향상 + 경로 출력 + 환승 횟수 출력 + 하나의 dic으로 통일화 + 목적지까지 최소 거리 완성 시, break)

# %%
# 그래프 : 본인 노드 이름 : {연결된 노드 이름 : 연결된 노드까지의 거리}
# dist : 시작 노드에서 특정 노드까지 거리 + 경로 + 환승 횟수 저장 dic
# st : 시작 노드
# heap : 다음 특정 노드 저장
# plus dist : 특정 노드까지 최소 거리
# cur dist : 특정 노드까지 거리
# cur dest : 특정 노드 노드명

import heapq  # 우선순위 큐 구현을 위함

def dijkstra(graph, st, end):
    # 거리 + track + 환승횟수 초기 설정
    global dist
    dist = {node: [float('inf')] for node in graph} # [시작 노드에서 특정 노드까지 거리] : 무한대
    # print(dist) # 확인용 코드
    for node in graph:
        dist[node].append([]) # [시작 노드에서 특정 노드까지 경로] : 비어있음
        dist[node].append(0) # [시작 노드에서 특정 노드까지 환승 횟수] : 0
    # print(dist) # 확인용 코드
    dist[st][1] = [st]
    dist[st][0] = 0
    # print(dist) # 확인용 코드
    # print(dist['충무로4'][1]) # 확인용 코드
    
    # heap 초기 설정
    queue = [] # [정보 저장 heap] 생성
    heapq.heappush(queue, [dist[st][0], st])  # [[시작 노드에서 시작 노드까지 거리], [시작 노드명]]를 [정보 저장 heap]에 저장
    # print(dist[st], st) # 확인용 코드

    # graph 생성
    while queue:  # heap에서 노드가 빌 때까지 반복
        cur_dist, cur_dest = heapq.heappop(queue) # [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] 빼기
        # print(cur_dist, cur_dest)
        if(cur_dest == end): # 확인용 코드
            break
        
        if dist[cur_dest][0] < cur_dist: # [정보 저장 heap]에서 가장 작은 [시작 노드에서 특정 노드까지 거리] > [기존 시작 노드에서 특정 노드까지 거리]이면 건너띔
            print(dist[cur_dest][0], cur_dist) # 확인용 코드
            continue

        for new_dest, new_dist in graph[cur_dest].items(): # [특정 노드]에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]] 전부 돌기
            plus_dist = cur_dist + new_dist # [시작 노드에서 다음 특정 노드까지의 새로운 거리] = [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] + 특정 노드명에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]
            if plus_dist < dist[new_dest][0]: # [시작 노드에서 다음 특정 노드까지 거리] > [시작 노드에서 다음 특정 노드까지의 새로운 거리]라면
                # 거리 최신화
                dist[new_dest][0] = plus_dist # [시작 노드에서 다음 특정 노드까지 거리] 최신화
                # print(type(track[cur_dest])) # 확인용 코드
                # print(track[new_dest]) # 확인용 코드
                # print(track[cur_dest]) # 확인용 코드
                
                # 경로 최신화
                dist[new_dest][1] = dist[cur_dest][1][:] # [시작 노드에서 특정 노드까지 경로] 최신화 (특정 노드 이전까지 경로 얕은 복사 + 특정 노드도 경로에 추가)
                # track[cur_dest] = [] # 확인용 코드
                # print(dist[new_dest][1]) # 확인용 코드
                dist[new_dest][1].append(new_dest)
                # if(new_dest == '충무로4'): # 확인용 코드
                    # print(dist[new_dest][1])
                    
                # 환승 횟수 최신화
                if(new_dest[0:len(new_dest)-1] == cur_dest[0:len(cur_dest)-1]): # [시작 노드에서 특정 노드까지 환승 횟수] 최신화 (특정 노드 이전까지 환승 횟수 + 특정 노드도 확인 후 추가)
                    dist[new_dest][2] = dist[cur_dest][2] + 1
                    # print(new_dest, cur_dest) # 확인용 코드
                else:
                    dist[new_dest][2] = dist[cur_dest][2]
                # print(cur_dest, new_dest) # 확인용 코드
                # print(track[new_dest]) # 확인용 코드
                # print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ") # 확인용 코드
                # if(new_dest == '시청1'):
                    # print(track[new_dest]) # 확인용 코드
                heapq.heappush(queue, [plus_dist, new_dest]) # [[시작 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]을 [정보 저장 heap]에 저장

        # print("ㅡㅡfor문 돌아ㅡㅡ") # 확인용 코드
    return dist

print(dist)
# Out:
# {'소요산1': [60, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1', '보산1', '동두천1', '소요산1'], 0], '동두천1': [58, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1', '보산1', '동두천1'], 0], '보산1': [56, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1', '보산1'], 0], '동두천중앙1': [54, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1'], 0], '지행1': [52, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1'], 0], '덕정1': [50, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1'], 0], '덕계1': [48, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1'], 0], '양주1': [46, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1'], 0], '녹양1': [44, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1'], 0], '가능1': [42, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1'], 0], '의정부1': [40, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1'], 0], '회룡1': [38, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1'], 0], '망월사1': [36, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1'], 0], '도봉산1': [34, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1'], 0], '방학1': [32, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1'], 0], '창동1': [30, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1'], 0], '녹천1': [28, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1'], 0], '월계1': [26, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1'], 0], '성북1': [24, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1'], 0], '신이문1': [22, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1'], 0], '외대앞1': [20, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1'], 0], '회기1': [18, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1'], 0], '청량리1': [16, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1'], 0], '제기동1': [14, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', ...

# %%
def print_dist():
    st = input("출발지 : ")
    end = input("도착지 : ")

    dijkstra(graph, st, end)
    print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ[결과]ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
    print("배열 : ", dist[end]) # 확인용 코드
    print("거리 : ", dist[end][0], "분")
    print("경로 : ", dist[end][1])
    print("환승 횟수 : ", dist[end][2], "회")
    print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")

# %%
print_dist()
# Out:
# 출발지 : 시청1
# 도착지 : 상일동5
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ[결과]ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# 배열 :  [44, ['시청1', '시청2', '을지로입구2', '을지로3가2', '을지로4가2', '동대문역사문화공원2', '신당2', '상왕십리2', '왕십리2', '왕십리5', '마장5', '답십리5', '장한평5', '군자5', '아차산5', '광나루5', '천호5', '강동5', '길동5', '굽은다리5', '명일5', '고덕5', '상일동5'], 2]
# 거리 :  44 분
# 경로 :  ['시청1', '시청2', '을지로입구2', '을지로3가2', '을지로4가2', '동대문역사문화공원2', '신당2', '상왕십리2', '왕십리2', '왕십리5', '마장5', '답십리5', '장한평5', '군자5', '아차산5', '광나루5', '천호5', '강동5', '길동5', '굽은다리5', '명일5', '고덕5', '상일동5']
# 환승 횟수 :  2 회
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
