# %%
import pandas as pd
import numpy as np

df_sb_list = pd.read_csv('C:\\Users\\Hi\\Desktop\\자료구조\\지하철역.csv')

# %% [markdown]
# # 1. 데이터 전처리

# %% [markdown]
# ## 1) 기본

# %%
sb_list = df_sb_list.to_numpy()

# %% [markdown]
# ## 2) 양방향 Graph 전처리(nan 존재x + 호선 구별o + 중복 호선 환승 고려x)

# %%
graph = {}

# 모든 역에 대해서 전처리
for i in range(5):
    for j in range(len(sb_list)):
        
        # graph 생성 - graph 마지막 원소 전이고, 비어있지 않은 역인 경우
        if(j < len(sb_list)-1 and not pd.isna(sb_list[j+1][i]) and not pd.isna(sb_list[j][i])):
            # graph에 해당 역 존재 : 해당 역의 key, value 빼서 다시 전처리 + 다음 역 추가시킨 graph 생성
            if (sb_list[j][i] + str(i+1)) in graph:
                keys = [k for k in graph[sb_list[j][i] + str(i+1)].keys()]
                values = [v for v in graph[sb_list[j][i] + str(i+1)].values()]
                
                dic = {}
                for d in range(len(keys)):
                    dic[keys[d]] = values[d]
                dic[sb_list[j+1][i] + str(i+1)] = 2
                graph[sb_list[j][i] + str(i+1)] = dic
                
            # graph에 해당 역 존재하지 않음 : 다음 역 추가시킨 graph 생성
            else:
                graph[sb_list[j][i] + str(i+1)] = {(sb_list[j+1][i] + str(i+1)):2}       
        # graph 생성 - 비어있는 역인 경우 : 건너뛰기
        elif(pd.isna(sb_list[j][i]) == True):
            pass
        # graph 생성 - 비어있는 역 아닌 경우
        else:
            # graph에 해당 역 존재 : 건너뛰기
            if (str(sb_list[j][i]) + str(i+1)) in graph:
                pass
            # graph에 해당 역 존재하지 않음 : 빈 원소로 두기
            else:
                graph[sb_list[j][i] + str(i+1)] = {}
                
        # graph 생성 - graph 첫 번째 원소 이후이고, 비어있지 않은 역인 경우
        if(0 < j and not pd.isna(sb_list[j-1][i]) and not pd.isna(sb_list[j][i])):
            # graph에 해당 역 존재 : 해당 역의 key, value 빼서 다시 전처리 + 다음 역 추가시킨 graph 생성
            if (sb_list[j][i] + str(i+1)) in graph:
                keys = [k for k in graph[sb_list[j][i] + str(i+1)].keys()]
                values = [v for v in graph[sb_list[j][i] + str(i+1)].values()]

                dic = {}
                for d in range(len(keys)):
                    dic[keys[d]] = values[d]
                dic[sb_list[j-1][i] + str(i+1)] = 2
                graph[sb_list[j][i] + str(i+1)] = dic
            # graph에 해당 역 존재하지 않음 : 다음 역 추가시킨 graph 생성
            else:
                graph[sb_list[j][i] + str(i+1)] = {sb_list[j-1][i] + str(i+1):2}
        # graph 생성 - graph 첫번째 원소이거나, 비어있는 역인 경우 : 불가능한 경우
        else:
            pass
        
# print(graph) # 확인용 코드
# Out:
, '신림2': {'신대방2': 2, '봉천2': 2}, '신대방2': {'구로디지털단지2': 2, '신림2': 2}, '구로디지털단지2': {'대림2': 2, '신대방2': 2}, '대림2': {'신도림2': 2, '구로디지털단지2': 2}, '신도림2': {'문래2': 2, '대림2': 2}, '문래2': {'영등포구청2': 2, '신도림2': 2}, '영등포구청2': {'당산2': 2, '문래2': 2}, '당산2': {'합 ...

# %% [markdown]
# ## 3) 양방향 Graph 전처리 추가(중복 호선 환승 고려o)

# %%
graph_key = list(graph.keys())

for i in range(len(graph_key)):
    for j in range(i+1, len(graph_key)):
        if(graph_key[i][0:len(graph_key[i])-1] == graph_key[j][0:len(graph_key[j])-1]):
            keys = [k for k in graph[graph_key[i]]]
            values = [v for v in graph[graph_key[i]].values()]

            dic = {}
            for d in range(len(keys)):
                dic[keys[d]] = values[d]
            dic[graph_key[j]] = 5 # 환승 시, 거리에 가중치
            graph[graph_key[i]] = dic

            keys = [k for k in graph[graph_key[j]]]
            values = [v for v in graph[graph_key[j]].values()]

            dic = {}
            for d in range(len(keys)):
                dic[keys[d]] = values[d]
            dic[graph_key[i]] = 5 # 환승 시, 거리에 가중치
            graph[graph_key[j]] = dic
            
# print(graph) # 확인용 코드
# Out:
# {'소요산1': {'동두천1': 2}, '동두천1': {'보산1': 2, '소요산1': 2}, '보산1': {'동두천중앙1': 2, '동두천1': 2}, '동두천중앙1': {'지행1': 2, '보산1': 2}, '지행1': {'덕정1': 2, '동두천중앙1': 2}, '덕정1': {'덕계1': 2, '지행1': 2}, '덕계1': {'양주1': 2, '덕정1': 2}, '양주1': {'녹양1': 2, '덕계1': 2}, '녹양1': {'가능1': 2, '양주1': 2}, '가능1': {'의정부1': 2, '녹양1': 2}, '의정부1': {'회룡1': 2, '가능1': 2}, '회룡1': {'망월사1': 2, '의정부1': 2}, '망월사1': {'도봉산1': 2, '회룡1': 2}, '도봉산1': {'방학1': 2, '망월사1': 2}, '방학1': {'창동1': 2, '도봉산1': 2}, '창동1': {'녹천1': 2, '방학1': 2, '창동4': 5}, '녹천1': {'월계1': 2, '창동1': 2}, '월계1': {'성북1': 2, '녹천1': 2}, '성북1': {'신이문1': 2, '월계1': 2}, '신이문1': {'외대앞1': 2, '성북1': 2}, '외대앞1': {'회기1': 2, '신이문1': 2}, '회기1': {'청량리1': 2, '외대앞1': 2}, '청량리1': {'제기동1': 2, '회기1': 2}, '제기동1': {'신설동1': 2, '청량리1': 2}, '신설동1': {'동묘앞1': 2, '제기동1': 2}, '동묘앞1': {'동대문1': 2, '신설동1': 2}, '동대문1': {'종로5가1': 2, '동묘앞1': 2, '동대문4': 5}, '종로5가1': {'종로3가1': 2, '동대문1': 2}, '종로3가1': {'종각1': 2, '종로5가1': 2, '종로3가3': 5, '종로3가5': 5}, '종각1': {'시청1': 2, '종로3가1': 2}, '시청1': {'서울역1': 2, '종각1': 2, '시청2': 5}, '서울역1': {'남영1': 2, '시청1': 2
 2}, '온양온천1': {'신창1': 2, '배방1': 2}, '신창1': {'서동탄1': 2, '온양온천1': 2}, '서동탄1': {'신창1': 2}, '시청2': {'을지로입구2': 2, '충정로2': 2, '시청1': 5}, '을지로입구2': {'을지로3가2': 2, '시청2': 2}, '을지로3가2': {'을지로4가2': 2, '을지로입구2': 2, '을지로3가3': 5}, '을지로4가2': {'동대문역사문화공원2': 2, '을지로3가2': 2, '을지로4가5': 5}, '동대문역사문화공원2': {'신당2': 2, '을지로4가2': 2, '동대문역사문화공원4': 5, '동대문역사문화공원5': 5}, '신당2': {'상왕십리2': 2, '동대문역사문화공원2': 2}, '상왕십리2': {'왕십리2': 2, '신당2': 2}, '왕십리2': {'한양대2': 2, '상왕십리2': 2, '왕십리5': 5}, '한양대2': {'뚝섬2': 2, '왕십리2': 2}, '뚝섬2': {'성수2': 2, '한양대2': 2}, '성수2': {'건대입구2': 2, '뚝섬2': 2}, '건대입구2': {'구의2': 2, '성수2': 2}, '구의2': {'강변2': 2, '건대입구2': 2}, '강변2': {'잠실나루2': 2, '구의2': 2}, '잠실나루2': {'신천2': 2, '강변2': 2}, '신천2': {'종합운동장2': 2, '잠실나루2': 2}, '종합운동장2': {'삼성2': 2, '신천2': 2}, '삼성2': {'선릉2': 2, '종합운동장2': 2}, '선릉2': {'역삼2': 2, '삼성2': 2}, '역삼2': {'강남2': 2, '선릉2': 2}, '강남2': {'교대2': 2, '역삼2': 2}, '교대2': {'서초2': 2, '강남2': 2, '교대3': 5}, '서초2': {'방배2': 2, '교대2': 2}, '방배2': {'사당2': 2, '서초2': 2}, '사당2': {'낙성대2': 2, '방배2': 2, '사당4': 5}, '낙성대2': {'서울대입구2': 2, '사당2': 2}, '서울대입구2': {'봉천2': 2, '낙성대2': 2}, '봉천2': {'신림2': 2, '서울대입구2': 2}, '신림2': {'신대방2': 2, '봉천2': 2}, '신대방2': {'구로 ...

# %% [markdown]
# ## 4) 양방향 Graph 거리 계산(nan 존재x + 호선 구별o + 중복 호선 환승 고려o + 가독성 향상 + 경로 출력 + 환승 횟수 출력 + 하나의 dic으로 통일화 + 목적지까지 최소 거리 완성 시, break)

# %% [markdown]
# ## + 추가 기능(열차 방향 표시, 환승 방향 표시, 환승 적은 경로 우선, 같은 호선에선 DFS컨셉)

# %%
# 그래프 : 본인 노드 이름 : {연결된 노드 이름 : 연결된 노드까지의 거리}
# dist : 시작 노드에서 특정 노드까지 거리 + 경로 + 환승 횟수 저장 dic
# st : 시작 노드
# heap : 다음 특정 노드 저장
# plus dist : 특정 노드까지 최소 거리
# cur dist : 특정 노드까지 거리
# cur dest : 특정 노드 노드명

import heapq  # 우선순위 큐 구현을 위함

def dijkstra(graph, st, end):
    # 거리 + track + 환승횟수 초기 설정
    global dist
    dist = {node: [float('inf')] for node in graph} # [시작 노드에서 특정 노드까지 거리] : 무한대
    for node in graph:
        dist[node].append([]) # [시작 노드에서 특정 노드까지 경로] : 비어있음
        dist[node].append(0) # [시작 노드에서 특정 노드까지 환승 횟수] : 0
    dist[st][1] = [st]
    dist[st][0] = 0
    
    # heap 초기 설정
    queue = [] # [정보 저장 heap] 생성
    heapq.heappush(queue, [dist[st][0], st])  # [[시작 노드에서 시작 노드까지 거리], [시작 노드명]]를 [정보 저장 heap]에 저장

    # graph 생성
    while queue:  # heap에서 노드가 빌 때까지 반복
        cur_dist, cur_dest = heapq.heappop(queue) # [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] 빼기
        if(cur_dest == end): # 확인용 코드
            break
        
        if dist[cur_dest][0] < cur_dist: # [정보 저장 heap]에서 가장 작은 [시작 노드에서 특정 노드까지 거리] > [기존 시작 노드에서 특정 노드까지 거리]이면 건너띔
            continue

        for new_dest, new_dist in graph[cur_dest].items(): # [특정 노드]에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]] 전부 돌기
            plus_dist = cur_dist + new_dist # [시작 노드에서 다음 특정 노드까지의 새로운 거리] = [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] + 특정 노드명에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]
            if plus_dist < dist[new_dest][0]: # [시작 노드에서 다음 특정 노드까지 거리] > [시작 노드에서 다음 특정 노드까지의 새로운 거리]라면
                # 거리 최신화
                dist[new_dest][0] = plus_dist
                
                # 경로 최신화
                dist[new_dest][1] = dist[cur_dest][1][:] # [시작 노드에서 특정 노드까지 경로] 최신화 (특정 노드 이전까지 경로 얕은 복사 + 특정 노드도 경로에 추가)
                dist[new_dest][1].append(new_dest)
                    
                # 환승 횟수 최신화
                if(new_dest[0:len(new_dest)-1] == cur_dest[0:len(cur_dest)-1]): # [시작 노드에서 특정 노드까지 환승 횟수] 최신화 (특정 노드 이전까지 환승 횟수 + 특정 노드도 확인 후 추가)
                    dist[new_dest][2] = dist[cur_dest][2] + 1
                else:
                    dist[new_dest][2] = dist[cur_dest][2]
                
                if st[len(st)-1] == end[len(end)-1] and (new_dest[0:len(new_dest)-1] == cur_dest[0:len(cur_dest)-1]):
                    continue
                else:   
                    heapq.heappush(queue, [plus_dist, new_dest]) # [[시작 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]을 [정보 저장 heap]에 저장
    return dist
# Out:
# {'소요산1': [inf, [], 0], '동두천1': [inf, [], 0], '보산1': [inf, [], 0], '동두천중앙1': [inf, [], 0], '지행1': [inf, [], 0], '덕정1': [inf, [], 0], '덕계1': [48, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1'], 0], '양주1': [46, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1'], 0], '녹양1': [44, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1'], 0], '가능1': [42, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1'], 0], '의정부1': [40, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1'], 0], '회룡1': [38, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1'], 0], '망월사1': [36, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1'], 0], '도봉산1': [34, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1'], 0], '방학1': [32, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1'], 0], '창동1': [30, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1'], 0], '녹천1': [28, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1'], 0], '월계1': [26, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1'], 0], '성북1': [24, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1'], 0], '신이문1': [22, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1'], 0], '외대앞1': [20, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1'], 0], '회기1': [18, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1'], 0], '청량리1': [16, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1'], 0], '제기동1': [14, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1'], 0], '신설동1': [12, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1'], 0], '동묘앞1': [10, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1'], 0], '동대문1': [8, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1'], 0], '종로5가1': [6, ['시청1', '종각1', '종로3가1', '종로5가1'], 0], '종로3가1': [4, ['시청1', '종각1', '종로3가1'], 0], '종각1': [2, ['시청1', '종각1'], 0], '시청1': [0, ['시청1'], 0], '서울역1': [2, ['시청1', '서울역1'], 0], '남영1': [4, ['시청1', '서울역1', '남영1'], 0], '용산1': [6, ['시청1', '서울역1', '남영1', '용산1'], 0], '노량진1': [8, ['시청1', '서울역1', '남영1', '용산1', '노량진1'], 0], '대방1': [10, ['시청1', '서울역1', '남영1', '용산1', '노량진1', '대방1'], 0], '신길1': [12, ['시청1', '서울역1', '남영1', '용산1', '노량진1', '대방1', '신길1'], 0], '영등포1': [14, ['시청1', '서울역1', '남영1', '용산1', '노량진1', '대방1', '신길1', '영등포1'], 0], '신도림1': [16, ['시청1', '서울역1', '남영1', '용산1', '노량진1', '대방1', '신길1', '영등포1', '신도림1'], 0], '구로1': [18, ['시청1', '서울역1', '남영1', '용산1', '노량진1', '대방1', '신길1', '영등포1', '신도림1', '구로1'], 0], '구일1': [20, ['시청1', '서울역1', '남영1', '용산1', '노량진1', '대방1', '신길1', '영등포1', '신도림1', '구로1', '구일1'], 0], '개봉1': [22, ['시청1', '서울역1', '남영1', '용산1', '노량진1', '대방1', '신길1', '영등포1', '신도림1', '구로1', '구일1', '개봉1'], 0], '오류동1': [24, ['시청1', '서울역1', '남영1', '용산1', '노량진1', '대방1', '신길1', '영등포1', '신도림1', '구로1', '구일1', '개봉1', '오류동1'], 0], '온수1': [26, ['시청1',  ...

# %%
def print_dist_dijkstra_plus():
    st = input("출발지 : ")
    end = input("도착지 : ")

    dijkstra(graph, st, end)
    dist[end][0] -= dist[end][2]*3 #가중된 시간값 원상복귀
    
    trans = False #환승 여부 확인
    
    for i in range(len(dist[end][1])-1):
        if (dist[end][1][i][0:len(dist[end][1][i])-2] == dist[end][1][i+1][0:len(dist[end][1][i+1])-2]): #환승 여부 확인
            print("환승 방향 : ", dist[end][1][i][len(dist[end][1][i])-1], "호선 -> " ,dist[end][1][i+1][len(dist[end][1][i+1])-1], "호선으로 환승")
            trans = True
            
        if (i == 0 and trans == False) or (trans == True and not i == len(dist[end][1])-2): 
            trans = False
            print("열차 방향 : ", end = ' ')
            if int(dist[end][1][i+1][len(dist[end][1][i+1])-1]) == 1:
                if dist[end][1][1] == list(graph[st])[0]:
                    print("1호선 서동탄행")
                else:
                    print("1호선 소요산행")
            if int(dist[end][1][i+1][len(dist[end][1][i+1])-1]) == 2:
                if dist[end][1][1] == list(graph[st])[0]:
                    print("2호선 충정로행")
                else:
                    print("2호선 을지로입구행")
            if int(dist[end][1][i+1][len(dist[end][1][i+1])-1]) == 3:
                if dist[end][1][1] == list(graph[st])[0]:
                    print("3호선 오금행")
                else:
                    print("3호선 대화행")
            if int(dist[end][1][i+1][len(dist[end][1][i+1])-1]) == 4:
                if dist[end][1][1] == list(graph[st])[0]:
                    print("4호선 오이도행")
                else:
                    print("4호선 진접행")
            if int(dist[end][1][i+1][len(dist[end][1][i+1])-1]) == 5:
                if dist[end][1][1] == list(graph[st])[0]:
                    print("5호선 마천행")
                else:
                    print("5호선 방화행")
    
    print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ[결과]ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
    # print("배열 : ", dist[end]) # 확인용 코드
    print("거리 : ", dist[end][0], "분")
    print("경로 : ", dist[end][1])
    print("환승 횟수 : ", dist[end][2], "회")
    print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")

# %%
print_dist_dijkstra_plus()
# Out:
# 출발지 : 시청1
# 도착지 : 상일동5
# 열차 방향 :  1호선 소요산행
# 환승 방향 :  1 호선 ->  5 호선으로 환승
# 열차 방향 :  5호선 방화행
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ[결과]ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# 거리 :  44 분
# 경로 :  ['시청1', '종각1', '종로3가1', '종로3가5', '을지로4가5', '동대문역사문화공원5', '청구5', '신금호5', '행당5', '왕십리5', '마장5', '답십리5', '장한평5', '군자5', '아차산5', '광나루5', '천호5', '강동5', '길동5', '굽은다리5', '명일5', '고덕5', '상일동5']
# 환승 횟수 :  1 회
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ

# %%
print(dist) # 확인용 코드
# Out:
# {'소요산1': [inf, [], 0], '동두천1': [inf, [], 0], '보산1': [inf, [], 0], '동두천중앙1': [inf, [], 0], '지행1': [inf, [], 0], '덕정1': [inf, [], 0], '덕계1': [48, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1'], 0], '양주1': [46, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1'], 0], '녹양1': [44, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1'], 0], '가능1': [42, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1', '가능1'], 0], '의정부1': [40, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1', '의정부1'], 0], '회룡1': [38, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1', '회룡1'], 0], '망월사1': [36, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '망월사1'], 0], '도봉산1': [34, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1'], 0], '방학1': [32, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1'], 0], '창동1': [30, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1'], 0], '녹천1': [28, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1'], 0], '월계1': [26, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1'], 0], '성북1': [24, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1'], 0], '신이문1': [22, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1'], 0], '외대앞1': [20, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1'], 0], '회기1': [18, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1'], 0], '청량리1': [16, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1'], 0], '제기동1': [14, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1'], 0], '신설동1': [12, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1'], 0], '동묘앞1': [10, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1'], 0], '동대문1': [8, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1'], 0], '종로5가1': [6, ['시청1', '종각1', '종로3가1', '종로5가1'], 0], '종로3가1': [4, ['시청1', '종각1', '종로3가1'], 0], '종각1': [2, ['시청1', '종각1'], 0], '시청1': [0, ['시청1'], 0], '서울역1': [2, ['시청1', '서울역1'], 0], '남영1': [4, ['시청1', '서울역1', '남영1'], 0], '용산1': [6, ['시청1', '서울역1', '남영1', '용산1'], 0], '노량진1': [8, ['시청1', '서울역1', '남영1', '용산1', '노량진1'], 0], '대방1': [10, ['시청1', '서울역1', '남영1', '용산1', '노량진1', '대방1'], 0], '신길1': [12, ['시청1', '서울역1', '남영1', '용산1', '노량진1', '대방1', '신길1'], 0], '영등포1': [14, ['시청1', '서울역1', '남영1', '용산1', '노량진1', '대방1', '신길1', '영등포1'], 0], '신도림1': [16, ['시청1', '서울역1', '남영1', '용산1', '노량진1', '대방1', '신길1', '영등포1', '신도림1'], 0], '구로1': [18, ['시청1', '서울역1', '남영1', '용산1', '노량진1', '대방1', '신길1', '영등포1', '신도림1', '구로1'], 0], '구일1': [20, ['시청1', '서울역1', '남영1', '용산1', '노량진1', '대방1', '신길1', '영등포1', '신도림1', '구로1', '구일1'], 0], '개봉1': [22, ['시청1', '서울역1', '남영1', '용산1', '노량진1', '대방1', '신길1', '영등포1', '신도림1', '구로1', '구일1', '개봉1'], 0], '오류동1': [24, ['시청1', '서울역1', '남영1', '용산1', '노량진1', '대방1', '신길1', '영등포1', '신도림1', '구로1', '구일1', '개봉1', '오류동1'], 0], '온수1': [26, ['시청1',  ...
