# %%
import pandas as pd
import numpy as np

df_sb_list = pd.read_csv('C:\\Users\\Hi\\Desktop\\자료구조\\지하철역.csv')

# %% [markdown]
# # 1. 데이터 전처리

# %% [markdown]
# ## 1) 기본

# %%
df_sb_list
# Out:
#       1호선        2호선  3호선    4호선   5호선
# 0     소요산         시청   대화     진접    방화
# 1     동두천      을지로입구   주엽     오남   개화산
# 2      보산      을지로3가  정발산  별내별가람  김포공항
# 3   동두천중앙      을지로4가   마두    당고개    송정
# 4      지행  동대문역사문화공원   백석     상계    마곡
# ..    ...        ...  ...    ...   ...
# 92     아산        NaN  NaN    NaN   NaN
# 93     배방        NaN  NaN    NaN   NaN
# 94   온양온천        NaN  NaN    NaN   NaN
# 95     신창        NaN  NaN    NaN   NaN
# 96    서동탄        NaN  NaN    NaN   NaN
#
# [97 rows x 5 columns]

# %%
sb_list = df_sb_list.to_numpy()
sb_list
# Out:
# array([['소요산', '시청', '대화', '진접', '방화'],
#        ['동두천', '을지로입구', '주엽', '오남', '개화산'],
#        ['보산', '을지로3가', '정발산', '별내별가람', '김포공항'],
#        ['동두천중앙', '을지로4가', '마두', '당고개', '송정'],
#        ['지행', '동대문역사문화공원', '백석', '상계', '마곡'],
#        ['덕정', '신당', '대곡', '노원', '발산'],
#        ['덕계', '상왕십리', '화정', '창동', '우장산'],
#        ['양주', '왕십리', '원당', '쌍문', '화곡'],
#        ['녹양', '한양대', '삼송', '수유', '까치산'],
#        ['가능', '뚝섬', '지축', '미아', '신정'],
#        ['의정부', '성수', '구파발', '미아삼거리', '목동'],
#        ['회룡', '건대입구', '연신내', '길음', '오목교'],
#        ['망월사', '구의', '붕광', '성신여대입구', '양평'],
#        ['도봉', '강변', '녹번', '한성대입구', '영등포구청'],
#        ['도봉산', '잠실나루', '홍제', '혜화', '영등포시장'],
#        ['방학', '잠실나루', '무악재', '동대문', '신길'],
#        ['창동', '신천', '독립문', '동대문역사문화공원', '여의도'],
#        ['녹천', '종합운동장', '경북궁', '충무로', '여의나루'],
#        ['월계', '삼성', '안국', '명동', '마포'],
#        ['성북', '선릉', '종로3가', '회현', '공덕'],
#        ['신이문', '역삼', '을지로3가', '서울역', '애오개'],
#        ['외대앞', '강남', '충무로', '숙대입구', '충정로'],
# ...

# %%
# 데이터 개수 확인
len(sb_list)
# Out:
# 97

# %%
# 환승역 확인
for k in range(0, 5):
    for u in range(k+1, 5):
        for i in range(len(sb_list)):
            for j in range(len(sb_list)):
                if sb_list[i][k] == sb_list[j][u]:
                    print("ㅡㅡㅡ환승역 :", sb_list[i][k], "ㅡㅡㅡ")
                    print(k+1, "호선 <->", u+1, "호선" )
                    print("행1, 행2, 호선1, 호선2 :", i+1, j+1, k+1, u+1)
# Out:
# ㅡㅡㅡ환승역 : 시청 ㅡㅡㅡ
# 1 호선 <-> 2 호선
# 행1, 행2, 호선1, 호선2 : 32 1 1 2
# ㅡㅡㅡ환승역 : 시청 ㅡㅡㅡ
# 1 호선 <-> 2 호선
# 행1, 행2, 호선1, 호선2 : 32 44 1 2
# ㅡㅡㅡ환승역 : 신도림 ㅡㅡㅡ
# 1 호선 <-> 2 호선
# 행1, 행2, 호선1, 호선2 : 40 34 1 2
# ㅡㅡㅡ환승역 : 종로3가 ㅡㅡㅡ
# 1 호선 <-> 3 호선
# 행1, 행2, 호선1, 호선2 : 30 20 1 3
# ㅡㅡㅡ환승역 : 창동 ㅡㅡㅡ
# 1 호선 <-> 4 호선
# 행1, 행2, 호선1, 호선2 : 17 7 1 4
# ㅡㅡㅡ환승역 : 동대문 ㅡㅡㅡ
# 1 호선 <-> 4 호선
# 행1, 행2, 호선1, 호선2 : 28 16 1 4
# ㅡㅡㅡ환승역 : 서울역 ㅡㅡㅡ
# 1 호선 <-> 4 호선
# 행1, 행2, 호선1, 호선2 : 33 21 1 4
# ㅡㅡㅡ환승역 : 금정 ㅡㅡㅡ
# 1 호선 <-> 4 호선
# 행1, 행2, 호선1, 호선2 : 70 38 1 4
# ㅡㅡㅡ환승역 : 종로3가 ㅡㅡㅡ
# 1 호선 <-> 5 호선
# 행1, 행2, 호선1, 호선2 : 30 25 1 5
# ㅡㅡㅡ환승역 : 신길 ㅡㅡㅡ
# 1 호선 <-> 5 호선
# 행1, 행2, 호선1, 호선2 : 38 16 1 5
# ㅡㅡㅡ환승역 : 을지로3가 ㅡㅡㅡ
# 2 호선 <-> 3 호선
# 행1, 행2, 호선1, 호선2 : 3 21 2 3
# ㅡㅡㅡ환승역 : 교대 ㅡㅡㅡ
# 2 호선 <-> 3 호선
# 행1, 행2, 호선1, 호선2 : 23 31 2 3
# ㅡㅡㅡ환승역 : 동대문역사문화공원 ㅡㅡㅡ
# 2 호선 <-> 4 호선
# 행1, 행2, 호선1, 호선2 : 5 17 2 4
# ㅡㅡㅡ환승역 : 사당 ㅡㅡㅡ
# 2 호선 <-> 4 호선
# 행1, 행2, 호선1, 호선2 : 26 28 2 4
# ㅡㅡㅡ환승역 : 을지로4가 ㅡㅡㅡ
# 2 호선 <-> 5 호선
# 행1, 행2, 호선1, 호선2 : 4 26 2 5
# ...

# %%
# 1호선 확인
for i in range(len(sb_list)):
    print(sb_list[i][0])
# Out:
# 소요산
# 동두천
# 보산
# 동두천중앙
# 지행
# 덕정
# 덕계
# 양주
# 녹양
# 가능
# 의정부
# 회룡
# 망월사
# 도봉
# 도봉산
# 방학
# 창동
# 녹천
# 월계
# 성북
# 신이문
# 외대앞
# 회기
# 청량리
# 제기동
# 신설동
# 동묘앞
# 동대문
# 종로5가
# 종로3가
# 종각
# 시청
# 서울역
# 남영
# 용산
# 노량진
# 대방
# 신길
# 영등포
# 신도림
# 구로
# 구일
# 개봉
# 오류동
# 온수
# 역곡
# 소사
# 부천
# 중동
# 송내
# 부개
# 부평
# 백운
# 동암
# 간석
# 주안
# 도화
# 제물포
# 도원
# 동인천
# 인천
# 광명
# 가산디지털단지
# 독산
# 금천구청
# 석수
# 관악
# 안양
# 명학
# 금정
# 군포
# 당정
# 의왕
# 성균관대
# 화서
# 수원
# 세류
# 병점
# 세마
# 오산대
# 오산대
# 진위
# 송탄
# 서정리
# 지제
# 평택
# 성환
# 직산
# 두정
# 천안
# 봉명
# 쌍용
# 아산
# 배방
# 온양온천
# 신창
# 서동탄

# %% [markdown]
# ## 테스트

# %%
pd.isna(sb_list[1][1])
# Out:
# False

# %%
sb_list[1][1]
# Out:
# '을지로입구'

# %%
graph = {"0":{"00":2}}

# %%
graph
# Out:
# {'0': {'00': 2}}

# %%
graph.get("0")
# Out:
# {'00': 2}

# %%
graph["1"] = {"11":2, "12":2, "13":2}

# %%
graph
# Out:
# {'0': {'00': 2}, '1': {'11': 2, '12': 2, '13': 2}}

# %%
graph.keys()
# Out:
# dict_keys(['0', '1'])

# %%
graph.values()
# Out:
# dict_values([{'00': 2}, {'11': 2, '12': 2, '13': 2}])

# %%
for i in graph.keys():
    print(i)
for i in graph.values():
    print(i)
# Out:
# 0
# 1
# {'00': 2}
# {'11': 2, '12': 2, '13': 2}

# %%
len(graph["0"])
# Out:
# 1

# %%
[i for i in graph["0"].values()]
# Out:
# [2]

# %%
keys = [i for i in graph["1"].keys()]
print(keys)
values = [i for i in graph["1"].values()]
print(values)
dic = {}
for i in range(len(keys)):
    dic[keys[i]] = values[i]
dic['14'] = 2
graph["2"] = dic
# Out:
# ['11', '12', '13']
# [2, 2, 2]

# %%
graph
# Out:
# {'0': {'00': 2},
#  '1': {'11': 2, '12': 2, '13': 2},
#  '2': {'11': 2, '12': 2, '13': 2, '14': 2}}

# %% [markdown]
# ## 2) 단방향 Graph 전처리

# %%
graph = {}

# print(graph) # 확인용 코드

for i in range(5):
    # print(i) # 확인용 코드
    for j in range(len(sb_list)):
        # print(j) # 확인용 코드
        if(j < len(sb_list)-1 and not pd.isna(sb_list[j+1][i]) and not pd.isna(sb_list[j][i])):
            if sb_list[j][i] in graph:
                # print(sb_list[j][i]) # 확인용 코드
                keys = [k for k in graph[sb_list[j][i]].keys()]
                # print(key) # 확인용 코드
                values = [v for v in graph[sb_list[j][i]].values()]
                # print(values) # 확인용 코드
                dic = {}
                for d in range(len(keys)):
                    dic[keys[d]] = values[d]
                dic[sb_list[j+1][i]] = 2
                graph[sb_list[j][i]] = dic
                # graph[sb_list[j][i]] = {graph.get(sb_list[j][i]), sb_list[j+1][i]:2}
            else:
                graph[sb_list[j][i]] = {sb_list[j+1][i]:2}
        else:
            graph[sb_list[j][i]] = {}
        
graph['시청'] = {'을지로입구':2}
print(graph)
# Out:
# {'소요산': {'동두천': 2}, '동두천': {'보산': 2}, '보산': {'동두천중앙': 2}, '동두천중앙': {'지행': 2}, '지행': {'덕정': 2}, '덕정': {'덕계': 2}, '덕계': {'양주': 2}, '양주': {'녹양': 2}, '녹양': {'가능': 2}, '가능': {'의정부': 2}, '의정부': {'회룡': 2}, '회룡': {'망월사': 2}, '망월사': {'도봉': 2}, '도봉': {'도봉산': 2}, '도봉산': {'방학': 2}, '방학': {'창동': 2}, '창동': {'녹천': 2, '쌍문': 2}, '녹천': {'월계': 2}, '월계': {'성북': 2}, '성북': {'신이문': 2}, '신이문': {'외대앞': 2}, '외대앞': {'회기': 2}, '회기': {'청량리': 2}, '청량리': {'제기동': 2}, '제기동': {'신설동': 2}, '신설동': {'동묘앞': 2}, '동묘앞': {'동대문': 2}, '동대문': {'종로5가': 2, '동대문역사문화공원': 2}, '종로5가': {'종로3가': 2}, '종로3가': {'종각': 2, '을지로3가': 2, '을지로4가': 2}, '종각': {'시청': 2}, '시청': {'을지로입구': 2}, '서울역': {'남영': 2, '숙대입구': 2}, '남영': {'용산': 2}, '용산': {'노량진': 2}, '노량진': {'대방': 2}, '대방': {'신길': 2}, '신길': {'영등포': 2, '여의도': 2}, '영등포': {'신도림': 2}, '신도림': {'구로': 2, '문래': 2}, '구로': {'구일': 2}, '구일': {'개봉': 2}, '개봉': {'오류동': 2}, '오류동': {'온수': 2}, '온수': {'역곡': 2}, '역곡': {'소사': 2}, '소사': {'부천': 2}, '부천': {'중동': 2}, '중동': {'송내': 2}, '송내': {'부개': 2}, '부개': {'부평': 2}, '부
# ...

# %% [markdown]
# ## 2) 단방향 Graph 거리 계산

# %%
# 그래프 : 본인 노드 이름 : {연결된 노드 이름 : 연결된 노드까지의 거리}
# distances : 시작 노드에서 특정 노드까지 거리 저장 dic
# start : 시작 노드
# heap : 다음 특정 노드 저장
# distance : 특정 노드까지 최소 거리
# current distance : 특정 노드까지 거리
# current destination : 특정 노드 노드명

import heapq  # 우선순위 큐 구현을 위함

def dijkstra(graph, start):
    # 초기값
    distances = {node: float('inf') for node in graph} # [시작 노드에서 특정 노드까지 거리] : 무한대
    distances[start] = 0 # [시작 노드에서 시작 노드까지 거리] : 0
    # print(distances) # 확인용 코드
    queue = [] # [정보 저장 heap] 생성
    heapq.heappush(queue, [distances[start], start])  # [[시작 노드에서 시작 노드까지 거리], [시작 노드명]]를 [정보 저장 heap]에 저장
    # print(distances[start], start) # 확인용 코드

    # graph 생성
    while queue:  # heap에서 노드가 빌 때까지 반복
        current_distance, current_destination = heapq.heappop(queue) # [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] 빼기
        # print(current_distance, current_destination)
        if distances[current_destination] < current_distance: # 가장 작은 [시작 노드에서 특정 노드까지 거리]가 [기존 시작 노드에서 특정 노드까지 거리]보다 크면 건너띔
            print(distances[current_destination], current_distance) # 확인용 코드
            continue

        for new_destination, new_distance in graph[current_destination].items(): # [특정 노드]에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]] 전부 돌기
            distance = current_distance + new_distance # [시작 노드에서 다음 특정 노드까지의 새로운 거리] = [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] + 특정 노드명에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]
            if distance < distances[new_destination]: # [시작 노드에서 다음 특정 노드까지 거리] > [시작 노드에서 다음 특정 노드까지의 새로운 거리]라면
                # 거리 최신화
                distances[new_destination] = distance # [시작 노드에서 다음 특정 노드까지 거리] 최신화
                heapq.heappush(queue, [distance, new_destination]) # [[시작 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]을 [정보 저장 heap]에 저장

    return distances

print(dijkstra(graph, '소요산'))
# Out:
# {'소요산': 0, '동두천': 2, '보산': 4, '동두천중앙': 6, '지행': 8, '덕정': 10, '덕계': 12, '양주': 14, '녹양': 16, '가능': 18, '의정부': 20, '회룡': 22, '망월사': 24, '도봉': 26, '도봉산': 28, '방학': 30, '창동': 32, '녹천': 34, '월계': 36, '성북': 38, '신이문': 40, '외대앞': 42, '회기': 44, '청량리': 46, '제기동': 48, '신설동': 50, '동묘앞': 52, '동대문': 50, '종로5가': 52, '종로3가': 54, '종각': 56, '시청': 58, '서울역': 60, '남영': 62, '용산': 64, '노량진': 66, '대방': 68, '신길': 70, '영등포': 72, '신도림': 74, '구로': 76, '구일': 78, '개봉': 80, '오류동': 82, '온수': 84, '역곡': 86, '소사': 88, '부천': 90, '중동': 92, '송내': 94, '부개': 96, '부평': 98, '백운': 100, '동암': 102, '간석': 104, '주안': 106, '도화': 108, '제물포': 110, '도원': 112, '동인천': 114, '인천': 116, '광명': 118, '가산디지털단지': 120, '독산': 122, '금천구청': 124, '석수': 126, '관악': 128, '안양': 130, '명학': 132, '금정': 94, '군포': 96, '당정': 98, '의왕': 100, '성균관대': 102, '화서': 104, '수원': 106, '세류': 108, '병점': 110, '세마': 112, '오산대': 114, '진위': 116, '송탄': 118, '서정리': 120, '지제': 122, '평택': 124, '성환': 126, '직산': 128, '두정': 130, '천안': 132, '봉명': 134, '쌍용': 136, '아산': 138, '배방': 14
# ...

# %% [markdown]
# ## 3) 양방향 Graph 전처리(nan 존재o+호선 구별x + 중복 호선 환승 고려x)

# %%
graph = {}

# print(graph) # 확인용 코드

# 모든 역에 대해서 전처리
for i in range(5):
    # print(i) # 확인용 코드
    for j in range(len(sb_list)):
        # print(j) # 확인용 코드
        
        # graph 생성 - graph 마지막 원소 전이고, 비어있지 않은 역인 경우
        if(j < len(sb_list)-1 and not pd.isna(sb_list[j+1][i]) and not pd.isna(sb_list[j][i])):
            # graph에 해당 역 존재 : 해당 역의 key, value 빼서 다시 전처리 + 다음 역 추가시킨 graph 생성
            if sb_list[j][i] in graph:
                # print(sb_list[j][i]) # 확인용 코드
                keys = [k for k in graph[sb_list[j][i]].keys()]
                # print(key) # 확인용 코드
                values = [v for v in graph[sb_list[j][i]].values()]
                # print(values) # 확인용 코드
                dic = {}
                for d in range(len(keys)):
                    dic[keys[d]] = values[d]
                dic[sb_list[j+1][i]] = 2
                graph[sb_list[j][i]] = dic
                # graph[sb_list[j][i]] = {graph.get(sb_list[j][i]), sb_list[j+1][i]:2}
                
            # graph에 해당 역 존재하지 않음 : 다음 역 추가시킨 graph 생성
            else:
                graph[sb_list[j][i]] = {sb_list[j+1][i]:2}
        # graph 생성 - graph 마지막 원소이거나, 비어있는 역인 경우
        else:
            # graph에 해당 역 존재 : 건너뛰기
            if sb_list[j][i] in graph:
                pass
            # graph에 해당 역 존재하지 않음 : 빈 원소로 두기
            else:
                graph[sb_list[j][i]] = {}

        # graph 생성 - graph 첫 번째 원소 이후이고, 비어있지 않은 역인 경우
        if(0 < j and not pd.isna(sb_list[j-1][i]) and not pd.isna(sb_list[j][i])):
            # graph에 해당 역 존재 : 해당 역의 key, value 빼서 다시 전처리 + 다음 역 추가시킨 graph 생성
            if sb_list[j][i] in graph:
                # print(sb_list[j][i]) # 확인용 코드
                keys = [k for k in graph[sb_list[j][i]].keys()]
                # print(key) # 확인용 코드
                values = [v for v in graph[sb_list[j][i]].values()]
                # print(values) # 확인용 코드
                dic = {}
                for d in range(len(keys)):
                    dic[keys[d]] = values[d]
                dic[sb_list[j-1][i]] = 2
                graph[sb_list[j][i]] = dic
                # graph[sb_list[j][i]] = {graph.get(sb_list[j][i]), sb_list[j+1][i]:2}
                '''if(sb_list[j][i] == '시청'): # 확인용 코드
                    print(keys)
                    print(graph[sb_list[j][i]])'''
            # graph에 해당 역 존재하지 않음 : 다음 역 추가시킨 graph 생성
            else:
                graph[sb_list[j][i]] = {sb_list[j-1][i]:2}
        # graph 생성 - graph 첫번째 원소이거나, 비어있는 역인 경우 : 불가능한 경우
        else:
            pass
        
print(graph)
# Out:
# {'소요산': {'동두천': 2}, '동두천': {'보산': 2, '소요산': 2}, '보산': {'동두천중앙': 2, '동두천': 2}, '동두천중앙': {'지행': 2, '보산': 2}, '지행': {'덕정': 2, '동두천중앙': 2}, '덕정': {'덕계': 2, '지행': 2}, '덕계': {'양주': 2, '덕정': 2}, '양주': {'녹양': 2, '덕계': 2}, '녹양': {'가능': 2, '양주': 2}, '가능': {'의정부': 2, '녹양': 2}, '의정부': {'회룡': 2, '가능': 2}, '회룡': {'망월사': 2, '의정부': 2}, '망월사': {'도봉': 2, '회룡': 2}, '도봉': {'도봉산': 2, '망월사': 2}, '도봉산': {'방학': 2, '도봉': 2}, '방학': {'창동': 2, '도봉산': 2}, '창동': {'녹천': 2, '방학': 2, '쌍문': 2, '노원': 2}, '녹천': {'월계': 2, '창동': 2}, '월계': {'성북': 2, '녹천': 2}, '성북': {'신이문': 2, '월계': 2}, '신이문': {'외대앞': 2, '성북': 2}, '외대앞': {'회기': 2, '신이문': 2}, '회기': {'청량리': 2, '외대앞': 2}, '청량리': {'제기동': 2, '회기': 2}, '제기동': {'신설동': 2, '청량리': 2}, '신설동': {'동묘앞': 2, '제기동': 2}, '동묘앞': {'동대문': 2, '신설동': 2}, '동대문': {'종로5가': 2, '동묘앞': 2, '동대문역사문화공원': 2, '혜화': 2}, '종로5가': {'종로3가': 2, '동대문': 2}, '종로3가': {'종각': 2, '종로5가': 2, '을지로3가': 2, '안국': 2, '을지로4가': 2, '광화문': 2}, '종각': {'시청': 2, '종로3가': 2}, '시청': {'서울역': 2, '종각': 2, '을지로입구': 2, '충정로': 2}, '서울역': {'
# ...

# %% [markdown]
# ## 3) 양방향 Graph 거리 계산(nan 존재o+호선 구별x + 중복 호선 환승 고려x)

# %%
# 그래프 : 본인 노드 이름 : {연결된 노드 이름 : 연결된 노드까지의 거리}
# distances : 시작 노드에서 특정 노드까지 거리 저장 dic
# start : 시작 노드
# heap : 다음 특정 노드 저장
# distance : 특정 노드까지 최소 거리
# current distance : 특정 노드까지 거리
# current destination : 특정 노드 노드명

import heapq  # 우선순위 큐 구현을 위함

def dijkstra(graph, start):
    # 거리 초기 설정
    distances = {node: float('inf') for node in graph} # [시작 노드에서 특정 노드까지 거리] : 무한대
    distances[start] = 0 # [시작 노드에서 시작 노드까지 거리] : 0
    # print(distances) # 확인용 코드
    queue = [] # [정보 저장 heap] 생성
    heapq.heappush(queue, [distances[start], start])  # [[시작 노드에서 시작 노드까지 거리], [시작 노드명]]를 [정보 저장 heap]에 저장
    # print(distances[start], start) # 확인용 코드

    # graph 생성
    while queue:  # heap에서 노드가 빌 때까지 반복
        current_distance, current_destination = heapq.heappop(queue) # [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] 빼기
        # print(current_distance, current_destination)
        if distances[current_destination] < current_distance: # [정보 저장 heap]에서 가장 작은 [시작 노드에서 특정 노드까지 거리] > [기존 시작 노드에서 특정 노드까지 거리]이면 건너띔
            print(distances[current_destination], current_distance) # 확인용 코드
            continue

        for new_destination, new_distance in graph[current_destination].items(): # [특정 노드]에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]] 전부 돌기
            distance = current_distance + new_distance # [시작 노드에서 다음 특정 노드까지의 새로운 거리] = [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] + 특정 노드명에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]
            if distance < distances[new_destination]: # [시작 노드에서 다음 특정 노드까지 거리] > [시작 노드에서 다음 특정 노드까지의 새로운 거리]라면
                # 거리 최신화
                distances[new_destination] = distance # [시작 노드에서 다음 특정 노드까지 거리] 최신화
                heapq.heappush(queue, [distance, new_destination]) # [[시작 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]을 [정보 저장 heap]에 저장

    return distances

dijkstra(graph, '시청1')
# Out:
# {'소요산1': 62,
#  '동두천1': 60,
#  '보산1': 58,
#  '동두천중앙1': 56,
#  '지행1': 54,
#  '덕정1': 52,
#  '덕계1': 50,
#  '양주1': 48,
#  '녹양1': 46,
#  '가능1': 44,
#  '의정부1': 42,
#  '회룡1': 40,
#  '망월사1': 38,
#  '도봉1': 36,
#  '도봉산1': 34,
#  '방학1': 32,
#  '창동1': 30,
#  '녹천1': 28,
#  '월계1': 26,
#  '성북1': 24,
#  '신이문1': 22,
#  '외대앞1': 20,
#  '회기1': 18,
#  '청량리1': 16,
#  '제기동1': 14,
#  '신설동1': 12,
#  '동묘앞1': 10,
#  '동대문1': 8,
#  '종로5가1': 6,
#  '종로3가1': 4,
#  '종각1': 2,
#  '시청1': 0,
#  '서울역1': 2,
#  '남영1': 4,
#  '용산1': 6,
#  '노량진1': 8,
#  '대방1': 10,
#  '신길1': 12,
#  '영등포1': 14,
#  '신도림1': 16,
#  '구로1': 18,
#  '구일1': 20,
#  '개봉1': 22,
#  '오류동1': 24,
#  '온수1': 26,
#  '역곡1': 28,
#  '소사1': 30,
#  '부천1': 32,
#  '중동1': 34,
#  '송내1': 36,
#  '부개1': 38,
#  '부평1': 40,
#  '백운1': 42,
#  '동암1': 44,
#  '간석1': 46,
#  '주안1': 48,
#  '도화1': 50,
#  '제물포1': 52,
#  '도원1': 54,
#  '동인천1': 56,
#  '인천1': 58,
#  '광명1': 56,
#  '가산디지털단지1': 54,
#  '독산1': 52,
#  '금천구청1': 50,
#  '석수1': 48,
#  '관악1': 46,
#  '안양1': 44,
#  '명학1': 42,
# ...

# %% [markdown]
# ## 4) 양방향 Graph 전처리(nan 존재x+호선 구별x + 중복 호선 환승 고려x)

# %%
graph = {}

# print(graph) # 확인용 코드

# 모든 역에 대해서 전처리
for i in range(5):
    # print(i) # 확인용 코드
    for j in range(len(sb_list)):
        # print(j) # 확인용 코드
        
        # graph 생성 - graph 마지막 원소 전이고, 비어있지 않은 역인 경우
        if(j < len(sb_list)-1 and not pd.isna(sb_list[j+1][i]) and not pd.isna(sb_list[j][i])):
            # graph에 해당 역 존재 : 해당 역의 key, value 빼서 다시 전처리 + 다음 역 추가시킨 graph 생성
            if sb_list[j][i] in graph:
                # print(sb_list[j][i]) # 확인용 코드
                keys = [k for k in graph[sb_list[j][i]].keys()]
                # print(key) # 확인용 코드
                values = [v for v in graph[sb_list[j][i]].values()]
                # print(values) # 확인용 코드
                dic = {}
                for d in range(len(keys)):
                    dic[keys[d]] = values[d]
                dic[sb_list[j+1][i]] = 2
                graph[sb_list[j][i]] = dic
                # graph[sb_list[j][i]] = {graph.get(sb_list[j][i]), sb_list[j+1][i]:2}
                
            # graph에 해당 역 존재하지 않음 : 다음 역 추가시킨 graph 생성
            else:
                graph[sb_list[j][i]] = {sb_list[j+1][i]:2}
        # graph 생성 - 비어있는 역인 경우 : 건너뛰기
        elif(pd.isna(sb_list[j][i]) == True):
            pass
        # graph 생성 - 비어있는 역 아닌 경우
        else:
            # graph에 해당 역 존재 : 건너뛰기
            if sb_list[j][i] in graph:
                pass
            # graph에 해당 역 존재하지 않음 : 빈 원소로 두기
            else:
                graph[sb_list[j][i]] = {}
                print(sb_list[j][i]) # 확인용 코드

        # graph 생성 - graph 첫 번째 원소 이후이고, 비어있지 않은 역인 경우
        if(0 < j and not pd.isna(sb_list[j-1][i]) and not pd.isna(sb_list[j][i])):
            # graph에 해당 역 존재 : 해당 역의 key, value 빼서 다시 전처리 + 다음 역 추가시킨 graph 생성
            if sb_list[j][i] in graph:
                # print(sb_list[j][i]) # 확인용 코드
                keys = [k for k in graph[sb_list[j][i]].keys()]
                # print(key) # 확인용 코드
                values = [v for v in graph[sb_list[j][i]].values()]
                # print(values) # 확인용 코드
                dic = {}
                for d in range(len(keys)):
                    dic[keys[d]] = values[d]
                dic[sb_list[j-1][i]] = 2
                graph[sb_list[j][i]] = dic
                # graph[sb_list[j][i]] = {graph.get(sb_list[j][i]), sb_list[j+1][i]:2}
                '''if(sb_list[j][i] == '시청'): # 확인용 코드
                    print(keys)
                    print(graph[sb_list[j][i]])'''
            # graph에 해당 역 존재하지 않음 : 다음 역 추가시킨 graph 생성
            else:
                graph[sb_list[j][i]] = {sb_list[j-1][i]:2}
        # graph 생성 - graph 첫번째 원소이거나, 비어있는 역인 경우 : 불가능한 경우
        else:
            pass
        
print(graph)
# Out:
# 서동탄
# 오금
# 오이도
# 마천
# ...

# %% [markdown]
# ## 4) 양방향 Graph 거리 계산(nan 존재x+호선 구별x + 중복 호선 환승 고려x)

# %%
# 그래프 : 본인 노드 이름 : {연결된 노드 이름 : 연결된 노드까지의 거리}
# distances : 시작 노드에서 특정 노드까지 거리 저장 dic
# start : 시작 노드
# heap : 다음 특정 노드 저장
# distance : 특정 노드까지 최소 거리
# current distance : 특정 노드까지 거리
# current destination : 특정 노드 노드명

import heapq  # 우선순위 큐 구현을 위함

def dijkstra(graph, start):
    # 거리 초기 설정
    distances = {node: float('inf') for node in graph} # [시작 노드에서 특정 노드까지 거리] : 무한대
    distances[start] = 0 # [시작 노드에서 시작 노드까지 거리] : 0
    # print(distances) # 확인용 코드
    queue = [] # [정보 저장 heap] 생성
    heapq.heappush(queue, [distances[start], start])  # [[시작 노드에서 시작 노드까지 거리], [시작 노드명]]를 [정보 저장 heap]에 저장
    # print(distances[start], start) # 확인용 코드

    # graph 생성
    while queue:  # heap에서 노드가 빌 때까지 반복
        current_distance, current_destination = heapq.heappop(queue) # [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] 빼기
        # print(current_distance, current_destination)
        if distances[current_destination] < current_distance: # [정보 저장 heap]에서 가장 작은 [시작 노드에서 특정 노드까지 거리] > [기존 시작 노드에서 특정 노드까지 거리]이면 건너띔
            print(distances[current_destination], current_distance) # 확인용 코드
            continue

        for new_destination, new_distance in graph[current_destination].items(): # [특정 노드]에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]] 전부 돌기
            distance = current_distance + new_distance # [시작 노드에서 다음 특정 노드까지의 새로운 거리] = [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] + 특정 노드명에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]
            if distance < distances[new_destination]: # [시작 노드에서 다음 특정 노드까지 거리] > [시작 노드에서 다음 특정 노드까지의 새로운 거리]라면
                # 거리 최신화
                distances[new_destination] = distance # [시작 노드에서 다음 특정 노드까지 거리] 최신화
                heapq.heappush(queue, [distance, new_destination]) # [[시작 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]을 [정보 저장 heap]에 저장

    return distances

dijkstra(graph, '시청')
# Out:
# {'소요산': 58,
#  '동두천': 56,
#  '보산': 54,
#  '동두천중앙': 52,
#  '지행': 50,
#  '덕정': 48,
#  '덕계': 46,
#  '양주': 44,
#  '녹양': 42,
#  '가능': 40,
#  '의정부': 38,
#  '회룡': 36,
#  '망월사': 34,
#  '도봉': 32,
#  '도봉산': 30,
#  '방학': 28,
#  '창동': 26,
#  '녹천': 28,
#  '월계': 26,
#  '성북': 24,
#  '신이문': 22,
#  '외대앞': 20,
#  '회기': 18,
#  '청량리': 16,
#  '제기동': 14,
#  '신설동': 12,
#  '동묘앞': 10,
#  '동대문': 8,
#  '종로5가': 6,
#  '종로3가': 4,
#  '종각': 2,
#  '시청': 0,
#  '서울역': 2,
#  '남영': 4,
#  '용산': 6,
#  '노량진': 8,
#  '대방': 10,
#  '신길': 12,
#  '영등포': 14,
#  '신도림': 16,
#  '구로': 18,
#  '구일': 20,
#  '개봉': 22,
#  '오류동': 24,
#  '온수': 26,
#  '역곡': 28,
#  '소사': 30,
#  '부천': 32,
#  '중동': 34,
#  '송내': 36,
#  '부개': 38,
#  '부평': 40,
#  '백운': 42,
#  '동암': 44,
#  '간석': 46,
#  '주안': 48,
#  '도화': 50,
#  '제물포': 52,
#  '도원': 54,
#  '동인천': 56,
#  '인천': 54,
#  '광명': 52,
#  '가산디지털단지': 50,
#  '독산': 48,
#  '금천구청': 46,
#  '석수': 44,
#  '관악': 42,
#  '안양': 40,
#  '명학': 38,
#  '금정': 36,
#  '군포': 38,
#  '당정': 40,
#  '의왕': 42,
#  '성균관대': 44,
# ...

# %% [markdown]
# ## 테스트

# %%
print("sb_list[1][1] : ", sb_list[1][1])
print("sb_list[1][1] : ", sb_list[1][1] + str(0))
# Out:
# sb_list[1][1] :  을지로입구
# sb_list[1][1] :  을지로입구0

# %%
print(len(graph))
for i in graph:
    print(i)
    print(i[0:len(i)-1])
# Out:
# 261
# 소요산
# 소요
# 동두천
# 동두
# 보산
# 보
# 동두천중앙
# 동두천중
# 지행
# 지
# 덕정
# 덕
# 덕계
# 덕
# 양주
# 양
# 녹양
# 녹
# 가능
# 가
# 의정부
# 의정
# 회룡
# 회
# 망월사
# 망월
# 도봉
# 도
# 도봉산
# 도봉
# 방학
# 방
# 창동
# 창
# 녹천
# 녹
# 월계
# 월
# 성북
# 성
# 신이문
# 신이
# 외대앞
# 외대
# 회기
# 회
# 청량리
# 청량
# 제기동
# 제기
# 신설동
# 신설
# 동묘앞
# 동묘
# 동대문
# 동대
# 종로5가
# 종로5
# 종로3가
# 종로3
# 종각
# 종
# 시청
# 시
# 서울역
# 서울
# 남영
# 남
# 용산
# 용
# 노량진
# 노량
# 대방
# 대
# 신길
# 신
# 영등포
# 영등
# 신도림
# 신도
# 구로
# 구
# 구일
# 구
# 개봉
# 개
# 오류동
# 오류
# 온수
# 온
# 역곡
# 역
# 소사
# 소
# 부천
# 부
# 중동
# 중
# 송내
# 송
# 부개
# 부
# 부평
# 부
# 백운
# 백
# 동암
# 동
# 간석
# 간
# 주안
# 주
# 도화
# 도
# 제물포
# 제물
# 도원
# 도
# 동인천
# 동인
# 인천
# 인
# 광명
# 광
# 가산디지털단지
# 가산디지털단
# 독산
# 독
# 금천구청
# 금천구
# 석수
# 석
# 관악
# 관
# 안양
# 안
# 명학
# 명
# 금정
# 금
# 군포
# 군
# 당정
# 당
# 의왕
# 의
# 성균관대
# 성균관
# 화서
# 화
# 수원
# 수
# 세류
# 세
# 병점
# 병
# 세마
# 세
# 오산대
# 오산
# 진위
# 진
# 송탄
# 송
# 서정리
# 서정
# 지제
# 지
# 평택
# 평
# 성환
# 성
# 직산
# 직
# 두정
# 두
# 천안
# 천
# 봉명
# 봉
# 쌍용
# 쌍
# 아산
# 아
# 배방
# 배
# 온양온천
# 온양온
# 신창
# 신
# 서동탄
# 서동
# 을지로입구
# 을지로입
# 을지로3가
# 을지로3
# 을지로4가
# 을지로4
# ...

# %% [markdown]
# ## 5) 양방향 Graph 전처리(nan 존재x + 호선 구별o + 중복 호선 환승 고려x)

# %%
graph = {}

# print(graph) # 확인용 코드

# 모든 역에 대해서 전처리
for i in range(5):
    # print(i) # 확인용 코드
    for j in range(len(sb_list)):
        # print(j) # 확인용 코드
        
        # graph 생성 - graph 마지막 원소 전이고, 비어있지 않은 역인 경우
        if(j < len(sb_list)-1 and not pd.isna(sb_list[j+1][i]) and not pd.isna(sb_list[j][i])):
            # graph에 해당 역 존재 : 해당 역의 key, value 빼서 다시 전처리 + 다음 역 추가시킨 graph 생성
            if (sb_list[j][i] + str(i+1)) in graph:
                # print(sb_list[j][i]) # 확인용 코드
                keys = [k for k in graph[sb_list[j][i] + str(i+1)].keys()]
                # print(key) # 확인용 코드
                values = [v for v in graph[sb_list[j][i] + str(i+1)].values()]
                # print(values) # 확인용 코드
                dic = {}
                for d in range(len(keys)):
                    dic[keys[d]] = values[d]
                dic[sb_list[j+1][i] + str(i+1)] = 2
                graph[sb_list[j][i] + str(i+1)] = dic
                # graph[sb_list[j][i]] = {graph.get(sb_list[j][i]), sb_list[j+1][i]:2}
                
            # graph에 해당 역 존재하지 않음 : 다음 역 추가시킨 graph 생성
            else:
                graph[sb_list[j][i] + str(i+1)] = {(sb_list[j+1][i] + str(i+1)):2}       
        # graph 생성 - 비어있는 역인 경우 : 건너뛰기
        elif(pd.isna(sb_list[j][i]) == True):
            pass
        # graph 생성 - 비어있는 역 아닌 경우
        else:
            # graph에 해당 역 존재 : 건너뛰기
            if (str(sb_list[j][i]) + str(i+1)) in graph:
                pass
            # graph에 해당 역 존재하지 않음 : 빈 원소로 두기
            else:
                graph[sb_list[j][i] + str(i+1)] = {}
                print(sb_list[j][i] + str(i+1)) # 확인용 코드
                
        # graph 생성 - graph 첫 번째 원소 이후이고, 비어있지 않은 역인 경우
        if(0 < j and not pd.isna(sb_list[j-1][i]) and not pd.isna(sb_list[j][i])):
            # graph에 해당 역 존재 : 해당 역의 key, value 빼서 다시 전처리 + 다음 역 추가시킨 graph 생성
            if (sb_list[j][i] + str(i+1)) in graph:
                # print(sb_list[j][i]) # 확인용 코드
                keys = [k for k in graph[sb_list[j][i] + str(i+1)].keys()]
                # print(key) # 확인용 코드
                values = [v for v in graph[sb_list[j][i] + str(i+1)].values()]
                # print(values) # 확인용 코드
                dic = {}
                for d in range(len(keys)):
                    dic[keys[d]] = values[d]
                dic[sb_list[j-1][i] + str(i+1)] = 2
                graph[sb_list[j][i] + str(i+1)] = dic
                # graph[sb_list[j][i]] = {graph.get(sb_list[j][i]), sb_list[j+1][i]:2}
                '''if(sb_list[j][i] == '시청'): # 확인용 코드
                    print(keys)
                    print(graph[sb_list[j][i]])'''
            # graph에 해당 역 존재하지 않음 : 다음 역 추가시킨 graph 생성
            else:
                graph[sb_list[j][i] + str(i+1)] = {sb_list[j-1][i] + str(i+1):2}
        # graph 생성 - graph 첫번째 원소이거나, 비어있는 역인 경우 : 불가능한 경우
        else:
            pass
        
print(graph)
# Out:
# 서동탄1
# 오금3
# 오이도4
# 마천5
# ...

# %% [markdown]
# ## 5) 양방향 Graph 전처리 추가(중복 호선 환승 고려o)

# %%
graph_key = list(graph.keys())
# print(graph_key) # 확인용 코드
print("ㅡㅡㅡㅡㅡ중첩 데이터 출력ㅡㅡㅡㅡㅡ")

for i in range(len(graph_key)):
    for j in range(i+1, len(graph_key)):
        # print(graph_key[0]) # 확인용 코드
        # print(graph_key[0][0:len(graph_key[0])-1]) # 확인용 코드
        if(graph_key[i][0:len(graph_key[i])-1] == graph_key[j][0:len(graph_key[j])-1]):
            print(graph_key[i], graph_key[j]) # 확인용 코드

            keys = [k for k in graph[graph_key[i]]]
            # print(key) # 확인용 코드
            values = [v for v in graph[graph_key[i]].values()]
            # print(values) # 확인용 코드
            dic = {}
            for d in range(len(keys)):
                dic[keys[d]] = values[d]
            dic[graph_key[j]] = 2
            graph[graph_key[i]] = dic

            keys = [k for k in graph[graph_key[j]]]
            # print(key) # 확인용 코드
            values = [v for v in graph[graph_key[j]].values()]
            # print(values) # 확인용 코드
            dic = {}
            for d in range(len(keys)):
                dic[keys[d]] = values[d]
            dic[graph_key[i]] = 2
            graph[graph_key[j]] = dic
# Out:
# ㅡㅡㅡㅡㅡ중첩 데이터 출력ㅡㅡㅡㅡㅡ
# 창동1 창동4
# 동대문1 동대문4
# 종로3가1 종로3가3
# 종로3가1 종로3가5
# 시청1 시청2
# 서울역1 서울역4
# 신길1 신길5
# 신도림1 신도림2
# 금정1 금정4
# 을지로3가2 을지로3가3
# 을지로4가2 을지로4가5
# 동대문역사문화공원2 동대문역사문화공원4
# 동대문역사문화공원2 동대문역사문화공원5
# 왕십리2 왕십리5
# 교대2 교대3
# 사당2 사당4
# 영등포구청2 영등포구청5
# 충정로2 충정로5
# 종로3가3 종로3가5
# 충무로3 충무로4
# 오금3 오금5
# 동대문역사문화공원4 동대문역사문화공원5

# %%
print(graph) # 확인용 코드
# Out:
# {'소요산1': {'동두천1': 2}, '동두천1': {'보산1': 2, '소요산1': 2}, '보산1': {'동두천중앙1': 2, '동두천1': 2}, '동두천중앙1': {'지행1': 2, '보산1': 2}, '지행1': {'덕정1': 2, '동두천중앙1': 2}, '덕정1': {'덕계1': 2, '지행1': 2}, '덕계1': {'양주1': 2, '덕정1': 2}, '양주1': {'녹양1': 2, '덕계1': 2}, '녹양1': {'가능1': 2, '양주1': 2}, '가능1': {'의정부1': 2, '녹양1': 2}, '의정부1': {'회룡1': 2, '가능1': 2}, '회룡1': {'망월사1': 2, '의정부1': 2}, '망월사1': {'도봉1': 2, '회룡1': 2}, '도봉1': {'도봉산1': 2, '망월사1': 2}, '도봉산1': {'방학1': 2, '도봉1': 2}, '방학1': {'창동1': 2, '도봉산1': 2}, '창동1': {'녹천1': 2, '방학1': 2, '창동4': 2}, '녹천1': {'월계1': 2, '창동1': 2}, '월계1': {'성북1': 2, '녹천1': 2}, '성북1': {'신이문1': 2, '월계1': 2}, '신이문1': {'외대앞1': 2, '성북1': 2}, '외대앞1': {'회기1': 2, '신이문1': 2}, '회기1': {'청량리1': 2, '외대앞1': 2}, '청량리1': {'제기동1': 2, '회기1': 2}, '제기동1': {'신설동1': 2, '청량리1': 2}, '신설동1': {'동묘앞1': 2, '제기동1': 2}, '동묘앞1': {'동대문1': 2, '신설동1': 2}, '동대문1': {'종로5가1': 2, '동묘앞1': 2, '동대문4': 2}, '종로5가1': {'종로3가1': 2, '동대문1': 2}, '종로3가1': {'종각1': 2, '종로5가1': 2, '종로3가3': 2, '종로3가5': 2}, '종각1': {'시청1': 2, '종로3가1': 2}, '시청1': 
# ...

# %% [markdown]
# ## 5-1) 양방향 Graph 거리 계산(nan 존재x + 호선 구별o + 중복 호선 환승 고려o)

# %%
# 그래프 : 본인 노드 이름 : {연결된 노드 이름 : 연결된 노드까지의 거리}
# distances : 시작 노드에서 특정 노드까지 거리 저장 dic
# start : 시작 노드
# heap : 다음 특정 노드 저장
# distance : 특정 노드까지 최소 거리
# current distance : 특정 노드까지 거리
# current destination : 특정 노드 노드명

import heapq  # 우선순위 큐 구현을 위함

def dijkstra(graph, start):
    # 거리 초기 설정
    distances = {node: float('inf') for node in graph} # [시작 노드에서 특정 노드까지 거리] : 무한대
    distances[start] = 0 # [시작 노드에서 시작 노드까지 거리] : 0
    # print(distances) # 확인용 코드
    queue = [] # [정보 저장 heap] 생성
    heapq.heappush(queue, [distances[start], start])  # [[시작 노드에서 시작 노드까지 거리], [시작 노드명]]를 [정보 저장 heap]에 저장
    # print(distances[start], start) # 확인용 코드

    # graph 생성
    while queue:  # heap에서 노드가 빌 때까지 반복
        current_distance, current_destination = heapq.heappop(queue) # [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] 빼기
        # print(current_distance, current_destination)
        if distances[current_destination] < current_distance: # [정보 저장 heap]에서 가장 작은 [시작 노드에서 특정 노드까지 거리] > [기존 시작 노드에서 특정 노드까지 거리]이면 건너띔
            print(distances[current_destination], current_distance) # 확인용 코드
            continue

        for new_destination, new_distance in graph[current_destination].items(): # [특정 노드]에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]] 전부 돌기
            distance = current_distance + new_distance # [시작 노드에서 다음 특정 노드까지의 새로운 거리] = [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] + 특정 노드명에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]
            if distance < distances[new_destination]: # [시작 노드에서 다음 특정 노드까지 거리] > [시작 노드에서 다음 특정 노드까지의 새로운 거리]라면
                # 거리 최신화
                distances[new_destination] = distance # [시작 노드에서 다음 특정 노드까지 거리] 최신화
                heapq.heappush(queue, [distance, new_destination]) # [[시작 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]을 [정보 저장 heap]에 저장

    return distances

print(dijkstra(graph, '시청1'))
# Out:
# {'소요산1': 62, '동두천1': 60, '보산1': 58, '동두천중앙1': 56, '지행1': 54, '덕정1': 52, '덕계1': 50, '양주1': 48, '녹양1': 46, '가능1': 44, '의정부1': 42, '회룡1': 40, '망월사1': 38, '도봉1': 36, '도봉산1': 34, '방학1': 32, '창동1': 30, '녹천1': 28, '월계1': 26, '성북1': 24, '신이문1': 22, '외대앞1': 20, '회기1': 18, '청량리1': 16, '제기동1': 14, '신설동1': 12, '동묘앞1': 10, '동대문1': 8, '종로5가1': 6, '종로3가1': 4, '종각1': 2, '시청1': 0, '서울역1': 2, '남영1': 4, '용산1': 6, '노량진1': 8, '대방1': 10, '신길1': 12, '영등포1': 14, '신도림1': 16, '구로1': 18, '구일1': 20, '개봉1': 22, '오류동1': 24, '온수1': 26, '역곡1': 28, '소사1': 30, '부천1': 32, '중동1': 34, '송내1': 36, '부개1': 38, '부평1': 40, '백운1': 42, '동암1': 44, '간석1': 46, '주안1': 48, '도화1': 50, '제물포1': 52, '도원1': 54, '동인천1': 56, '인천1': 58, '광명1': 56, '가산디지털단지1': 54, '독산1': 52, '금천구청1': 50, '석수1': 48, '관악1': 46, '안양1': 44, '명학1': 42, '금정1': 40, '군포1': 42, '당정1': 44, '의왕1': 46, '성균관대1': 48, '화서1': 50, '수원1': 52, '세류1': 54, '병점1': 56, '세마1': 58, '오산대1': 60, '진위1': 62, '송탄1': 64, '서정리1': 66, '지제1': 68, '평택1': 70, '성환1': 72, '직산1': 74, '두정1': 76, '
# ...

# %% [markdown]
# ## 5-2) 양방향 Graph 거리 계산(nan 존재x + 호선 구별o + 중복 호선 환승 고려o + 가독성 향상)

# %%
# 그래프 : 본인 노드 이름 : {연결된 노드 이름 : 연결된 노드까지의 거리}
# dist : 시작 노드에서 특정 노드까지 거리 저장 dic
# st : 시작 노드
# heap : 다음 특정 노드 저장
# plus dist : 특정 노드까지 최소 거리
# cur dist : 특정 노드까지 거리
# cur dest : 특정 노드 노드명

import heapq  # 우선순위 큐 구현을 위함

def dijkstra(graph, st):
    # 거리 초기 설정
    dist = {node: float('inf') for node in graph} # [시작 노드에서 특정 노드까지 거리] : 무한대
    dist[st] = 0 # [시작 노드에서 시작 노드까지 거리] : 0
    # print(dist) # 확인용 코드
    
    # heap 초기 설정
    queue = [] # [정보 저장 heap] 생성
    heapq.heappush(queue, [dist[st], st])  # [[시작 노드에서 시작 노드까지 거리], [시작 노드명]]를 [정보 저장 heap]에 저장
    # print(dist[st], st) # 확인용 코드

    # graph 생성
    while queue:  # heap에서 노드가 빌 때까지 반복
        cur_dist, cur_dest = heapq.heappop(queue) # [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] 빼기
        # print(cur_dist, cur_dest)
        if dist[cur_dest] < cur_dist: # [정보 저장 heap]에서 가장 작은 [시작 노드에서 특정 노드까지 거리] > [기존 시작 노드에서 특정 노드까지 거리]이면 건너띔
            print(dist[cur_dest], cur_dist) # 확인용 코드
            continue

        for new_dest, new_dist in graph[cur_dest].items(): # [특정 노드]에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]] 전부 돌기
            plus_dist = cur_dist + new_dist # [시작 노드에서 다음 특정 노드까지의 새로운 거리] = [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] + 특정 노드명에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]
            if plus_dist < dist[new_dest]: # [시작 노드에서 다음 특정 노드까지 거리] > [시작 노드에서 다음 특정 노드까지의 새로운 거리]라면
                # 거리 최신화
                dist[new_dest] = plus_dist # [시작 노드에서 다음 특정 노드까지 거리] 최신화
                heapq.heappush(queue, [plus_dist, new_dest]) # [[시작 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]을 [정보 저장 heap]에 저장

    return dist

dijkstra(graph, '시청1')
# Out:
# {'소요산1': 62,
#  '동두천1': 60,
#  '보산1': 58,
#  '동두천중앙1': 56,
#  '지행1': 54,
#  '덕정1': 52,
#  '덕계1': 50,
#  '양주1': 48,
#  '녹양1': 46,
#  '가능1': 44,
#  '의정부1': 42,
#  '회룡1': 40,
#  '망월사1': 38,
#  '도봉1': 36,
#  '도봉산1': 34,
#  '방학1': 32,
#  '창동1': 30,
#  '녹천1': 28,
#  '월계1': 26,
#  '성북1': 24,
#  '신이문1': 22,
#  '외대앞1': 20,
#  '회기1': 18,
#  '청량리1': 16,
#  '제기동1': 14,
#  '신설동1': 12,
#  '동묘앞1': 10,
#  '동대문1': 8,
#  '종로5가1': 6,
#  '종로3가1': 4,
#  '종각1': 2,
#  '시청1': 0,
#  '서울역1': 2,
#  '남영1': 4,
#  '용산1': 6,
#  '노량진1': 8,
#  '대방1': 10,
#  '신길1': 12,
#  '영등포1': 14,
#  '신도림1': 16,
#  '구로1': 18,
#  '구일1': 20,
#  '개봉1': 22,
#  '오류동1': 24,
#  '온수1': 26,
#  '역곡1': 28,
#  '소사1': 30,
#  '부천1': 32,
#  '중동1': 34,
#  '송내1': 36,
#  '부개1': 38,
#  '부평1': 40,
#  '백운1': 42,
#  '동암1': 44,
#  '간석1': 46,
#  '주안1': 48,
#  '도화1': 50,
#  '제물포1': 52,
#  '도원1': 54,
#  '동인천1': 56,
#  '인천1': 58,
#  '광명1': 56,
#  '가산디지털단지1': 54,
#  '독산1': 52,
#  '금천구청1': 50,
#  '석수1': 48,
#  '관악1': 46,
#  '안양1': 44,
#  '명학1': 42,
# ...

# %% [markdown]
# ## 5-3) 양방향 Graph 거리 계산(nan 존재x + 호선 구별o + 중복 호선 환승 고려o + 가독성 향상 + 경로 출력)

# %%
# 그래프 : 본인 노드 이름 : {연결된 노드 이름 : 연결된 노드까지의 거리}
# dist : 시작 노드에서 특정 노드까지 거리 저장 dic
# st : 시작 노드
# heap : 다음 특정 노드 저장
# plus dist : 특정 노드까지 최소 거리
# cur dist : 특정 노드까지 거리
# cur dest : 특정 노드 노드명

# track : 시작 노드에서 특정 노드까지 경로 저장 dic

import heapq  # 우선순위 큐 구현을 위함

def dijkstra(graph, st):
    # 거리 + track 초기 설정
    dist = {node: float('inf') for node in graph} # [시작 노드에서 특정 노드까지 거리] : 무한대
    global track
    track = {node: [] for node in graph} # [시작 노드에서 특정 노드까지 경로] : 비어있음
    track[st] = [st] # [시작 노드에서 시작 노드까지 경로] : 시작 노드
    dist[st] = 0 # [시작 노드에서 시작 노드까지 거리] : 0
    # print(dist) # 확인용 코드
    
    # heap 초기 설정
    queue = [] # [정보 저장 heap] 생성
    heapq.heappush(queue, [dist[st], st])  # [[시작 노드에서 시작 노드까지 거리], [시작 노드명]]를 [정보 저장 heap]에 저장
    # print(dist[st], st) # 확인용 코드

    # graph 생성
    while queue:  # heap에서 노드가 빌 때까지 반복
        cur_dist, cur_dest = heapq.heappop(queue) # [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] 빼기
        # print(cur_dist, cur_dest)
        if dist[cur_dest] < cur_dist: # [정보 저장 heap]에서 가장 작은 [시작 노드에서 특정 노드까지 거리] > [기존 시작 노드에서 특정 노드까지 거리]이면 건너띔
            print(dist[cur_dest], cur_dist) # 확인용 코드
            continue

        for new_dest, new_dist in graph[cur_dest].items(): # [특정 노드]에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]] 전부 돌기
            plus_dist = cur_dist + new_dist # [시작 노드에서 다음 특정 노드까지의 새로운 거리] = [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] + 특정 노드명에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]
            if plus_dist < dist[new_dest]: # [시작 노드에서 다음 특정 노드까지 거리] > [시작 노드에서 다음 특정 노드까지의 새로운 거리]라면
                # 거리 최신화
                dist[new_dest] = plus_dist # [시작 노드에서 다음 특정 노드까지 거리] 최신화
                # print(type(track[cur_dest])) # 확인용 코드
                # print(track[new_dest]) # 확인용 코드
                # print(track[cur_dest]) # 확인용 코드
                
                # 경로 최신화
                track[new_dest] = track[cur_dest][:] # [시작 노드에서 특정 노드까지 경로] 최신화
                # track[cur_dest] = [] # 확인용 코드
                track[new_dest].append(new_dest)
                # print(cur_dest, new_dest) # 확인용 코드
                # print(track[new_dest]) # 확인용 코드
                # print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ") # 확인용 코드
                # if(new_dest == '시청1'):
                    # print(track[new_dest]) # 확인용 코드
                heapq.heappush(queue, [plus_dist, new_dest]) # [[시작 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]을 [정보 저장 heap]에 저장

        # print("ㅡㅡfor문 돌아ㅡㅡ") # 확인용 코드
    return dist

dijkstra(graph, '시청1')
# Out:
# {'소요산1': 62,
#  '동두천1': 60,
#  '보산1': 58,
#  '동두천중앙1': 56,
#  '지행1': 54,
#  '덕정1': 52,
#  '덕계1': 50,
#  '양주1': 48,
#  '녹양1': 46,
#  '가능1': 44,
#  '의정부1': 42,
#  '회룡1': 40,
#  '망월사1': 38,
#  '도봉1': 36,
#  '도봉산1': 34,
#  '방학1': 32,
#  '창동1': 30,
#  '녹천1': 28,
#  '월계1': 26,
#  '성북1': 24,
#  '신이문1': 22,
#  '외대앞1': 20,
#  '회기1': 18,
#  '청량리1': 16,
#  '제기동1': 14,
#  '신설동1': 12,
#  '동묘앞1': 10,
#  '동대문1': 8,
#  '종로5가1': 6,
#  '종로3가1': 4,
#  '종각1': 2,
#  '시청1': 0,
#  '서울역1': 2,
#  '남영1': 4,
#  '용산1': 6,
#  '노량진1': 8,
#  '대방1': 10,
#  '신길1': 12,
#  '영등포1': 14,
#  '신도림1': 16,
#  '구로1': 18,
#  '구일1': 20,
#  '개봉1': 22,
#  '오류동1': 24,
#  '온수1': 26,
#  '역곡1': 28,
#  '소사1': 30,
#  '부천1': 32,
#  '중동1': 34,
#  '송내1': 36,
#  '부개1': 38,
#  '부평1': 40,
#  '백운1': 42,
#  '동암1': 44,
#  '간석1': 46,
#  '주안1': 48,
#  '도화1': 50,
#  '제물포1': 52,
#  '도원1': 54,
#  '동인천1': 56,
#  '인천1': 58,
#  '광명1': 56,
#  '가산디지털단지1': 54,
#  '독산1': 52,
#  '금천구청1': 50,
#  '석수1': 48,
#  '관악1': 46,
#  '안양1': 44,
#  '명학1': 42,
# ...

# %%
# 경로 출력
track
# Out:
# {'소요산1': ['시청1',
#   '종각1',
#   '종로3가1',
#   '종로5가1',
#   '동대문1',
#   '동묘앞1',
#   '신설동1',
#   '제기동1',
#   '청량리1',
#   '회기1',
#   '외대앞1',
#   '신이문1',
#   '성북1',
#   '월계1',
#   '녹천1',
#   '창동1',
#   '방학1',
#   '도봉산1',
#   '도봉1',
#   '망월사1',
#   '회룡1',
#   '의정부1',
#   '가능1',
#   '녹양1',
#   '양주1',
#   '덕계1',
#   '덕정1',
#   '지행1',
#   '동두천중앙1',
#   '보산1',
#   '동두천1',
#   '소요산1'],
#  '동두천1': ['시청1',
#   '종각1',
#   '종로3가1',
#   '종로5가1',
#   '동대문1',
#   '동묘앞1',
#   '신설동1',
#   '제기동1',
#   '청량리1',
#   '회기1',
#   '외대앞1',
#   '신이문1',
#   '성북1',
#   '월계1',
#   '녹천1',
#   '창동1',
#   '방학1',
#   '도봉산1',
#   '도봉1',
#   '망월사1',
#   '회룡1',
#   '의정부1',
#   '가능1',
#   '녹양1',
#   '양주1',
#   '덕계1',
#   '덕정1',
#   '지행1',
#   '동두천중앙1',
#   '보산1',
#   '동두천1'],
#  '보산1': ['시청1',
#   '종각1',
#   '종로3가1',
#   '종로5가1',
#   '동대문1',
#   '동묘앞1',
#   '신설동1',
#   '제기동1',
#   '청량리1',
#   '회기1',
#   '외대앞1',
#   '신이문1',
#   '성북1',
#   '월계1',
#   '녹천1',
#   '창동1',
#   '방학1',
#   '도봉산1',
#   '도봉1',
#   '망월사1',
#   '회룡1',
# ...

# %%
print(track['시청1'])
print(track['명동4'])
print(track['상일동5'])
print(track['을지로3가3'])
print(track['금호3'])
# Out:
# ['시청1']
# ['시청1', '서울역1', '서울역4', '회현4', '명동4']
# ['시청1', '시청2', '을지로입구2', '을지로3가2', '을지로4가2', '동대문역사문화공원2', '신당2', '상왕십리2', '왕십리2', '왕십리5', '마장5', '답십리5', '장한평5', '군자5', '아차산5', '광나루5', '천호5', '강동5', '길동5', '굽은다리5', '명일5', '고덕5', '상일동5']
# ['시청1', '시청2', '을지로입구2', '을지로3가2', '을지로3가3']
# ['시청1', '시청2', '을지로입구2', '을지로3가2', '을지로3가3', '충무로3', '동대입구3', '약수3', '금호3']

# %% [markdown]
# ## 5-4) 양방향 Graph 거리 계산(nan 존재x + 호선 구별o + 중복 호선 환승 고려o + 가독성 향상 + 경로 출력 + 환승 횟수 출력)

# %%
# 그래프 : 본인 노드 이름 : {연결된 노드 이름 : 연결된 노드까지의 거리}
# dist : 시작 노드에서 특정 노드까지 거리 저장 dic
# st : 시작 노드
# heap : 다음 특정 노드 저장
# plus dist : 특정 노드까지 최소 거리
# cur dist : 특정 노드까지 거리
# cur dest : 특정 노드 노드명

# track : 시작 노드에서 특정 노드까지 경로 저장 dic
# count : 시작 노드에서 특정 노드까지 환승 횟수 저장 dic

import heapq  # 우선순위 큐 구현을 위함

def dijkstra(graph, st):
    # 거리 + track + 환승횟수 초기 설정
    dist = {node: float('inf') for node in graph} # [시작 노드에서 특정 노드까지 거리] : 무한대
    global track, count
    track = {node: [] for node in graph} # [시작 노드에서 특정 노드까지 경로] : 비어있음
    track[st] = [st] # [시작 노드에서 시작 노드까지 경로] : 시작 노드
    count = {node: 0 for node in graph} # [시작 노드에서 특정 노드까지 환승 횟수] : 0
    dist[st] = 0 # [시작 노드에서 시작 노드까지 거리] : 0
    # print(dist) # 확인용 코드
    
    # heap 초기 설정
    queue = [] # [정보 저장 heap] 생성
    heapq.heappush(queue, [dist[st], st])  # [[시작 노드에서 시작 노드까지 거리], [시작 노드명]]를 [정보 저장 heap]에 저장
    # print(dist[st], st) # 확인용 코드

    # graph 생성
    while queue:  # heap에서 노드가 빌 때까지 반복
        cur_dist, cur_dest = heapq.heappop(queue) # [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] 빼기
        # print(cur_dist, cur_dest)
        if dist[cur_dest] < cur_dist: # [정보 저장 heap]에서 가장 작은 [시작 노드에서 특정 노드까지 거리] > [기존 시작 노드에서 특정 노드까지 거리]이면 건너띔
            print(dist[cur_dest], cur_dist) # 확인용 코드
            continue

        for new_dest, new_dist in graph[cur_dest].items(): # [특정 노드]에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]] 전부 돌기
            plus_dist = cur_dist + new_dist # [시작 노드에서 다음 특정 노드까지의 새로운 거리] = [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] + 특정 노드명에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]
            if plus_dist < dist[new_dest]: # [시작 노드에서 다음 특정 노드까지 거리] > [시작 노드에서 다음 특정 노드까지의 새로운 거리]라면
                # 거리 최신화
                dist[new_dest] = plus_dist # [시작 노드에서 다음 특정 노드까지 거리] 최신화
                # print(type(track[cur_dest])) # 확인용 코드
                # print(track[new_dest]) # 확인용 코드
                # print(track[cur_dest]) # 확인용 코드
                
                # 경로 최신화
                track[new_dest] = track[cur_dest][:] # [시작 노드에서 특정 노드까지 경로] 최신화 (특정 노드 이전까지 경로 얕은 복사 + 특정 노드도 경로에 추가)
                # track[cur_dest] = [] # 확인용 코드
                track[new_dest].append(new_dest)
                if(new_dest == '충무로4'): # 확인용 코드
                    print(track[new_dest])
                    
                # 환승 횟수 최신화
                if(new_dest[0:len(new_dest)-1] == cur_dest[0:len(cur_dest)-1]): # [시작 노드에서 특정 노드까지 환승 횟수] 최신화 (특정 노드 이전까지 환승 횟수 + 특정 노드도 확인 후 추가)
                    count[new_dest] = count[cur_dest] + 1
                    print(new_dest, cur_dest) # 확인용 코드
                else:
                    count[new_dest] = count[cur_dest]
                # print(cur_dest, new_dest) # 확인용 코드
                # print(track[new_dest]) # 확인용 코드
                # print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ") # 확인용 코드
                # if(new_dest == '시청1'):
                    # print(track[new_dest]) # 확인용 코드
                heapq.heappush(queue, [plus_dist, new_dest]) # [[시작 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]을 [정보 저장 heap]에 저장

        # print("ㅡㅡfor문 돌아ㅡㅡ") # 확인용 코드
    return dist

print(dijkstra(graph, '시청1'))
# Out:
# 시청2 시청1
# 서울역4 서울역1
# 종로3가3 종로3가1
# 종로3가5 종로3가1
# 충정로5 충정로2
# 을지로3가3 을지로3가2
# 동대문4 동대문1
# ['시청1', '서울역1', '서울역4', '회현4', '명동4', '충무로4']
# 신길5 신길1
# 신도림2 신도림1
# 왕십리5 왕십리2
# 사당2 사당4
# 교대3 교대2
# 금정1 금정4
# 오금5 오금3
# ...

# %%
# 경로 출력
print(track)
# Out:
# {'소요산1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '도봉1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1', '보산1', '동두천1', '소요산1'], '동두천1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '도봉1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1', '보산1', '동두천1'], '보산1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '도봉1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1', '보산1'], '동두천중앙1': ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '도봉1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1'], '지행1': ['시청1', '종각1', '종로3가1', 
# ...

# %%
print(track['시청1'])
print(track['명동4'])
print(track['상일동5'])
print(track['시청2'])
print(track['을지로3가3'])
print(track['금호3'])
# Out:
# ['시청1']
# ['시청1', '서울역1', '서울역4', '회현4', '명동4']
# ['시청1', '시청2', '을지로입구2', '을지로3가2', '을지로4가2', '동대문역사문화공원2', '신당2', '상왕십리2', '왕십리2', '왕십리5', '마장5', '답십리5', '장한평5', '군자5', '아차산5', '광나루5', '천호5', '강동5', '길동5', '굽은다리5', '명일5', '고덕5', '상일동5']
# ['시청1', '시청2']
# ['시청1', '시청2', '을지로입구2', '을지로3가2', '을지로3가3']
# ['시청1', '시청2', '을지로입구2', '을지로3가2', '을지로3가3', '충무로3', '동대입구3', '약수3', '금호3']

# %%
# 환승 횟수 출력
print(count)
# Out:
# {'소요산1': 0, '동두천1': 0, '보산1': 0, '동두천중앙1': 0, '지행1': 0, '덕정1': 0, '덕계1': 0, '양주1': 0, '녹양1': 0, '가능1': 0, '의정부1': 0, '회룡1': 0, '망월사1': 0, '도봉1': 0, '도봉산1': 0, '방학1': 0, '창동1': 0, '녹천1': 0, '월계1': 0, '성북1': 0, '신이문1': 0, '외대앞1': 0, '회기1': 0, '청량리1': 0, '제기동1': 0, '신설동1': 0, '동묘앞1': 0, '동대문1': 0, '종로5가1': 0, '종로3가1': 0, '종각1': 0, '시청1': 0, '서울역1': 0, '남영1': 0, '용산1': 0, '노량진1': 0, '대방1': 0, '신길1': 0, '영등포1': 0, '신도림1': 0, '구로1': 0, '구일1': 0, '개봉1': 0, '오류동1': 0, '온수1': 0, '역곡1': 0, '소사1': 0, '부천1': 0, '중동1': 0, '송내1': 0, '부개1': 0, '부평1': 0, '백운1': 0, '동암1': 0, '간석1': 0, '주안1': 0, '도화1': 0, '제물포1': 0, '도원1': 0, '동인천1': 0, '인천1': 2, '광명1': 2, '가산디지털단지1': 2, '독산1': 2, '금천구청1': 2, '석수1': 2, '관악1': 2, '안양1': 2, '명학1': 2, '금정1': 2, '군포1': 2, '당정1': 2, '의왕1': 2, '성균관대1': 2, '화서1': 2, '수원1': 2, '세류1': 2, '병점1': 2, '세마1': 2, '오산대1': 2, '진위1': 2, '송탄1': 2, '서정리1': 2, '지제1': 2, '평택1': 2, '성환1': 2, '직산1': 2, '두정1': 2, '천안1': 2, '봉명1': 2, '쌍용1': 2, '아산1': 2, '배방1': 2, '온양온천1': 2, '신창1': 2, '서동탄1': 
# ...

# %%
print(count['시청1'])
print(count['명동4'])
print(count['상일동5'])
print(count['시청2'])
print(count['을지로3가3'])
print(count['금호3']) # 이건 환승 2번함
# Out:
# 0
# 1
# 2
# 1
# 2
# 2

# %% [markdown]
# ## 5-5) 양방향 Graph 거리 계산(nan 존재x + 호선 구별o + 중복 호선 환승 고려o + 가독성 향상 + 경로 출력 + 환승 횟수 출력 + 하나의 dic으로 통일화)

# %%
# 그래프 : 본인 노드 이름 : {연결된 노드 이름 : 연결된 노드까지의 거리}
# dist : 시작 노드에서 특정 노드까지 거리 + 경로 + 환승 횟수 저장 dic
# st : 시작 노드
# heap : 다음 특정 노드 저장
# plus dist : 특정 노드까지 최소 거리
# cur dist : 특정 노드까지 거리
# cur dest : 특정 노드 노드명

import heapq  # 우선순위 큐 구현을 위함

def dijkstra(graph, st):
    # 거리 + track + 환승횟수 초기 설정
    global dist
    dist = {node: [float('inf')] for node in graph} # [시작 노드에서 특정 노드까지 거리] : 무한대
    # print(dist) # 확인용 코드
    for node in graph:
        dist[node].append([]) # [시작 노드에서 특정 노드까지 경로] : 비어있음
        dist[node].append(0) # [시작 노드에서 특정 노드까지 환승 횟수] : 0
    # print(dist) # 확인용 코드
    dist[st][1] = [st]
    dist[st][0] = 0
    # print(dist) # 확인용 코드
    # print(dist['충무로4'][1]) # 확인용 코드
    
    # heap 초기 설정
    queue = [] # [정보 저장 heap] 생성
    heapq.heappush(queue, [dist[st][0], st])  # [[시작 노드에서 시작 노드까지 거리], [시작 노드명]]를 [정보 저장 heap]에 저장
    # print(dist[st], st) # 확인용 코드

    # graph 생성
    while queue:  # heap에서 노드가 빌 때까지 반복
        cur_dist, cur_dest = heapq.heappop(queue) # [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] 빼기
        # print(cur_dist, cur_dest)
        if dist[cur_dest][0] < cur_dist: # [정보 저장 heap]에서 가장 작은 [시작 노드에서 특정 노드까지 거리] > [기존 시작 노드에서 특정 노드까지 거리]이면 건너띔
            print(dist[cur_dest][0], cur_dist) # 확인용 코드
            continue

        for new_dest, new_dist in graph[cur_dest].items(): # [특정 노드]에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]] 전부 돌기
            plus_dist = cur_dist + new_dist # [시작 노드에서 다음 특정 노드까지의 새로운 거리] = [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] + 특정 노드명에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]
            if plus_dist < dist[new_dest][0]: # [시작 노드에서 다음 특정 노드까지 거리] > [시작 노드에서 다음 특정 노드까지의 새로운 거리]라면
                # 거리 최신화
                dist[new_dest][0] = plus_dist # [시작 노드에서 다음 특정 노드까지 거리] 최신화
                # print(type(track[cur_dest])) # 확인용 코드
                # print(track[new_dest]) # 확인용 코드
                # print(track[cur_dest]) # 확인용 코드
                
                # 경로 최신화
                dist[new_dest][1] = dist[cur_dest][1][:] # [시작 노드에서 특정 노드까지 경로] 최신화 (특정 노드 이전까지 경로 얕은 복사 + 특정 노드도 경로에 추가)
                # track[cur_dest] = [] # 확인용 코드
                # print(dist[new_dest][1]) # 확인용 코드
                dist[new_dest][1].append(new_dest)
                # if(new_dest == '충무로4'): # 확인용 코드
                    # print(dist[new_dest][1])
                    
                # 환승 횟수 최신화
                if(new_dest[0:len(new_dest)-1] == cur_dest[0:len(cur_dest)-1]): # [시작 노드에서 특정 노드까지 환승 횟수] 최신화 (특정 노드 이전까지 환승 횟수 + 특정 노드도 확인 후 추가)
                    dist[new_dest][2] = dist[cur_dest][2] + 1
                    # print(new_dest, cur_dest) # 확인용 코드
                else:
                    dist[new_dest][2] = dist[cur_dest][2]
                # print(cur_dest, new_dest) # 확인용 코드
                # print(track[new_dest]) # 확인용 코드
                # print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ") # 확인용 코드
                # if(new_dest == '시청1'):
                    # print(track[new_dest]) # 확인용 코드
                heapq.heappush(queue, [plus_dist, new_dest]) # [[시작 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]을 [정보 저장 heap]에 저장

        # print("ㅡㅡfor문 돌아ㅡㅡ") # 확인용 코드
    return dist

print(dijkstra(graph, '시청1'))
# Out:
# {'소요산1': [62, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '도봉1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1', '보산1', '동두천1', '소요산1'], 0], '동두천1': [60, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '도봉1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1', '보산1', '동두천1'], 0], '보산1': [58, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '도봉1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1', '보산1'], 0], '동두천중앙1': [56, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '도봉1', '망월사1', '회룡1', '의정부1', '가능1', '녹양1', '양주1', '덕계1', '덕정1', '지행1', '동두천중앙1'],
# ...

# %%
# 확인용 코드
print(dist['시청1'][0])
print(dist['시청1'][1])
print(dist['시청1'][2])
print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
print(dist['명동4'][0])
print(dist['명동4'][1])
print(dist['명동4'][2])
print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
print(dist['상일동5'][0])
print(dist['상일동5'][1])
print(dist['상일동5'][2])
print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
print(dist['시청2'][0])
print(dist['시청2'][1])
print(dist['시청2'][2])
print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
print(dist['을지로3가3'][0])
print(dist['을지로3가3'][1])
print(dist['을지로3가3'][2])
print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
print(dist['금호3'][0])
print(dist['금호3'][1])
print(dist['금호3'][2])
# Out:
# 0
# ['시청1']
# 0
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# 8
# ['시청1', '서울역1', '서울역4', '회현4', '명동4']
# 1
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# 44
# ['시청1', '시청2', '을지로입구2', '을지로3가2', '을지로4가2', '동대문역사문화공원2', '신당2', '상왕십리2', '왕십리2', '왕십리5', '마장5', '답십리5', '장한평5', '군자5', '아차산5', '광나루5', '천호5', '강동5', '길동5', '굽은다리5', '명일5', '고덕5', '상일동5']
# 2
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# 2
# ['시청1', '시청2']
# 1
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# 8
# ['시청1', '시청2', '을지로입구2', '을지로3가2', '을지로3가3']
# 2
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# 16
# ['시청1', '시청2', '을지로입구2', '을지로3가2', '을지로3가3', '충무로3', '동대입구3', '약수3', '금호3']
# 2

# %% [markdown]
# ## 5-6) 양방향 Graph 거리 계산(nan 존재x + 호선 구별o + 중복 호선 환승 고려o + 가독성 향상 + 경로 출력 + 환승 횟수 출력 + 하나의 dic으로 통일화 + 목적지까지 최소 거리 완성 시, break)

# %%
# 그래프 : 본인 노드 이름 : {연결된 노드 이름 : 연결된 노드까지의 거리}
# dist : 시작 노드에서 특정 노드까지 거리 + 경로 + 환승 횟수 저장 dic
# st : 시작 노드
# heap : 다음 특정 노드 저장
# plus dist : 특정 노드까지 최소 거리
# cur dist : 특정 노드까지 거리
# cur dest : 특정 노드 노드명

import heapq  # 우선순위 큐 구현을 위함

def dijkstra(graph, st, end):
    # 거리 + track + 환승횟수 초기 설정
    global dist
    dist = {node: [float('inf')] for node in graph} # [시작 노드에서 특정 노드까지 거리] : 무한대
    # print(dist) # 확인용 코드
    for node in graph:
        dist[node].append([]) # [시작 노드에서 특정 노드까지 경로] : 비어있음
        dist[node].append(0) # [시작 노드에서 특정 노드까지 환승 횟수] : 0
    # print(dist) # 확인용 코드
    dist[st][1] = [st]
    dist[st][0] = 0
    # print(dist) # 확인용 코드
    # print(dist['충무로4'][1]) # 확인용 코드
    
    # heap 초기 설정
    queue = [] # [정보 저장 heap] 생성
    heapq.heappush(queue, [dist[st][0], st])  # [[시작 노드에서 시작 노드까지 거리], [시작 노드명]]를 [정보 저장 heap]에 저장
    # print(dist[st], st) # 확인용 코드

    # graph 생성
    while queue:  # heap에서 노드가 빌 때까지 반복
        cur_dist, cur_dest = heapq.heappop(queue) # [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] 빼기
        # print(cur_dist, cur_dest)
        if(cur_dest == end): # 확인용 코드
            break
        
        if dist[cur_dest][0] < cur_dist: # [정보 저장 heap]에서 가장 작은 [시작 노드에서 특정 노드까지 거리] > [기존 시작 노드에서 특정 노드까지 거리]이면 건너띔
            print(dist[cur_dest][0], cur_dist) # 확인용 코드
            continue

        for new_dest, new_dist in graph[cur_dest].items(): # [특정 노드]에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]] 전부 돌기
            plus_dist = cur_dist + new_dist # [시작 노드에서 다음 특정 노드까지의 새로운 거리] = [정보 저장 heap]에서 가장 작은 [[시작 노드에서 특정 노드까지 거리], [특정 노드명]] + 특정 노드명에 연결된 [[특정 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]
            if plus_dist < dist[new_dest][0]: # [시작 노드에서 다음 특정 노드까지 거리] > [시작 노드에서 다음 특정 노드까지의 새로운 거리]라면
                # 거리 최신화
                dist[new_dest][0] = plus_dist # [시작 노드에서 다음 특정 노드까지 거리] 최신화
                # print(type(track[cur_dest])) # 확인용 코드
                # print(track[new_dest]) # 확인용 코드
                # print(track[cur_dest]) # 확인용 코드
                
                # 경로 최신화
                dist[new_dest][1] = dist[cur_dest][1][:] # [시작 노드에서 특정 노드까지 경로] 최신화 (특정 노드 이전까지 경로 얕은 복사 + 특정 노드도 경로에 추가)
                # track[cur_dest] = [] # 확인용 코드
                # print(dist[new_dest][1]) # 확인용 코드
                dist[new_dest][1].append(new_dest)
                # if(new_dest == '충무로4'): # 확인용 코드
                    # print(dist[new_dest][1])
                    
                # 환승 횟수 최신화
                if(new_dest[0:len(new_dest)-1] == cur_dest[0:len(cur_dest)-1]): # [시작 노드에서 특정 노드까지 환승 횟수] 최신화 (특정 노드 이전까지 환승 횟수 + 특정 노드도 확인 후 추가)
                    dist[new_dest][2] = dist[cur_dest][2] + 1
                    # print(new_dest, cur_dest) # 확인용 코드
                else:
                    dist[new_dest][2] = dist[cur_dest][2]
                # print(cur_dest, new_dest) # 확인용 코드
                # print(track[new_dest]) # 확인용 코드
                # print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ") # 확인용 코드
                # if(new_dest == '시청1'):
                    # print(track[new_dest]) # 확인용 코드
                heapq.heappush(queue, [plus_dist, new_dest]) # [[시작 노드에서 다음 특정 노드까지 거리], [다음 특정 노드명]]을 [정보 저장 heap]에 저장

        # print("ㅡㅡfor문 돌아ㅡㅡ") # 확인용 코드
    return dist

print(dist)
# Out:
# {'소요산1': [inf, [], 0], '동두천1': [inf, [], 0], '보산1': [inf, [], 0], '동두천중앙1': [inf, [], 0], '지행1': [inf, [], 0], '덕정1': [inf, [], 0], '덕계1': [inf, [], 0], '양주1': [inf, [], 0], '녹양1': [inf, [], 0], '가능1': [inf, [], 0], '의정부1': [inf, [], 0], '회룡1': [inf, [], 0], '망월사1': [38, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '도봉1', '망월사1'], 0], '도봉1': [36, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '도봉1'], 0], '도봉산1': [34, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1'], 0], '방학1': [32, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1'], 0], '창동1': [30, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1',
# ...

# %%
def print_dist():
    st = input("출발지 : ")
    end = input("도착지 : ")

    dijkstra(graph, st, end)
    print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ[결과]ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
    print("배열 : ", dist[end]) # 확인용 코드
    print("거리 : ", dist[end][0], "분")
    print("경로 : ", dist[end][1])
    print("환승 횟수 : ", dist[end][2], "회")
    print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")

# %%
print_dist()
# Out:
# 출발지 : 시청1
# 도착지 : 범계4
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ[결과]ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# 배열 :  [36, ['시청1', '서울역1', '서울역4', '숙대입구4', '삼각지4', '신용산4', '이촌4', '동작4', '이수4', '사당4', '남태령4', '선바위4', '경마공원4', '대공원4', '과천4', '정부과천청사4', '인덕원4', '평촌4', '범계4'], 1]
# 거리 :  36 분
# 경로 :  ['시청1', '서울역1', '서울역4', '숙대입구4', '삼각지4', '신용산4', '이촌4', '동작4', '이수4', '사당4', '남태령4', '선바위4', '경마공원4', '대공원4', '과천4', '정부과천청사4', '인덕원4', '평촌4', '범계4']
# 환승 횟수 :  1 회
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ

# %% [markdown]
# # BFS를 통한 구현

# %%
def bfs(graph, start):
    

    #방문 여부 확인
    visited = {node: False for node in graph}
    visited[start] = True

    queue = []
    
    
    #역간 거리 초기화   
    distances = {node: [float('inf')] for node in graph} # [시작 노드에서 특정 노드까지 거리] : 무한대
    distances[start] = 0
    heapq.heappush(queue, [distances[start], start])  
    
    
    while queue:
        current_distances, current_destination = heapq.heappop(queue)

        for new_destination, new_distances in graph[current_destination].items():
            if visited[new_destination] == False:
                distance = current_distances + new_distances
                distances[new_destination] = distance
                heapq.heappush(queue, [distance, new_destination])
                visited[new_destination] = True #방문 기록 표시
                

    return distances
    

bfs(graph, '시청1')
# Out:
# {'소요산1': 62,
#  '동두천1': 60,
#  '보산1': 58,
#  '동두천중앙1': 56,
#  '지행1': 54,
#  '덕정1': 52,
#  '덕계1': 50,
#  '양주1': 48,
#  '녹양1': 46,
#  '가능1': 44,
#  '의정부1': 42,
#  '회룡1': 40,
#  '망월사1': 38,
#  '도봉1': 36,
#  '도봉산1': 34,
#  '방학1': 32,
#  '창동1': 30,
#  '녹천1': 28,
#  '월계1': 26,
#  '성북1': 24,
#  '신이문1': 22,
#  '외대앞1': 20,
#  '회기1': 18,
#  '청량리1': 16,
#  '제기동1': 14,
#  '신설동1': 12,
#  '동묘앞1': 10,
#  '동대문1': 8,
#  '종로5가1': 6,
#  '종로3가1': 4,
#  '종각1': 2,
#  '시청1': 0,
#  '서울역1': 2,
#  '남영1': 4,
#  '용산1': 6,
#  '노량진1': 8,
#  '대방1': 10,
#  '신길1': 12,
#  '영등포1': 14,
#  '신도림1': 16,
#  '구로1': 18,
#  '구일1': 20,
#  '개봉1': 22,
#  '오류동1': 24,
#  '온수1': 26,
#  '역곡1': 28,
#  '소사1': 30,
#  '부천1': 32,
#  '중동1': 34,
#  '송내1': 36,
#  '부개1': 38,
#  '부평1': 40,
#  '백운1': 42,
#  '동암1': 44,
#  '간석1': 46,
#  '주안1': 48,
#  '도화1': 50,
#  '제물포1': 52,
#  '도원1': 54,
#  '동인천1': 56,
#  '인천1': 58,
#  '광명1': 56,
#  '가산디지털단지1': 54,
#  '독산1': 52,
#  '금천구청1': 50,
#  '석수1': 48,
#  '관악1': 46,
#  '안양1': 44,
#  '명학1': 42,
# ...

# %%
def bfs(graph, st, end):

    #거리 초기화용
    global dist
    dist = {node: [float('inf')] for node in graph}

    
    for node in graph:
        dist[node].append([]) 
        dist[node].append(0) 
  
    dist[st][1] = [st]
    dist[st][0] = 0
   
    queue = [] 
    heapq.heappush(queue, [dist[st][0], st])  

    #방문 여부 확인용
    visited = {node: False for node in graph}
    visited[st] = True #첫 정거장 방문처리


    while queue:  
        cur_dist, cur_dest = heapq.heappop(queue) 

        if(cur_dest == end): 
            break
        
        if dist[cur_dest][0] < cur_dist: 
            print(dist[cur_dest][0], cur_dist) 
            continue

        for new_dest, new_dist in graph[cur_dest].items():
            if visited[new_dest] == False: #방문 하지 않은 경우에만 거리 계산
                plus_dist = cur_dist + new_dist   
                dist[new_dest][0] = plus_dist 
                dist[new_dest][1] = dist[cur_dest][1][:] 
                dist[new_dest][1].append(new_dest)

                if(new_dest[0:len(new_dest)-1] == cur_dest[0:len(cur_dest)-1]): 
                    dist[new_dest][2] = dist[cur_dest][2] + 1
                else:
                    dist[new_dest][2] = dist[cur_dest][2]

                heapq.heappush(queue, [plus_dist, new_dest]) 
                visited[new_dest] = True #방문한 정거장 방문 처리

    return dist


print(dist)
# Out:
# {'소요산1': [inf, [], 0], '동두천1': [inf, [], 0], '보산1': [inf, [], 0], '동두천중앙1': [inf, [], 0], '지행1': [inf, [], 0], '덕정1': [inf, [], 0], '덕계1': [inf, [], 0], '양주1': [inf, [], 0], '녹양1': [inf, [], 0], '가능1': [inf, [], 0], '의정부1': [inf, [], 0], '회룡1': [inf, [], 0], '망월사1': [38, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '도봉1', '망월사1'], 0], '도봉1': [36, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1', '도봉1'], 0], '도봉산1': [34, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1', '도봉산1'], 0], '방학1': [32, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1', '신이문1', '성북1', '월계1', '녹천1', '창동1', '방학1'], 0], '창동1': [30, ['시청1', '종각1', '종로3가1', '종로5가1', '동대문1', '동묘앞1', '신설동1', '제기동1', '청량리1', '회기1', '외대앞1',
# ...

# %%
def print_dist_bfs():
    st = input("출발지 : ")
    end = input("도착지 : ")

    bfs(graph, st, end)
    print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ[결과]ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")
    print("배열 : ", dist[end]) # 확인용 코드
    print("거리 : ", dist[end][0], "분")
    print("경로 : ", dist[end][1])
    print("환승 횟수 : ", dist[end][2], "회")
    print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ")

# %%
print_dist_bfs()
# Out:
# 출발지 : 시청1
# 도착지 : 범계4
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ[결과]ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# 배열 :  [36, ['시청1', '서울역1', '서울역4', '숙대입구4', '삼각지4', '신용산4', '이촌4', '동작4', '이수4', '사당4', '남태령4', '선바위4', '경마공원4', '대공원4', '과천4', '정부과천청사4', '인덕원4', '평촌4', '범계4'], 1]
# 거리 :  36 분
# 경로 :  ['시청1', '서울역1', '서울역4', '숙대입구4', '삼각지4', '신용산4', '이촌4', '동작4', '이수4', '사당4', '남태령4', '선바위4', '경마공원4', '대공원4', '과천4', '정부과천청사4', '인덕원4', '평촌4', '범계4']
# 환승 횟수 :  1 회
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
